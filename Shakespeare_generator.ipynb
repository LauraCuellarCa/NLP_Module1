# %%
import nltk
from nltk.book import *
import spacy
nlp = spacy.load("en_core_web_sm")
from nltk.util import bigrams

# %% [markdown]
# # Task 1

# %% [markdown]
# ### Reading Shakepeare's Work:

# %%
import string
from nltk.corpus import gutenberg

# List available texts in the Gutenberg corpus
#print(gutenberg.fileids())

# Access Shakespeare's Macbeth
macbeth_text = gutenberg.raw('shakespeare-macbeth.txt')
#print(macbeth_text[:500])  #Display the first 500 characters

#Accessing Hamlet from Guttenberg Libray 
hamlet_text = gutenberg.raw('shakespeare-hamlet.txt')

#Cleaning Text
hamlet_text = hamlet_text.lower()  #Make it lower case 
hamlet_text = hamlet_text.translate(str.maketrans('', '', string.punctuation))  #Remove Punctuation


#Display 
print(hamlet_text[:200])  # Display the first 100 characters
# Out:
# the tragedie of hamlet by william shakespeare 1599
#
#
# actus primus scoena prima
#
# enter barnardo and francisco two centinels
#
#   barnardo whos there
#   fran nay answer me stand  vnfold
# your selfe
#
#    bar

# %%
#Further Clenaing
hamlet_text = hamlet_text.replace('\n', ' ')  #replace newlines with a space
hamlet_text = hamlet_text.replace('\r', '')   #Remove carriage returns if present

# %%
#Tokenize
hamlet_tokenized = nlp(hamlet_text)

#Display tokenized words, excluding spaces

tokens = [token.text for token in hamlet_tokenized if token.text.strip() != '']


#Print tokenized words
print(tokens)  

# # Tokenize sentences
# doc = nlp(hamlet_text)
# sentences = [sent.text for sent in doc.sents]
# print(sentences)
# Out:
# ['the', 'tragedie', 'of', 'hamlet', 'by', 'william', 'shakespeare', '1599', 'actus', 'primus', 'scoena', 'prima', 'enter', 'barnardo', 'and', 'francisco', 'two', 'centinels', 'barnardo', 'who', 's', 'there', 'fran', 'nay', 'answer', 'me', 'stand', 'vnfold', 'your', 'selfe', 'bar', 'long', 'liue', 'the', 'king', 'fran', 'barnardo', 'bar', 'he', 'fran', 'you', 'come', 'most', 'carefully', 'vpon', 'your', 'houre', 'bar', 'tis', 'now', 'strook', 'twelue', 'get', 'thee', 'to', 'bed', 'francisco', 'fran', 'for', 'this', 'releefe', 'much', 'thankes', 'tis', 'bitter', 'cold', 'and', 'i', 'am', 'sicke', 'at', 'heart', 'barn', 'haue', 'you', 'had', 'quiet', 'guard', 'fran', 'not', 'a', 'mouse', 'stirring', 'barn', 'well', 'goodnight', 'if', 'you', 'do', 'meet', 'horatio', 'and', 'marcellus', 'the', 'riuals', 'of', 'my', 'watch', 'bid', 'them', 'make', 'hast', 'enter', 'horatio', 'and', 'marcellus', 'fran', 'i', 'thinke', 'i', 'heare', 'them', 'stand', 'who', 's', 'there', 'hor', 'friends', 'to', 'this', 'ground', 'mar', 'and', 'leigemen', 'to', 'the', 'dane', 'fran', 'giue', 'you', 'good', 'night', 'mar', 'o', 'farwel', 'honest', 'soldier', 'who', 'hath', 'relieud', 'you', 'fra', 'barnardo', 'has', 'my', 'place', 'giue', 'you', 'goodnight', 'exit', 'fran', 'mar', 'holla', 'barnardo', 'bar', 'say', 'what', 'is', 'horatio', 'there', 'hor', 'a', 'peece', 'of', 'him', 'bar', 'welcome', 'horatio', 'welcome', 'good', 'marcellus', 'mar', 'what', 'has', 'this', 'thing', 'appeard', 'againe', 'to', 'night', 'bar', 'i', 'haue', 'seene', 'nothing', 'mar', 'horatio', 'saies', 'tis', 'but', 'our', 'fantasie', 'and', 'will', 'not', 'let', 'beleefe', 'take', 'hold', 'of', 'him', 'touching', 'this', 'dreaded', 'sight', 'twice', 'seene', 'of', 'vs', 'therefore', 'i', 'haue', 'intreated', 'him', 'along', 'with', 'vs', 'to', 'watch', 'the', 'minutes', 'of', 'this', 'night', 'that', 'if', 'againe', 'this', 'apparition', 'come', 'he', 'may', 'approue', 'our', 'eyes', 'and', 'speake', 'to', 'it', 'hor', 'tush', 'tush', 'twill', 'not', 'appeare', 'bar', 'sit', 'downe', 'awhile', 'and', 'let', 'vs', 'once', 'againe', 'assaile', 'your', 'eares', 'that', 'are', 'so', 'fortified', 'against', 'our', 'story', 'what', 'we', 'two', 'nights', 'haue', 'seene', 'hor', 'well', 'sit', 'we', 'downe', 'and', 'let', 'vs', 'heare', 'barnardo', 'speake', 'of', 'this', 'barn', 'last', 'night', 'of', 'all', 'when', 'yond', 'same', 'starre', 'that', 's', 'westward', 'from', 'the', 'pole', 'had', 'made', 'his', 'course', 't', 'illume', 'that', 'part', 'of', 'heauen', 'where', 'now', 'it', 'burnes', 'marcellus', 'and', 'my', 'selfe', 'the', 'bell', 'then', 'beating', 'one', 'mar', 'peace', 'breake', 'thee', 'of', 'enter', 'the', 'ghost', 'looke', 'where', 'it', 'comes', 'againe', 'barn', 'in', 'the', 'same', 'figure', 'like', 'the', 'king', 'that', 's', 'dead', 'mar', 'thou', 'art', 'a', 'scholler', 'speake', 'to', 'it', 'horatio', 'barn', 'lookes', 'it', 'not', 'like', 'the', 'king', 'marke', 'it', 'horatio', 'hora', 'most', 'like', 'it', 'harrowes', 'me', 'with', 'fear', 'wonder', 'barn', 'it', 'would', 'be', 'spoke', 'too', 'mar', 'question', 'it', 'horatio', 'hor', 'what', 'art', 'thou', 'that', 'vsurpst', 'this', 'time', 'of', 'night', 'together', 'with', 'that', 'faire', 'and', 'warlike', 'forme', 'in', 'which', 'the', 'maiesty', 'of', 'buried', 'denmarke', 'did', 'sometimes', 'march', 'by', 'heauen', 'i', 'charge', 'thee', 'speake', 'mar', 'it', 'is', 'offended', 'barn', 'see', 'it', 'stalkes', 'away', 'hor', 'stay', 'speake', 'speake', 'i', 'charge', 'thee', 'speake', 'exit', 'the', 'ghost', 'mar', 'tis', 'gone', 'and', 'will', 'not', 'answer', 'barn', 'how', 'now', 'horatio', 'you', 'tremble', 'look', 'pale', 'is', 'not', 'this', 'something', 'more', 'then', 'fantasie', 'what', 'thinke', 'you', 'ont', 'hor', 'before', 'my', 'god', 'i', 'might', 'not', 'this', 'beleeue', 'without', 'the', 'sensible', 'and', 'true', 'auouch', 'of', 'mine', 'owne', 'eyes', 'mar', 'is', 'it', ' ...

# %%
#Creating bigrams
hamlet_bigrams = list(bigrams(tokens))
#Print bigrams
print(hamlet_bigrams)
# Out:
# [('the', 'tragedie'), ('tragedie', 'of'), ('of', 'hamlet'), ('hamlet', 'by'), ('by', 'william'), ('william', 'shakespeare'), ('shakespeare', '1599'), ('1599', 'actus'), ('actus', 'primus'), ('primus', 'scoena'), ('scoena', 'prima'), ('prima', 'enter'), ('enter', 'barnardo'), ('barnardo', 'and'), ('and', 'francisco'), ('francisco', 'two'), ('two', 'centinels'), ('centinels', 'barnardo'), ('barnardo', 'who'), ('who', 's'), ('s', 'there'), ('there', 'fran'), ('fran', 'nay'), ('nay', 'answer'), ('answer', 'me'), ('me', 'stand'), ('stand', 'vnfold'), ('vnfold', 'your'), ('your', 'selfe'), ('selfe', 'bar'), ('bar', 'long'), ('long', 'liue'), ('liue', 'the'), ('the', 'king'), ('king', 'fran'), ('fran', 'barnardo'), ('barnardo', 'bar'), ('bar', 'he'), ('he', 'fran'), ('fran', 'you'), ('you', 'come'), ('come', 'most'), ('most', 'carefully'), ('carefully', 'vpon'), ('vpon', 'your'), ('your', 'houre'), ('houre', 'bar'), ('bar', 'tis'), ('tis', 'now'), ('now', 'strook'), ('strook', 'twelue'), ('twelue', 'get'), ('get', 'thee'), ('thee', 'to'), ('to', 'bed'), ('bed', 'francisco'), ('francisco', 'fran'), ('fran', 'for'), ('for', 'this'), ('this', 'releefe'), ('releefe', 'much'), ('much', 'thankes'), ('thankes', 'tis'), ('tis', 'bitter'), ('bitter', 'cold'), ('cold', 'and'), ('and', 'i'), ('i', 'am'), ('am', 'sicke'), ('sicke', 'at'), ('at', 'heart'), ('heart', 'barn'), ('barn', 'haue'), ('haue', 'you'), ('you', 'had'), ('had', 'quiet'), ('quiet', 'guard'), ('guard', 'fran'), ('fran', 'not'), ('not', 'a'), ('a', 'mouse'), ('mouse', 'stirring'), ('stirring', 'barn'), ('barn', 'well'), ('well', 'goodnight'), ('goodnight', 'if'), ('if', 'you'), ('you', 'do'), ('do', 'meet'), ('meet', 'horatio'), ('horatio', 'and'), ('and', 'marcellus'), ('marcellus', 'the'), ('the', 'riuals'), ('riuals', 'of'), ('of', 'my'), ('my', 'watch'), ('watch', 'bid'), ('bid', 'them'), ('them', 'make'), ('make', 'hast'), ('hast', 'enter'), ('enter', 'horatio'), ('horatio', 'and'), ('and', 'marcellus'), ('marcellus', 'fran'), ('fran', 'i'), ('i', 'thinke'), ('thinke', 'i'), ('i', 'heare'), ('heare', 'them'), ('them', 'stand'), ('stand', 'who'), ('who', 's'), ('s', 'there'), ('there', 'hor'), ('hor', 'friends'), ('friends', 'to'), ('to', 'this'), ('this', 'ground'), ('ground', 'mar'), ('mar', 'and'), ('and', 'leigemen'), ('leigemen', 'to'), ('to', 'the'), ('the', 'dane'), ('dane', 'fran'), ('fran', 'giue'), ('giue', 'you'), ('you', 'good'), ('good', 'night'), ('night', 'mar'), ('mar', 'o'), ('o', 'farwel'), ('farwel', 'honest'), ('honest', 'soldier'), ('soldier', 'who'), ('who', 'hath'), ('hath', 'relieud'), ('relieud', 'you'), ('you', 'fra'), ('fra', 'barnardo'), ('barnardo', 'has'), ('has', 'my'), ('my', 'place'), ('place', 'giue'), ('giue', 'you'), ('you', 'goodnight'), ('goodnight', 'exit'), ('exit', 'fran'), ('fran', 'mar'), ('mar', 'holla'), ('holla', 'barnardo'), ('barnardo', 'bar'), ('bar', 'say'), ('say', 'what'), ('what', 'is'), ('is', 'horatio'), ('horatio', 'there'), ('there', 'hor'), ('hor', 'a'), ('a', 'peece'), ('peece', 'of'), ('of', 'him'), ('him', 'bar'), ('bar', 'welcome'), ('welcome', 'horatio'), ('horatio', 'welcome'), ('welcome', 'good'), ('good', 'marcellus'), ('marcellus', 'mar'), ('mar', 'what'), ('what', 'has'), ('has', 'this'), ('this', 'thing'), ('thing', 'appeard'), ('appeard', 'againe'), ('againe', 'to'), ('to', 'night'), ('night', 'bar'), ('bar', 'i'), ('i', 'haue'), ('haue', 'seene'), ('seene', 'nothing'), ('nothing', 'mar'), ('mar', 'horatio'), ('horatio', 'saies'), ('saies', 'tis'), ('tis', 'but'), ('but', 'our'), ('our', 'fantasie'), ('fantasie', 'and'), ('and', 'will'), ('will', 'not'), ('not', 'let'), ('let', 'beleefe'), ('beleefe', 'take'), ('take', 'hold'), ('hold', 'of'), ('of', 'him'), ('him', 'touching'), ('touching', 'this'), ('this', 'dreaded'), ('dreaded', 'sight'), ('sight', 'twice'), ('twice', 'seene'), ('seene', 'of'), ('of', 'vs'), ('vs', 'therefore'), ('therefore', 'i'), ('i', 'haue'), ('haue', 'intreated'), ('intreated', ' ...

# %% [markdown]
# ### Dictionary of Bigram Counts

# %%
from collections import defaultdict

#initialize dictionary with default dictionaries inside
from_bigram_to_next_token_counts = defaultdict(lambda: defaultdict(int))

#loop through the bigram list
for i in range(len(hamlet_bigrams) - 1):  #stop at len(bigram_list) - 1 to access the next token
    bigram = hamlet_bigrams[i]  #crrent bigram
    next_token = hamlet_bigrams[i + 1][0]  # get the first token of the next bigram
    from_bigram_to_next_token_counts[bigram][next_token] += 1  #increment count

#print it nicely
for bigram, next_tokens in from_bigram_to_next_token_counts.items():
    print(f"{bigram} -> {dict(next_tokens)}")
# Out:
# ('the', 'tragedie') -> {'tragedie': 2}
# ('tragedie', 'of') -> {'of': 2}
# ('of', 'hamlet') -> {'hamlet': 5}
# ('hamlet', 'by') -> {'by': 1}
# ('by', 'william') -> {'william': 1}
# ('william', 'shakespeare') -> {'shakespeare': 1}
# ('shakespeare', '1599') -> {'1599': 1}
# ('1599', 'actus') -> {'actus': 1}
# ('actus', 'primus') -> {'primus': 1}
# ('primus', 'scoena') -> {'scoena': 1}
# ('scoena', 'prima') -> {'prima': 1}
# ('prima', 'enter') -> {'enter': 1}
# ('enter', 'barnardo') -> {'barnardo': 1}
# ('barnardo', 'and') -> {'and': 2}
# ('and', 'francisco') -> {'francisco': 1}
# ('francisco', 'two') -> {'two': 1}
# ('two', 'centinels') -> {'centinels': 1}
# ('centinels', 'barnardo') -> {'barnardo': 1}
# ('barnardo', 'who') -> {'who': 1}
# ('who', 's') -> {'s': 2}
# ('s', 'there') -> {'there': 2}
# ('there', 'fran') -> {'fran': 1}
# ('fran', 'nay') -> {'nay': 1}
# ('nay', 'answer') -> {'answer': 1}
# ('answer', 'me') -> {'me': 2}
# ('me', 'stand') -> {'stand': 1}
# ('stand', 'vnfold') -> {'vnfold': 1}
# ('vnfold', 'your') -> {'your': 1}
# ('your', 'selfe') -> {'selfe': 15}
# ('selfe', 'bar') -> {'bar': 1}
# ('bar', 'long') -> {'long': 1}
# ('long', 'liue') -> {'liue': 1}
# ('liue', 'the') -> {'the': 4}
# ('the', 'king') -> {'king': 39}
# ('king', 'fran') -> {'fran': 1}
# ('fran', 'barnardo') -> {'barnardo': 1}
# ('barnardo', 'bar') -> {'bar': 2}
# ('bar', 'he') -> {'he': 1}
# ('he', 'fran') -> {'fran': 1}
# ('fran', 'you') -> {'you': 1}
# ('you', 'come') -> {'come': 2}
# ('come', 'most') -> {'most': 1}
# ('most', 'carefully') -> {'carefully': 1}
# ('carefully', 'vpon') -> {'vpon': 1}
# ('vpon', 'your') -> {'your': 4}
# ('your', 'houre') -> {'houre': 1}
# ('houre', 'bar') -> {'bar': 1}
# ('bar', 'tis') -> {'tis': 1}
# ('tis', 'now') -> {'now': 2}
# ('now', 'strook') -> {'strook': 1}
# ('strook', 'twelue') -> {'twelue': 1}
# ('twelue', 'get') -> {'get': 1}
# ('get', 'thee') -> {'thee': 4}
# ('thee', 'to') -> {'to': 5}
# ('to', 'bed') -> {'bed': 4}
# ('bed', 'francisco') -> {'francisco': 1}
# ('francisco', 'fran') -> {'fran': 1}
# ('fran', 'for') -> {'for': 1}
# ('for', 'this') -> {'this': 7}
# ('this', 'releefe') -> {'releefe': 1}
# ('releefe', 'much') -> {'much': 1}
# ('much', 'thankes') -> {'thankes': 1}
# ('thankes', 'tis') -> {'tis': 1}
# ('tis', 'bitter') -> {'bitter': 1}
# ('bitter', 'cold') -> {'cold': 1}
# ('cold', 'and') -> {'and': 1}
# ('and', 'i') -> {'i': 12}
# ('i', 'am') -> {'am': 43}
# ('am', 'sicke') -> {'sicke': 1}
# ('sicke', 'at') -> {'at': 1}
# ('at', 'heart') -> {'heart': 1}
# ('heart', 'barn') -> {'barn': 1}
# ('barn', 'haue') -> {'haue': 1}
# ('haue', 'you') -> {'you': 14}
# ('you', 'had') -> {'had': 1}
# ('had', 'quiet') -> {'quiet': 1}
# ('quiet', 'guard') -> {'guard': 1}
# ('guard', 'fran') -> {'fran': 1}
# ('fran', 'not') -> {'not': 1}
# ('not', 'a') -> {'a': 6}
# ('a', 'mouse') -> {'mouse': 1}
# ('mouse', 'stirring') -> {'stirring': 1}
# ('stirring', 'barn') -> {'barn': 1}
# ('barn', 'well') -> {'well': 1}
# ('well', 'goodnight') -> {'goodnight': 1}
# ('goodnight', 'if') -> {'if': 1}
# ('if', 'you') -> {'you': 13}
# ('you', 'do') -> {'do': 3}
# ('do', 'meet') -> {'meet': 1}
# ('meet', 'horatio') -> {'horatio': 1}
# ('horatio', 'and') -> {'and': 3}
# ('and', 'marcellus') -> {'marcellus': 4}
# ('marcellus', 'the') -> {'the': 1}
# ('the', 'riuals') -> {'riuals': 1}
# ('riuals', 'of') -> {'of': 1}
# ('of', 'my') -> {'my': 25}
# ('my', 'watch') -> {'watch': 1}
# ('watch', 'bid') -> {'bid': 1}
# ('bid', 'them') -> {'them': 1}
# ('them', 'make') -> {'make': 1}
# ('make', 'hast') -> {'hast': 3}
# ('hast', 'enter') -> {'enter': 1}
# ('enter', 'horatio') -> {'horatio': 5}
# ('marcellus', 'fran') -> {'fran': 1}
# ('fran', 'i') -> {'i': 1}
# ('i', 'thinke') -> {'thinke': 9}
# ('thinke', 'i') -> {'i': 4}
# ('i', 'heare') -> {'heare': 3}
# ('heare', 'them') -> {'them': 2}
# ('them', 'stand') -> {'stand': 2}
# ('stand', 'who') -> {'who': 1}
# ('there', 'hor') -> {'hor': 3}
# ('hor', 'friends') -> {'friends': 1}
# ('friends', 'to') -> {'to': 2}
# ('to', 'this') -> {'this': 15}
# ('this', 'ground') -> {'ground': 1}
# ('ground', 'mar') -> {'mar': 1}
# ('mar', 'and') -> {'and': 1}
# ('and', 'leigemen') -> {'leigemen': 1}
# ('leigemen', 'to') -> {'to': 1}
# ('to', 'the') -> {'the': 60}
# ('the', 'dane') -> {'dane': 3}
# ('dane', 'fran') -> {'fran': 1}
# ('fran', 'giue') -> {'giue': 1}
# ('giue', 'you') -> {'you': 4}
# ('you', 'good') -> {'good': 5}
# ('good', 'night') -> {'night': 4}
# ('night', 'mar') -> {'mar': 1}
# ('mar', 'o') -> {'o': 1}
# ('o', 'farwel') -> {'farwel': 1}
# ('farwel', 'honest') -> {'honest': 1}
# ('honest', 'soldier') -> {'soldier': 1}
# ('soldier', 'who') -> {'who': 1}
# ('who', 'hath') -> {'hath': 1}
# ('hath', 'relieud') -> {'relieud': 1}
# ('relieud', 'you') -> {'you': 1}
# ('you', 'fra') -> {'fra': 1}
# ('fra', 'barnardo') -> {'barnardo': 1}
# ('barnardo', 'has') -> {'has': 1}
# ('has', 'my') -> {'my': 2}
# ('my', 'place') -> {'place': 1}
# ('place', 'giue') -> {'giue': 1}
# ('you', 'goodnight') -> {'goodnight': 1}
# ('goodnight', 'exit') -> {'exit': 1}
# ('exit', 'fran') -> {'fran': 1}
# ('fran', 'mar') -> {'mar': 1}
# ('mar', 'holla') -> {'holla': 1}
# ('holla', 'barnardo') -> {'barnardo': 1}
# ('bar', 'say') -> {'say': 1}
# ('say', 'what') -> {'what': 2}
# ('what', 'is') -> {'is': 19}
# ('is', 'horatio') -> {'horatio': 1}
# ('horatio', 'there') -> {'there': 1}
# ('hor', 'a') -> {'a': 3}
# ('a', 'peece') -> {'peece': 3}
# ('peece', 'of') -> {'of': 4}
# ('of', 'him') -> {'him': 6}
# ('him', 'bar') -> {'bar': 1}
# ('bar', 'welcome') -> {'welcome': 1}
# ('welcome', 'horatio') -> {'horatio': 1}
# ('horatio', 'welcome') -> {'welcome': 1}
# ('welcome', 'good') -> {'good': 3}
# ('good', 'marcellus') -> {'marcellus': 1}
# ('marcellus', 'mar') -> {'mar': 4}
# ('mar', 'what') -> {'what': 1}
# ('what', 'has') -> {'has': 1}
# ('has', 'this') -> {'this': 2}
# ('this', 'thing') -> {'thing': 1}
# ('thing', 'appeard') -> {'appeard': 1}
# ('appeard', 'againe') -> {'againe': 1}
# ('againe', 'to') -> {'to': 3}
# ('to', 'night') -> {'night': 11}
# ('night', 'bar') -> {'bar': 1}
# ('bar', 'i') -> {'i': 1}
# ('i', 'haue') -> {'haue': 53}
# ('haue', 'seene') -> {'seene': 10}
# ('seene', 'nothing') -> {'nothing': 1}
# ('nothing', 'mar') -> {'mar': 1}
# ('mar', 'horatio') -> {'horatio': 1}
# ('horatio', 'saies') -> {'saies': 1}
# ('saies', 'tis') -> {'tis': 1}
# ('tis', 'but') -> {'but': 1}
# ('but', 'our') -> {'our': 3}
# ('our', 'fantasie') -> {'fantasie': 1}
# ('fantasie', 'and') -> {'and': 1}
# ('and', 'will') -> {'will': 8}
# ('will', 'not') -> {'not': 12}
# ('not', 'let') -> {'let': 4}
# ('let', 'beleefe') -> {'beleefe': 1}
# ('beleefe', 'take') -> {'take': 1}
# ('take', 'hold') -> {'hold': 1}
# ('hold', 'of') -> {'of': 1}
# ('him', 'touching') -> {'touching': 1}
# ('touching', 'this') -> {'this': 2}
# ('this', 'dreaded') -> {'dreaded': 1}
# ('dreaded', 'sight') -> {'sight': 1}
# ('sight', 'twice') -> {'twice': 1}
# ('twice', 'seene') -> {'seene': 1}
# ('seene', 'of') -> {'of': 1}
# ('of', 'vs') -> {'vs': 6}
# ('vs', 'therefore') -> {'therefore': 1}
# ('therefore', 'i') -> {'i': 2}
# ('haue', 'intreated') -> {'intreated': 1}
# ('intreated', 'him') -> {'him': 1}
# ('him', 'along') -> {'along': 1}
# ('along', 'with') -> {'with': 2}
# ('with', 'vs') -> {'vs': 9}
# ('vs', 'to') -> {'to': 5}
# ('to', 'watch') -> {'watch': 1}
# ('watch', 'the') -> {'the': 1}
# ('the', 'minutes') -> {'minutes': 1}
# ('minutes', 'of') -> {'of': 1}
# ('of', 'this') -> {'this': 23}
# ('this', 'night') -> {'night': 2}
# ('night', 'that') -> {'that': 1}
# ('that', 'if') -> {'if': 3}
# ('if', 'againe') -> {'againe': 1}
# ('againe', 'this') -> {'this': 1}
# ('this', 'apparition') -> {'apparition': 1}
# ('apparition', 'come') -> {'come': 1}
# ('come', 'he') -> {'he': 1}
# ('he', 'may') -> {'may': 3}
# ('may', 'approue') -> {'approue': 1}
# ('approue', 'our') -> {'our': 1}
# ('our', 'eyes') -> {'eyes': 1}
# ('eyes', 'and') -> {'and': 3}
# ('and', 'speake') -> {'speake': 3}
# ('speake', 'to') -> {'to': 13}
# ('to', 'it') -> {'it': 5}
# ('it', 'hor') -> {'hor': 7}
# ('hor', 'tush') -> {'tush': 1}
# ('tush', 'tush') -> {'tush': 1}
# ('tush', 'twill') -> {'twill': 1}
# ('twill', 'not') -> {'not': 2}
# ('not', 'appeare') -> {'appeare': 1}
# ('appeare', 'bar') -> {'bar': 1}
# ('bar', 'sit') -> {'sit': 1}
# ('sit', 'downe') -> {'downe': 2}
# ('downe', 'awhile') -> {'awhile': 1}
# ('awhile', 'and') -> {'and': 2}
# ('and', 'let') -> {'let': 11}
# ('let', 'vs') -> {'vs': 7}
# ('vs', 'once') -> {'once': 1}
# ('once', 'againe') -> {'againe': 1}
# ('againe', 'assaile') -> {'assaile': 1}
# ('assaile', 'your') -> {'your': 1}
# ('your', 'eares') -> {'eares': 1}
# ('eares', 'that') -> {'that': 1}
# ('that', 'are') -> {'are': 3}
# ('are', 'so') -> {'so': 3}
# ('so', 'fortified') -> {'fortified': 1}
# ('fortified', 'against') -> {'against': 1}
# ('against', 'our') -> {'our': 1}
# ('our', 'story') -> {'story': 1}
# ('story', 'what') -> {'what': 1}
# ('what', 'we') -> {'we': 7}
# ('we', 'two') -> {'two': 1}
# ('two', 'nights') -> {'nights': 2}
# ('nights', 'haue') -> {'haue': 1}
# ('seene', 'hor') -> {'hor': 1}
# ('hor', 'well') -> {'well': 1}
# ('well', 'sit') -> {'sit': 1}
# ('sit', 'we') -> {'we': 1}
# ('we', 'downe') -> {'downe': 1}
# ('downe', 'and') -> {'and': 3}
# ('vs', 'heare') -> {'heare': 1}
# ('heare', 'barnardo') -> {'barnardo': 1}
# ('barnardo', 'speake') -> {'speake': 1}
# ('speake', 'of') -> {'of': 7}
# ('this', 'barn') -> {'barn': 1}
# ('barn', 'last') -> {'last': 1}
# ('last', 'night') -> {'night': 1}
# ('night', 'of') -> {'of': 1}
# ('of', 'all') -> {'all': 9}
# ('all', 'when') -> {'when': 2}
# ('when', 'yond') -> {'yond': 1}
# ('yond', 'same') -> {'same': 1}
# ('same', 'starre') -> {'starre': 1}
# ('starre', 'that') -> {'that': 1}
# ('that', 's') -> {'s': 15}
# ('s', 'westward') -> {'westward': 1}
# ('westward', 'from') -> {'from': 1}
# ('from', 'the') -> {'the': 10}
# ('the', 'pole') -> {'pole': 1}
# ('pole', 'had') -> {'had': 1}
# ('had', 'made') -> {'made': 2}
# ('made', 'his') -> {'his': 1}
# ('his', 'course') -> {'course': 1}
# ('course', 't') -> {'t': 1}
# ('t', 'illume') -> {'illume': 1}
# ('illume', 'that') -> {'that': 1}
# ('that', 'part') -> {'part': 1}
# ('part', 'of') -> {'of': 5}
# ('of', 'heauen') -> {'heauen': 8}
# ('heauen', 'where') -> {'where': 1}
# ('where', 'now') -> {'now': 1}
# ('now', 'it') -> {'it': 2}
# ('it', 'burnes') -> {'burnes': 1}
# ('burnes', 'marcellus') -> {'marcellus': 1}
# ('marcellus', 'and') -> {'and': 2}
# ('and', 'my') -> {'my': 14}
# ('my', 'selfe') -> {'selfe': 12}
# ('selfe', 'the') -> {'the': 2}
# ('the', 'bell') -> {'bell': 1}
# ('bell', 'then') -> {'then': 1}
# ('then', 'beating') -> {'beating': 1}
# ('beating', 'one') -> {'one': 1}
# ('one', 'mar') -> {'mar': 1}
# ('mar', 'peace') -> {'peace': 1}
# ('peace', 'breake') -> {'breake': 1}
# ('breake', 'thee') -> {'thee': 1}
# ('thee', 'of') -> {'of': 3}
# ('of', 'enter') -> {'enter': 1}
# ('enter', 'the') -> {'the': 1}
# ('the', 'ghost') -> {'ghost': 2}
# ('ghost', 'looke') -> {'looke': 1}
# ('looke', 'where') -> {'where': 5}
# ('where', 'it') -> {'it': 4}
# ('it', 'comes') -> {'comes': 5}
# ('comes', 'againe') -> {'againe': 2}
# ('againe', 'barn') -> {'barn': 1}
# ('barn', 'in') -> {'in': 1}
# ('in', 'the') -> {'the': 73}
# ('the', 'same') -> {'same': 5}
# ('same', 'figure') -> {'figure': 1}
# ('figure', 'like') -> {'like': 2}
# ('like', 'the') -> {'the': 11}
# ('king', 'that') -> {'that': 3}
# ('s', 'dead') -> {'dead': 1}
# ('dead', 'mar') -> {'mar': 1}
# ('mar', 'thou') -> {'thou': 1}
# ('thou', 'art') -> {'art': 6}
# ('art', 'a') -> {'a': 2}
# ('a', 'scholler') -> {'scholler': 1}
# ('scholler', 'speake') -> {'speake': 1}
# ('it', 'horatio') -> {'horatio': 3}
# ('horatio', 'barn') -> {'barn': 1}
# ('barn', 'lookes') -> {'lookes': 1}
# ('lookes', 'it') -> {'it': 1}
# ('it', 'not') -> {'not': 15}
# ('not', 'like') -> {'like': 3}
# ('king', 'marke') -> {'marke': 1}
# ('marke', 'it') -> {'it': 1}
# ('horatio', 'hora') -> {'hora': 2}
# ('hora', 'most') -> {'most': 1}
# ('most', 'like') -> {'like': 4}
# ('like', 'it') -> {'it': 2}
# ('it', 'harrowes') -> {'harrowes': 1}
# ('harrowes', 'me') -> {'me': 1}
# ('me', 'with') -> {'with': 8}
# ('with', 'fear') -> {'fear': 1}
# ('fear', 'wonder') -> {'wonder': 1}
# ('wonder', 'barn') -> {'barn': 1}
# ('barn', 'it') -> {'it': 2}
# ('it', 'would') -> {'would': 5}
# ('would', 'be') -> {'be': 3}
# ('be', 'spoke') -> {'spoke': 1}
# ('spoke', 'too') -> {'too': 1}
# ('too', 'mar') -> {'mar': 1}
# ('mar', 'question') -> {'question': 1}
# ('question', 'it') -> {'it': 1}
# ('horatio', 'hor') -> {'hor': 2}
# ('hor', 'what') -> {'what': 6}
# ('what', 'art') -> {'art': 2}
# ('art', 'thou') -> {'thou': 3}
# ('thou', 'that') -> {'that': 1}
# ('that', 'vsurpst') -> {'vsurpst': 1}
# ('vsurpst', 'this') -> {'this': 1}
# ('this', 'time') -> {'time': 4}
# ('time', 'of') -> {'of': 4}
# ('of', 'night') -> {'night': 2}
# ('night', 'together') -> {'together': 1}
# ('together', 'with') -> {'with': 4}
# ('with', 'that') -> {'that': 1}
# ('that', 'faire') -> {'faire': 1}
# ('faire', 'and') -> {'and': 4}
# ('and', 'warlike') -> {'warlike': 1}
# ('warlike', 'forme') -> {'forme': 1}
# ('forme', 'in') -> {'in': 1}
# ('in', 'which') -> {'which': 3}
# ('which', 'the') -> {'the': 1}
# ('the', 'maiesty') -> {'maiesty': 1}
# ('maiesty', 'of') -> {'of': 2}
# ('of', 'buried') -> {'buried': 1}
# ('buried', 'denmarke') -> {'denmarke': 1}
# ('denmarke', 'did') -> {'did': 1}
# ('did', 'sometimes') -> {'sometimes': 1}
# ('sometimes', 'march') -> {'march': 1}
# ('march', 'by') -> {'by': 1}
# ('by', 'heauen') -> {'heauen': 6}
# ('heauen', 'i') -> {'i': 1}
# ('i', 'charge') -> {'charge': 3}
# ('charge', 'thee') -> {'thee': 2}
# ('thee', 'speake') -> {'speake': 3}
# ('speake', 'mar') -> {'mar': 1}
# ('mar', 'it') -> {'it': 2}
# ('it', 'is') -> {'is': 52}
# ('is', 'offended') -> {'offended': 1}
# ('offended', 'barn') -> {'barn': 1}
# ('barn', 'see') -> {'see': 1}
# ('see', 'it') -> {'it': 1}
# ('it', 'stalkes') -> {'stalkes': 1}
# ('stalkes', 'away') -> {'away': 1}
# ('away', 'hor') -> {'hor': 1}
# ('hor', 'stay') -> {'stay': 1}
# ('stay', 'speake') -> {'speake': 1}
# ('speake', 'speake') -> {'speake': 1}
# ('speake', 'i') -> {'i': 2}
# ('speake', 'exit') -> {'exit': 1}
# ('exit', 'the') -> {'the': 1}
# ('ghost', 'mar') -> {'mar': 1}
# ('mar', 'tis') -> {'tis': 2}
# ('tis', 'gone') -> {'gone': 2}
# ('gone', 'and') -> {'and': 4}
# ('not', 'answer') -> {'answer': 1}
# ('answer', 'barn') -> {'barn': 1}
# ('barn', 'how') -> {'how': 1}
# ('how', 'now') -> {'now': 10}
# ('now', 'horatio') -> {'horatio': 1}
# ('horatio', 'you') -> {'you': 1}
# ('you', 'tremble') -> {'tremble': 1}
# ('tremble', 'look') -> {'look': 1}
# ('look', 'pale') -> {'pale': 1}
# ('pale', 'is') -> {'is': 1}
# ('is', 'not') -> {'not': 20}
# ('not', 'this') -> {'this': 5}
# ('this', 'something') -> {'something': 2}
# ('something', 'more') -> {'more': 1}
# ('more', 'then') -> {'then': 11}
# ('then', 'fantasie') -> {'fantasie': 1}
# ('fantasie', 'what') -> {'what': 1}
# ('what', 'thinke') -> {'thinke': 2}
# ('thinke', 'you') -> {'you': 3}
# ('you', 'ont') -> {'ont': 2}
# ('ont', 'hor') -> {'hor': 1}
# ('hor', 'before') -> {'before': 1}
# ('before', 'my') -> {'my': 2}
# ('my', 'god') -> {'god': 2}
# ('god', 'i') -> {'i': 2}
# ('i', 'might') -> {'might': 2}
# ('might', 'not') -> {'not': 4}
# ('this', 'beleeue') -> {'beleeue': 1}
# ('beleeue', 'without') -> {'without': 1}
# ('without', 'the') -> {'the': 3}
# ('the', 'sensible') -> {'sensible': 1}
# ('sensible', 'and') -> {'and': 1}
# ('and', 'true') -> {'true': 1}
# ('true', 'auouch') -> {'auouch': 1}
# ('auouch', 'of') -> {'of': 1}
# ('of', 'mine') -> {'mine': 7}
# ('mine', 'owne') -> {'owne': 6}
# ('owne', 'eyes') -> {'eyes': 1}
# ('eyes', 'mar') -> {'mar': 1}
# ('mar', 'is') -> {'is': 1}
# ('is', 'it') -> {'it': 13}
# ('king', 'hor') -> {'hor': 1}
# ('hor', 'as') -> {'as': 2}
# ('as', 'thou') -> {'thou': 3}
# ('art', 'to') -> {'to': 2}
# ('to', 'thy') -> {'thy': 9}
# ('thy', 'selfe') -> {'selfe': 5}
# ('selfe', 'such') -> {'such': 1}
# ('such', 'was') -> {'was': 1}
# ('was', 'the') -> {'the': 6}
# ('the', 'very') -> {'very': 13}
# ('very', 'armour') -> {'armour': 1}
# ('armour', 'he') -> {'he': 1}
# ('he', 'had') -> {'had': 3}
# ('had', 'on') -> {'on': 1}
# ('on', 'when') -> {'when': 1}
# ('when', 'th') -> {'th': 1}
# ('th', 'ambitious') -> {'ambitious': 1}
# ('ambitious', 'norwey') -> {'norwey': 1}
# ('norwey', 'combatted') -> {'combatted': 1}
# ('combatted', 'so') -> {'so': 1}
# ('so', 'frownd') -> {'frownd': 1}
# ('frownd', 'he') -> {'he': 1}
# ('he', 'once') -> {'once': 1}
# ('once', 'when') -> {'when': 1}
# ('when', 'in') -> {'in': 2}
# ('in', 'an') -> {'an': 1}
# ('an', 'angry') -> {'angry': 1}
# ('angry', 'parle') -> {'parle': 1}
# ('parle', 'he') -> {'he': 1}
# ('he', 'smot') -> {'smot': 1}
# ('smot', 'the') -> {'the': 1}
# ('the', 'sledded') -> {'sledded': 1}
# ('sledded', 'pollax') -> {'pollax': 1}
# ('pollax', 'on') -> {'on': 1}
# ('on', 'the') -> {'the': 21}
# ('the', 'ice') -> {'ice': 1}
# ('ice', 'tis') -> {'tis': 1}
# ('tis', 'strange') -> {'strange': 1}
# ('strange', 'mar') -> {'mar': 1}
# ('mar', 'thus') -> {'thus': 1}
# ('thus', 'twice') -> {'twice': 1}
# ('twice', 'before') -> {'before': 1}
# ('before', 'and') -> {'and': 1}
# ('and', 'iust') -> {'iust': 1}
# ('iust', 'at') -> {'at': 1}
# ('at', 'this') -> {'this': 3}
# ('this', 'dead') -> {'dead': 1}
# ('dead', 'houre') -> {'houre': 1}
# ('houre', 'with') -> {'with': 1}
# ('with', 'martiall') -> {'martiall': 1}
# ('martiall', 'stalke') -> {'stalke': 1}
# ('stalke', 'hath') -> {'hath': 1}
# ('hath', 'he') -> {'he': 2}
# ('he', 'gone') -> {'gone': 2}
# ('gone', 'by') -> {'by': 1}
# ('by', 'our') -> {'our': 4}
# ('our', 'watch') -> {'watch': 3}
# ('watch', 'hor') -> {'hor': 1}
# ('hor', 'in') -> {'in': 1}
# ('in', 'what') -> {'what': 3}
# ('what', 'particular') -> {'particular': 1}
# ('particular', 'thought') -> {'thought': 1}
# ('thought', 'to') -> {'to': 2}
# ('to', 'work') -> {'work': 1}
# ('work', 'i') -> {'i': 1}
# ('i', 'know') -> {'know': 20}
# ('know', 'not') -> {'not': 8}
# ('not', 'but') -> {'but': 5}
# ('but', 'in') -> {'in': 8}
# ('the', 'grosse') -> {'grosse': 1}
# ('grosse', 'and') -> {'and': 1}
# ('and', 'scope') -> {'scope': 1}
# ('scope', 'of') -> {'of': 2}
# ('my', 'opinion') -> {'opinion': 1}
# ('opinion', 'this') -> {'this': 1}
# ('this', 'boades') -> {'boades': 1}
# ('boades', 'some') -> {'some': 1}
# ('some', 'strange') -> {'strange': 1}
# ('strange', 'erruption') -> {'erruption': 1}
# ('erruption', 'to') -> {'to': 1}
# ('to', 'our') -> {'our': 8}
# ('our', 'state') -> {'state': 3}
# ('state', 'mar') -> {'mar': 1}
# ('mar', 'good') -> {'good': 1}
# ('good', 'now') -> {'now': 1}
# ('now', 'sit') -> {'sit': 1}
# ('downe', 'tell') -> {'tell': 1}
# ('tell', 'me') -> {'me': 6}
# ('me', 'he') -> {'he': 2}
# ('he', 'that') -> {'that': 6}
# ('that', 'knowes') -> {'knowes': 1}
# ('knowes', 'why') -> {'why': 1}
# ('why', 'this') -> {'this': 1}
# ('this', 'same') -> {'same': 6}
# ('same', 'strict') -> {'strict': 1}
# ('strict', 'and') -> {'and': 1}
# ('and', 'most') -> {'most': 6}
# ('most', 'obseruant') -> {'obseruant': 1}
# ('obseruant', 'watch') -> {'watch': 1}
# ('watch', 'so') -> {'so': 1}
# ('so', 'nightly') -> {'nightly': 1}
# ('nightly', 'toyles') -> {'toyles': 1}
# ('toyles', 'the') -> {'the': 1}
# ('the', 'subiect') -> {'subiect': 1}
# ('subiect', 'of') -> {'of': 1}
# ('of', 'the') -> {'the': 59}
# ('the', 'land') -> {'land': 3}
# ('land', 'and') -> {'and': 2}
# ('and', 'why') -> {'why': 2}
# ('why', 'such') -> {'such': 2}
# ('such', 'dayly') -> {'dayly': 1}
# ('dayly', 'cast') -> {'cast': 1}
# ('cast', 'of') -> {'of': 2}
# ('of', 'brazon') -> {'brazon': 1}
# ('brazon', 'cannon') -> {'cannon': 1}
# ('cannon', 'and') -> {'and': 1}
# ('and', 'forraigne') -> {'forraigne': 1}
# ('forraigne', 'mart') -> {'mart': 1}
# ('mart', 'for') -> {'for': 1}
# ('for', 'implements') -> {'implements': 1}
# ('implements', 'of') -> {'of': 1}
# ('of', 'warre') -> {'warre': 2}
# ('warre', 'why') -> {'why': 1}
# ('such', 'impresse') -> {'impresse': 1}
# ('impresse', 'of') -> {'of': 1}
# ('of', 'shipwrights') -> {'shipwrights': 1}
# ('shipwrights', 'whose') -> {'whose': 1}
# ('whose', 'sore') -> {'sore': 1}
# ('sore', 'taske') -> {'taske': 1}
# ('taske', 'dos') -> {'dos': 1}
# ('dos', 'not') -> {'not': 1}
# ('not', 'diuide') -> {'diuide': 1}
# ('diuide', 'the') -> {'the': 1}
# ('the', 'sunday') -> {'sunday': 1}
# ('sunday', 'from') -> {'from': 1}
# ('the', 'weeke') -> {'weeke': 1}
# ('weeke', 'what') -> {'what': 1}
# ('what', 'might') -> {'might': 4}
# ('might', 'be') -> {'be': 5}
# ('be', 'toward') -> {'toward': 1}
# ('toward', 'that') -> {'that': 1}
# ('that', 'this') -> {'this': 6}
# ('this', 'sweaty') -> {'sweaty': 1}
# ('sweaty', 'hast') -> {'hast': 1}
# ('hast', 'doth') -> {'doth': 1}
# ('doth', 'make') -> {'make': 1}
# ('make', 'the') -> {'the': 4}
# ('the', 'night') -> {'night': 6}
# ('night', 'ioyntlabourer') -> {'ioyntlabourer': 1}
# ('ioyntlabourer', 'with') -> {'with': 1}
# ('with', 'the') -> {'the': 19}
# ('the', 'day') -> {'day': 5}
# ('day', 'who') -> {'who': 1}
# ('who', 'ist') -> {'ist': 1}
# ('ist', 'that') -> {'that': 1}
# ('that', 'can') -> {'can': 6}
# ('can', 'informe') -> {'informe': 1}
# ('informe', 'me') -> {'me': 1}
# ('me', 'hor') -> {'hor': 2}
# ('hor', 'that') -> {'that': 2}
# ('can', 'i') -> {'i': 3}
# ('i', 'at') -> {'at': 1}
# ('at', 'least') -> {'least': 2}
# ('least', 'the') -> {'the': 1}
# ('the', 'whisper') -> {'whisper': 1}
# ('whisper', 'goes') -> {'goes': 1}
# ('goes', 'so') -> {'so': 2}
# ('so', 'our') -> {'our': 1}
# ('our', 'last') -> {'last': 3}
# ('last', 'king') -> {'king': 2}
# ('king', 'whose') -> {'whose': 1}
# ('whose', 'image') -> {'image': 1}
# ('image', 'euen') -> {'euen': 1}
# ('euen', 'but') -> {'but': 1}
# ('but', 'now') -> {'now': 3}
# ('now', 'appeard') -> {'appeard': 1}
# ('appeard', 'to') -> {'to': 2}
# ('to', 'vs') -> {'vs': 6}
# ('vs', 'was') -> {'was': 1}
# ('was', 'as') -> {'as': 3}
# ('as', 'you') -> {'you': 12}
# ('you', 'know') -> {'know': 12}
# ('know', 'by') -> {'by': 2}
# ('by', 'fortinbras') -> {'fortinbras': 1}
# ('fortinbras', 'of') -> {'of': 2}
# ('of', 'norway') -> {'norway': 2}
# ('norway', 'thereto') -> {'thereto': 1}
# ('thereto', 'prickd') -> {'prickd': 1}
# ('prickd', 'on') -> {'on': 1}
# ('on', 'by') -> {'by': 2}
# ('by', 'a') -> {'a': 5}
# ('a', 'most') -> {'most': 4}
# ('most', 'emulate') -> {'emulate': 1}
# ('emulate', 'pride') -> {'pride': 1}
# ('pride', 'dard') -> {'dard': 1}
# ('dard', 'to') -> {'to': 1}
# ('the', 'combate') -> {'combate': 1}
# ('combate', 'in') -> {'in': 1}
# ('which', 'our') -> {'our': 1}
# ('our', 'valiant') -> {'valiant': 1}
# ('valiant', 'hamlet') -> {'hamlet': 1}
# ('hamlet', 'for') -> {'for': 2}
# ('for', 'so') -> {'so': 3}
# ('so', 'this') -> {'this': 1}
# ('this', 'side') -> {'side': 1}
# ('side', 'of') -> {'of': 1}
# ('of', 'our') -> {'our': 18}
# ('our', 'knowne') -> {'knowne': 1}
# ('knowne', 'world') -> {'world': 1}
# ('world', 'esteemd') -> {'esteemd': 1}
# ('esteemd', 'him') -> {'him': 1}
# ('him', 'did') -> {'did': 1}
# ('did', 'slay') -> {'slay': 1}
# ('slay', 'this') -> {'this': 1}
# ('this', 'fortinbras') -> {'fortinbras': 1}
# ('fortinbras', 'who') -> {'who': 2}
# ('who', 'by') -> {'by': 1}
# ('a', 'seald') -> {'seald': 1}
# ('seald', 'compact') -> {'compact': 1}
# ('compact', 'well') -> {'well': 1}
# ('well', 'ratified') -> {'ratified': 1}
# ('ratified', 'by') -> {'by': 1}
# ('by', 'law') -> {'law': 1}
# ('law', 'and') -> {'and': 1}
# ('and', 'heraldrie') -> {'heraldrie': 1}
# ('heraldrie', 'did') -> {'did': 1}
# ('did', 'forfeite') -> {'forfeite': 1}
# ('forfeite', 'with') -> {'with': 1}
# ('with', 'his') -> {'his': 14}
# ('his', 'life') -> {'life': 3}
# ('life', 'all') -> {'all': 1}
# ('all', 'those') -> {'those': 1}
# ('those', 'his') -> {'his': 1}
# ('his', 'lands') -> {'lands': 2}
# ('lands', 'which') -> {'which': 1}
# ('which', 'he') -> {'he': 5}
# ('he', 'stood') -> {'stood': 1}
# ('stood', 'seizd') -> {'seizd': 1}
# ('seizd', 'on') -> {'on': 1}
# ('on', 'to') -> {'to': 5}
# ('the', 'conqueror') -> {'conqueror': 1}
# ('conqueror', 'against') -> {'against': 1}
# ('against', 'the') -> {'the': 8}
# ('the', 'which') -> {'which': 7}
# ('which', 'a') -> {'a': 2}
# ('a', 'moity') -> {'moity': 1}
# ('moity', 'competent') -> {'competent': 1}
# ('competent', 'was') -> {'was': 1}
# ('was', 'gaged') -> {'gaged': 1}
# ('gaged', 'by') -> {'by': 1}
# ('our', 'king') -> {'king': 1}
# ('king', 'which') -> {'which': 1}
# ('which', 'had') -> {'had': 1}
# ('had', 'returnd') -> {'returnd': 1}
# ('returnd', 'to') -> {'to': 1}
# ('the', 'inheritance') -> {'inheritance': 1}
# ('inheritance', 'of') -> {'of': 1}
# ('of', 'fortinbras') -> {'fortinbras': 1}
# ('fortinbras', 'had') -> {'had': 1}
# ('had', 'he') -> {'he': 6}
# ('he', 'bin') -> {'bin': 1}
# ('bin', 'vanquisher') -> {'vanquisher': 1}
# ('vanquisher', 'as') -> {'as': 1}
# ('as', 'by') -> {'by': 3}
# ('by', 'the') -> {'the': 14}
# ('same', 'counant') -> {'counant': 1}
# ('counant', 'and') -> {'and': 1}
# ('and', 'carriage') -> {'carriage': 1}
# ('carriage', 'of') -> {'of': 1}
# ('the', 'article') -> {'article': 1}
# ('article', 'designe') -> {'designe': 1}
# ('designe', 'his') -> {'his': 1}
# ('his', 'fell') -> {'fell': 2}
# ('fell', 'to') -> {'to': 1}
# ('to', 'hamlet') -> {'hamlet': 2}
# ('hamlet', 'now') -> {'now': 1}
# ('now', 'sir') -> {'sir': 1}
# ('sir', 'young') -> {'young': 1}
# ('young', 'fortinbras') -> {'fortinbras': 3}
# ('of', 'vnimproued') -> {'vnimproued': 1}
# ('vnimproued', 'mettle') -> {'mettle': 1}
# ('mettle', 'hot') -> {'hot': 1}
# ('hot', 'and') -> {'and': 2}
# ('and', 'full') -> {'full': 2}
# ('full', 'hath') -> {'hath': 1}
# ('hath', 'in') -> {'in': 1}
# ('the', 'skirts') -> {'skirts': 1}
# ('skirts', 'of') -> {'of': 1}
# ('norway', 'heere') -> {'heere': 1}
# ('heere', 'and') -> {'and': 3}
# ('and', 'there') -> {'there': 8}
# ('there', 'sharkd') -> {'sharkd': 1}
# ('sharkd', 'vp') -> {'vp': 1}
# ('vp', 'a') -> {'a': 2}
# ('a', 'list') -> {'list': 1}
# ('list', 'of') -> {'of': 1}
# ('of', 'landlesse') -> {'landlesse': 1}
# ('landlesse', 'resolutes') -> {'resolutes': 1}
# ('resolutes', 'for') -> {'for': 1}
# ('for', 'foode') -> {'foode': 1}
# ('foode', 'and') -> {'and': 1}
# ('and', 'diet') -> {'diet': 1}
# ('diet', 'to') -> {'to': 1}
# ('to', 'some') -> {'some': 3}
# ('some', 'enterprize') -> {'enterprize': 1}
# ('enterprize', 'that') -> {'that': 1}
# ('that', 'hath') -> {'hath': 3}
# ('hath', 'a') -> {'a': 1}
# ('a', 'stomacke') -> {'stomacke': 1}
# ('stomacke', 'int') -> {'int': 1}
# ('int', 'which') -> {'which': 1}
# ('which', 'is') -> {'is': 3}
# ('is', 'no') -> {'no': 7}
# ('no', 'other') -> {'other': 4}
# ('other', 'and') -> {'and': 2}
# ('and', 'it') -> {'it': 5}
# ('it', 'doth') -> {'doth': 4}
# ('doth', 'well') -> {'well': 1}
# ('well', 'appeare') -> {'appeare': 1}
# ('appeare', 'vnto') -> {'vnto': 1}
# ('vnto', 'our') -> {'our': 1}
# ('state', 'but') -> {'but': 1}
# ('but', 'to') -> {'to': 14}
# ('to', 'recouer') -> {'recouer': 2}
# ('recouer', 'of') -> {'of': 1}
# ('vs', 'by') -> {'by': 2}
# ('by', 'strong') -> {'strong': 1}
# ('strong', 'hand') -> {'hand': 1}
# ('hand', 'and') -> {'and': 1}
# ('and', 'termes') -> {'termes': 1}
# ('termes', 'compulsatiue') -> {'compulsatiue': 1}
# ('compulsatiue', 'those') -> {'those': 1}
# ('those', 'foresaid') -> {'foresaid': 1}
# ('foresaid', 'lands') -> {'lands': 1}
# ('lands', 'so') -> {'so': 1}
# ('so', 'by') -> {'by': 3}
# ('by', 'his') -> {'his': 5}
# ('his', 'father') -> {'father': 3}
# ('father', 'lost') -> {'lost': 4}
# ('lost', 'and') -> {'and': 1}
# ('and', 'this') -> {'this': 3}
# ('this', 'i') -> {'i': 2}
# ('i', 'take') -> {'take': 3}
# ('take', 'it') -> {'it': 5}
# ('is', 'the') -> {'the': 27}
# ('the', 'maine') -> {'maine': 3}
# ('maine', 'motiue') -> {'motiue': 1}
# ('motiue', 'of') -> {'of': 1}
# ('our', 'preparations') -> {'preparations': 1}
# ('preparations', 'the') -> {'the': 1}
# ('the', 'sourse') -> {'sourse': 1}
# ('sourse', 'of') -> {'of': 2}
# ('this', 'our') -> {'our': 1}
# ('watch', 'and') -> {'and': 1}
# ('and', 'the') -> {'the': 29}
# ('the', 'cheefe') -> {'cheefe': 1}
# ('cheefe', 'head') -> {'head': 1}
# ('head', 'of') -> {'of': 3}
# ('this', 'posthast') -> {'posthast': 1}
# ('posthast', 'and') -> {'and': 1}
# ('and', 'romage') -> {'romage': 1}
# ('romage', 'in') -> {'in': 1}
# ('land', 'enter') -> {'enter': 1}
# ('enter', 'ghost') -> {'ghost': 4}
# ('ghost', 'againe') -> {'againe': 1}
# ('againe', 'but') -> {'but': 1}
# ('but', 'soft') -> {'soft': 4}
# ('soft', 'behold') -> {'behold': 1}
# ('behold', 'loe') -> {'loe': 1}
# ('loe', 'where') -> {'where': 1}
# ('againe', 'ile') -> {'ile': 2}
# ('ile', 'crosse') -> {'crosse': 1}
# ('crosse', 'it') -> {'it': 1}
# ('it', 'though') -> {'though': 2}
# ('though', 'it') -> {'it': 5}
# ('it', 'blast') -> {'blast': 1}
# ('blast', 'me') -> {'me': 1}
# ('me', 'stay') -> {'stay': 1}
# ('stay', 'illusion') -> {'illusion': 1}
# ('illusion', 'if') -> {'if': 1}
# ('if', 'thou') -> {'thou': 12}
# ('thou', 'hast') -> {'hast': 9}
# ('hast', 'any') -> {'any': 1}
# ('any', 'sound') -> {'sound': 1}
# ('sound', 'or') -> {'or': 1}
# ('or', 'vse') -> {'vse': 1}
# ('vse', 'of') -> {'of': 2}
# ('of', 'voyce') -> {'voyce': 1}
# ('voyce', 'speake') -> {'speake': 1}
# ('to', 'me') -> {'me': 14}
# ('me', 'if') -> {'if': 4}
# ('if', 'there') -> {'there': 2}
# ('there', 'be') -> {'be': 4}
# ('be', 'any') -> {'any': 1}
# ('any', 'good') -> {'good': 1}
# ('good', 'thing') -> {'thing': 1}
# ('thing', 'to') -> {'to': 4}
# ('to', 'be') -> {'be': 29}
# ('be', 'done') -> {'done': 4}
# ('done', 'that') -> {'that': 4}
# ('that', 'may') -> {'may': 2}
# ('may', 'to') -> {'to': 2}
# ('to', 'thee') -> {'thee': 4}
# ('thee', 'do') -> {'do': 1}
# ('do', 'ease') -> {'ease': 1}
# ('ease', 'and') -> {'and': 1}
# ('and', 'grace') -> {'grace': 2}
# ('grace', 'to') -> {'to': 3}
# ('me', 'speak') -> {'speak': 2}
# ('speak', 'to') -> {'to': 1}
# ('art', 'priuy') -> {'priuy': 1}
# ('priuy', 'to') -> {'to': 1}
# ('thy', 'countries') -> {'countries': 1}
# ('countries', 'fate') -> {'fate': 1}
# ('fate', 'which') -> {'which': 1}
# ('which', 'happily') -> {'happily': 1}
# ('happily', 'foreknowing') -> {'foreknowing': 1}
# ('foreknowing', 'may') -> {'may': 1}
# ('may', 'auoyd') -> {'auoyd': 1}
# ('auoyd', 'oh') -> {'oh': 1}
# ('oh', 'speake') -> {'speake': 3}
# ('speake', 'or') -> {'or': 2}
# ('or', 'if') -> {'if': 5}
# ('hast', 'vphoorded') -> {'vphoorded': 1}
# ('vphoorded', 'in') -> {'in': 1}
# ('in', 'thy') -> {'thy': 5}
# ('thy', 'life') -> {'life': 1}
# ('life', 'extorted') -> {'extorted': 1}
# ('extorted', 'treasure') -> {'treasure': 1}
# ('treasure', 'in') -> {'in': 1}
# ('the', 'wombe') -> {'wombe': 1}
# ('wombe', 'of') -> {'of': 1}
# ('of', 'earth') -> {'earth': 2}
# ('earth', 'for') -> {'for': 1}
# ('for', 'which') -> {'which': 2}
# ('which', 'they') -> {'they': 1}
# ('they', 'say') -> {'say': 8}
# ('say', 'you') -> {'you': 10}
# ('you', 'spirits') -> {'spirits': 1}
# ('spirits', 'oft') -> {'oft': 1}
# ('oft', 'walke') -> {'walke': 1}
# ('walke', 'in') -> {'in': 1}
# ('in', 'death') -> {'death': 2}
# ('death', 'speake') -> {'speake': 1}
# ('of', 'it') -> {'it': 17}
# ('it', 'stay') -> {'stay': 1}
# ('stay', 'and') -> {'and': 1}
# ('speake', 'stop') -> {'stop': 1}
# ('stop', 'it') -> {'it': 1}
# ('it', 'marcellus') -> {'marcellus': 1}
# ('mar', 'shall') -> {'shall': 1}
# ('shall', 'i') -> {'i': 7}
# ('i', 'strike') -> {'strike': 1}
# ('strike', 'at') -> {'at': 1}
# ('at', 'it') -> {'it': 3}
# ('it', 'with') -> {'with': 5}
# ('with', 'my') -> {'my': 3}
# ('my', 'partizan') -> {'partizan': 1}
# ('partizan', 'hor') -> {'hor': 1}
# ('hor', 'do') -> {'do': 1}
# ('do', 'if') -> {'if': 1}
# ('if', 'it') -> {'it': 17}
# ('it', 'will') -> {'will': 11}
# ('not', 'stand') -> {'stand': 1}
# ('stand', 'barn') -> {'barn': 1}
# ('barn', 'tis') -> {'tis': 1}
# ('tis', 'heere') -> {'heere': 2}
# ('heere', 'hor') -> {'hor': 1}
# ('hor', 'tis') -> {'tis': 1}
# ('heere', 'mar') -> {'mar': 1}
# ('gone', 'exit') -> {'exit': 1}
# ('exit', 'ghost') -> {'ghost': 1}
# ('ghost', 'we') -> {'we': 1}
# ('we', 'do') -> {'do': 4}
# ('do', 'it') -> {'it': 4}
# ('it', 'wrong') -> {'wrong': 1}
# ('wrong', 'being') -> {'being': 1}
# ('being', 'so') -> {'so': 1}
# ('so', 'maiesticall') -> {'maiesticall': 1}
# ('maiesticall', 'to') -> {'to': 1}
# ('to', 'offer') -> {'offer': 2}
# ('offer', 'it') -> {'it': 1}
# ('it', 'the') -> {'the': 3}
# ('the', 'shew') -> {'shew': 1}
# ('shew', 'of') -> {'of': 3}
# ('of', 'violence') -> {'violence': 1}
# ('violence', 'for') -> {'for': 1}
# ('for', 'it') -> {'it': 4}
# ('is', 'as') -> {'as': 3}
# ('as', 'the') -> {'the': 13}
# ('the', 'ayre') -> {'ayre': 6}
# ('ayre', 'invulnerable') -> {'invulnerable': 1}
# ('invulnerable', 'and') -> {'and': 1}
# ('and', 'our') -> {'our': 7}
# ('our', 'vaine') -> {'vaine': 1}
# ('vaine', 'blowes') -> {'blowes': 1}
# ('blowes', 'malicious') -> {'malicious': 1}
# ('malicious', 'mockery') -> {'mockery': 1}
# ('mockery', 'barn') -> {'barn': 1}
# ('it', 'was') -> {'was': 14}
# ('was', 'about') -> {'about': 2}
# ('about', 'to') -> {'to': 3}
# ('to', 'speake') -> {'speake': 10}
# ('speake', 'when') -> {'when': 1}
# ('when', 'the') -> {'the': 5}
# ('the', 'cocke') -> {'cocke': 3}
# ('cocke', 'crew') -> {'crew': 2}
# ('crew', 'hor') -> {'hor': 1}
# ('hor', 'and') -> {'and': 1}
# ('and', 'then') -> {'then': 5}
# ('then', 'it') -> {'it': 3}
# ('it', 'started') -> {'started': 1}
# ('started', 'like') -> {'like': 1}
# ('like', 'a') -> {'a': 25}
# ('a', 'guilty') -> {'guilty': 1}
# ('guilty', 'thing') -> {'thing': 1}
# ('thing', 'vpon') -> {'vpon': 1}
# ('vpon', 'a') -> {'a': 4}
# ('a', 'fearfull') -> {'fearfull': 1}
# ('fearfull', 'summons') -> {'summons': 1}
# ('summons', 'i') -> {'i': 1}
# ('haue', 'heard') -> {'heard': 6}
# ('heard', 'the') -> {'the': 2}
# ('cocke', 'that') -> {'that': 1}
# ('that', 'is') -> {'is': 11}
# ('the', 'trumpet') -> {'trumpet': 2}
# ('trumpet', 'to') -> {'to': 2}
# ('day', 'doth') -> {'doth': 1}
# ('doth', 'with') -> {'with': 1}
# ('his', 'lofty') -> {'lofty': 1}
# ('lofty', 'and') -> {'and': 1}
# ('and', 'shrillsounding') -> {'shrillsounding': 1}
# ('shrillsounding', 'throate') -> {'throate': 1}
# ('throate', 'awake') -> {'awake': 1}
# ('awake', 'the') -> {'the': 1}
# ('the', 'god') -> {'god': 1}
# ('god', 'of') -> {'of': 1}
# ('of', 'day') -> {'day': 2}
# ('day', 'and') -> {'and': 4}
# ('and', 'at') -> {'at': 3}
# ('at', 'his') -> {'his': 5}
# ('his', 'warning') -> {'warning': 1}
# ('warning', 'whether') -> {'whether': 1}
# ('whether', 'in') -> {'in': 1}
# ('in', 'sea') -> {'sea': 1}
# ('sea', 'or') -> {'or': 1}
# ('or', 'fire') -> {'fire': 1}
# ('fire', 'in') -> {'in': 1}
# ('in', 'earth') -> {'earth': 1}
# ('earth', 'or') -> {'or': 1}
# ('or', 'ayre') -> {'ayre': 1}
# ('ayre', 'th') -> {'th': 1}
# ('th', 'extrauagant') -> {'extrauagant': 1}
# ('extrauagant', 'and') -> {'and': 1}
# ('and', 'erring') -> {'erring': 1}
# ('erring', 'spirit') -> {'spirit': 1}
# ('spirit', 'hyes') -> {'hyes': 1}
# ('hyes', 'to') -> {'to': 1}
# ('to', 'his') -> {'his': 19}
# ('his', 'confine') -> {'confine': 1}
# ('confine', 'and') -> {'and': 1}
# ('and', 'of') -> {'of': 5}
# ('the', 'truth') -> {'truth': 3}
# ('truth', 'heerein') -> {'heerein': 1}
# ('heerein', 'this') -> {'this': 1}
# ('this', 'present') -> {'present': 1}
# ('present', 'obiect') -> {'obiect': 1}
# ('obiect', 'made') -> {'made': 1}
# ('made', 'probation') -> {'probation': 1}
# ('probation', 'mar') -> {'mar': 1}
# ('it', 'faded') -> {'faded': 1}
# ('faded', 'on') -> {'on': 1}
# ('the', 'crowing') -> {'crowing': 1}
# ('crowing', 'of') -> {'of': 1}
# ('cocke', 'some') -> {'some': 1}
# ('some', 'sayes') -> {'sayes': 1}
# ('sayes', 'that') -> {'that': 1}
# ('that', 'euer') -> {'euer': 3}
# ('euer', 'gainst') -> {'gainst': 1}
# ('gainst', 'that') -> {'that': 1}
# ('that', 'season') -> {'season': 1}
# ('season', 'comes') -> {'comes': 1}
# ('comes', 'wherein') -> {'wherein': 1}
# ('wherein', 'our') -> {'our': 1}
# ('our', 'sauiours') -> {'sauiours': 1}
# ('sauiours', 'birch') -> {'birch': 1}
# ('birch', 'is') -> {'is': 1}
# ('is', 'celebrated') -> {'celebrated': 1}
# ('celebrated', 'the') -> {'the': 1}
# ('the', 'bird') -> {'bird': 1}
# ('bird', 'of') -> {'of': 1}
# ('of', 'dawning') -> {'dawning': 1}
# ('dawning', 'singeth') -> {'singeth': 1}
# ('singeth', 'all') -> {'all': 1}
# ('all', 'night') -> {'night': 1}
# ('night', 'long') -> {'long': 1}
# ('long', 'and') -> {'and': 1}
# ('then', 'they') -> {'they': 2}
# ('say', 'no') -> {'no': 1}
# ('no', 'spirit') -> {'spirit': 1}
# ('spirit', 'can') -> {'can': 1}
# ('can', 'walke') -> {'walke': 1}
# ('walke', 'abroad') -> {'abroad': 1}
# ('abroad', 'the') -> {'the': 1}
# ('the', 'nights') -> {'nights': 1}
# ('nights', 'are') -> {'are': 1}
# ('are', 'wholsome') -> {'wholsome': 1}
# ('wholsome', 'then') -> {'then': 1}
# ('then', 'no') -> {'no': 1}
# ('no', 'planets') -> {'planets': 1}
# ('planets', 'strike') -> {'strike': 1}
# ('strike', 'no') -> {'no': 1}
# ('no', 'faiery') -> {'faiery': 1}
# ('faiery', 'talkes') -> {'talkes': 1}
# ('talkes', 'nor') -> {'nor': 1}
# ('nor', 'witch') -> {'witch': 1}
# ('witch', 'hath') -> {'hath': 1}
# ('hath', 'power') -> {'power': 2}
# ('power', 'to') -> {'to': 2}
# ('to', 'charme') -> {'charme': 1}
# ('charme', 'so') -> {'so': 1}
# ('so', 'hallowd') -> {'hallowd': 1}
# ('hallowd', 'and') -> {'and': 1}
# ('and', 'so') -> {'so': 11}
# ('so', 'gracious') -> {'gracious': 1}
# ('gracious', 'is') -> {'is': 1}
# ('the', 'time') -> {'time': 8}
# ('time', 'hor') -> {'hor': 1}
# ('hor', 'so') -> {'so': 2}
# ('so', 'haue') -> {'haue': 2}
# ('haue', 'i') -> {'i': 7}
# ('i', 'heard') -> {'heard': 3}
# ('heard', 'and') -> {'and': 2}
# ('and', 'do') -> {'do': 3}
# ('do', 'in') -> {'in': 1}
# ('in', 'part') -> {'part': 3}
# ('part', 'beleeue') -> {'beleeue': 1}
# ('beleeue', 'it') -> {'it': 5}
# ('it', 'but') -> {'but': 2}
# ('but', 'looke') -> {'looke': 3}
# ('looke', 'the') -> {'the': 1}
# ('the', 'morne') -> {'morne': 2}
# ('morne', 'in') -> {'in': 1}
# ('in', 'russet') -> {'russet': 1}
# ('russet', 'mantle') -> {'mantle': 1}
# ('mantle', 'clad') -> {'clad': 1}
# ('clad', 'walkes') -> {'walkes': 1}
# ('walkes', 'ore') -> {'ore': 1}
# ('ore', 'the') -> {'the': 4}
# ('the', 'dew') -> {'dew': 1}
# ('dew', 'of') -> {'of': 2}
# ('of', 'yon') -> {'yon': 1}
# ('yon', 'high') -> {'high': 1}
# ('high', 'easterne') -> {'easterne': 1}
# ('easterne', 'hill') -> {'hill': 1}
# ('hill', 'breake') -> {'breake': 1}
# ('breake', 'we') -> {'we': 1}
# ('we', 'our') -> {'our': 2}
# ('watch', 'vp') -> {'vp': 1}
# ('vp', 'and') -> {'and': 5}
# ('and', 'by') -> {'by': 10}
# ('by', 'my') -> {'my': 5}
# ('my', 'aduice') -> {'aduice': 2}
# ('aduice', 'let') -> {'let': 1}
# ('vs', 'impart') -> {'impart': 1}
# ('impart', 'what') -> {'what': 1}
# ('we', 'haue') -> {'haue': 14}
# ('seene', 'to') -> {'to': 2}
# ('night', 'vnto') -> {'vnto': 1}
# ('vnto', 'yong') -> {'yong': 1}
# ('yong', 'hamlet') -> {'hamlet': 1}
# ('for', 'vpon') -> {'vpon': 1}
# ('vpon', 'my') -> {'my': 6}
# ('my', 'life') -> {'life': 8}
# ('life', 'this') -> {'this': 1}
# ('this', 'spirit') -> {'spirit': 1}
# ('spirit', 'dumbe') -> {'dumbe': 1}
# ('dumbe', 'to') -> {'to': 1}
# ('vs', 'will') -> {'will': 1}
# ('will', 'speake') -> {'speake': 5}
# ('to', 'him') -> {'him': 13}
# ('him', 'do') -> {'do': 1}
# ('do', 'you') -> {'you': 16}
# ('you', 'consent') -> {'consent': 1}
# ('consent', 'we') -> {'we': 1}
# ('we', 'shall') -> {'shall': 9}
# ('shall', 'acquaint') -> {'acquaint': 1}
# ('acquaint', 'him') -> {'him': 1}
# ('him', 'with') -> {'with': 4}
# ('with', 'it') -> {'it': 4}
# ('it', 'as') -> {'as': 6}
# ('as', 'needfull') -> {'needfull': 1}
# ('needfull', 'in') -> {'in': 1}
# ('in', 'our') -> {'our': 8}
# ('our', 'loues') -> {'loues': 2}
# ('loues', 'fitting') -> {'fitting': 1}
# ('fitting', 'our') -> {'our': 1}
# ('our', 'duty') -> {'duty': 4}
# ('duty', 'mar') -> {'mar': 1}
# ('mar', 'let') -> {'let': 1}
# ('let', 'dot') -> {'dot': 1}
# ('dot', 'i') -> {'i': 1}
# ('i', 'pray') -> {'pray': 16}
# ('pray', 'and') -> {'and': 1}
# ('i', 'this') -> {'this': 2}
# ('this', 'morning') -> {'morning': 1}
# ('morning', 'know') -> {'know': 1}
# ('know', 'where') -> {'where': 1}
# ('where', 'we') -> {'we': 2}
# ('shall', 'finde') -> {'finde': 1}
# ('finde', 'him') -> {'him': 5}
# ('him', 'most') -> {'most': 1}
# ('most', 'conueniently') -> {'conueniently': 1}
# ('conueniently', 'exeunt') -> {'exeunt': 1}
# ('exeunt', 'scena') -> {'scena': 2}
# ('scena', 'secunda') -> {'secunda': 2}
# ('secunda', 'enter') -> {'enter': 2}
# ('enter', 'claudius') -> {'claudius': 1}
# ('claudius', 'king') -> {'king': 1}
# ('king', 'of') -> {'of': 4}
# ('of', 'denmarke') -> {'denmarke': 7}
# ('denmarke', 'gertrude') -> {'gertrude': 1}
# ('gertrude', 'the') -> {'the': 1}
# ('the', 'queene') -> {'queene': 13}
# ('queene', 'hamlet') -> {'hamlet': 1}
# ('hamlet', 'polonius') -> {'polonius': 1}
# ('polonius', 'laertes') -> {'laertes': 1}
# ('laertes', 'and') -> {'and': 4}
# ('and', 'his') -> {'his': 8}
# ('his', 'sister') -> {'sister': 1}
# ('sister', 'ophelia') -> {'ophelia': 1}
# ('ophelia', 'lords') -> {'lords': 1}
# ('lords', 'attendant') -> {'attendant': 3}
# ('attendant', 'king') -> {'king': 1}
# ('king', 'though') -> {'though': 1}
# ('though', 'yet') -> {'yet': 1}
# ('yet', 'of') -> {'of': 1}
# ('hamlet', 'our') -> {'our': 1}
# ('our', 'deere') -> {'deere': 1}
# ('deere', 'brothers') -> {'brothers': 2}
# ('brothers', 'death') -> {'death': 2}
# ('death', 'the') -> {'the': 2}
# ('the', 'memory') -> {'memory': 1}
# ('memory', 'be') -> {'be': 1}
# ('be', 'greene') -> {'greene': 1}
# ('greene', 'and') -> {'and': 1}
# ('and', 'that') -> {'that': 15}
# ('that', 'it') -> {'it': 10}
# ('it', 'vs') -> {'vs': 1}
# ('vs', 'befitted') -> {'befitted': 1}
# ('befitted', 'to') -> {'to': 1}
# ('to', 'beare') -> {'beare': 3}
# ('beare', 'our') -> {'our': 1}
# ('our', 'hearts') -> {'hearts': 2}
# ('hearts', 'in') -> {'in': 1}
# ('in', 'greefe') -> {'greefe': 2}
# ('greefe', 'and') -> {'and': 1}
# ('our', 'whole') -> {'whole': 1}
# ('whole', 'kingdome') -> {'kingdome': 1}
# ('kingdome', 'to') -> {'to': 2}
# ('be', 'contracted') -> {'contracted': 1}
# ('contracted', 'in') -> {'in': 1}
# ('in', 'one') -> {'one': 2}
# ('one', 'brow') -> {'brow': 1}
# ('brow', 'of') -> {'of': 2}
# ('of', 'woe') -> {'woe': 3}
# ('woe', 'yet') -> {'yet': 1}
# ('yet', 'so') -> {'so': 1}
# ('so', 'farre') -> {'farre': 6}
# ('farre', 'hath') -> {'hath': 1}
# ('hath', 'discretion') -> {'discretion': 1}
# ('discretion', 'fought') -> {'fought': 1}
# ('fought', 'with') -> {'with': 1}
# ('with', 'nature') -> {'nature': 1}
# ('nature', 'that') -> {'that': 1}
# ('that', 'we') -> {'we': 12}
# ('we', 'with') -> {'with': 1}
# ('with', 'wisest') -> {'wisest': 1}
# ('wisest', 'sorrow') -> {'sorrow': 1}
# ('sorrow', 'thinke') -> {'thinke': 1}
# ('thinke', 'on') -> {'on': 1}
# ('on', 'him') -> {'him': 9}
# ('him', 'together') -> {'together': 1}
# ('with', 'remembrance') -> {'remembrance': 1}
# ('remembrance', 'of') -> {'of': 1}
# ('our', 'selues') -> {'selues': 12}
# ('selues', 'therefore') -> {'therefore': 1}
# ('therefore', 'our') -> {'our': 1}
# ('our', 'sometimes') -> {'sometimes': 1}
# ('sometimes', 'sister') -> {'sister': 1}
# ('sister', 'now') -> {'now': 1}
# ('now', 'our') -> {'our': 1}
# ('our', 'queene') -> {'queene': 1}
# ('queene', 'th') -> {'th': 1}
# ('th', 'imperiall') -> {'imperiall': 1}
# ('imperiall', 'ioyntresse') -> {'ioyntresse': 1}
# ('ioyntresse', 'of') -> {'of': 1}
# ('this', 'warlike') -> {'warlike': 2}
# ('warlike', 'state') -> {'state': 1}
# ('state', 'haue') -> {'haue': 1}
# ('haue', 'we') -> {'we': 2}
# ('we', 'as') -> {'as': 1}
# ('as', 'twere') -> {'twere': 6}
# ('twere', 'with') -> {'with': 1}
# ('with', 'a') -> {'a': 14}
# ('a', 'defeated') -> {'defeated': 1}
# ('defeated', 'ioy') -> {'ioy': 1}
# ('ioy', 'with') -> {'with': 1}
# ('with', 'one') -> {'one': 1}
# ('one', 'auspicious') -> {'auspicious': 1}
# ('auspicious', 'and') -> {'and': 1}
# ('and', 'one') -> {'one': 1}
# ('one', 'dropping') -> {'dropping': 1}
# ('dropping', 'eye') -> {'eye': 1}
# ('eye', 'with') -> {'with': 1}
# ('with', 'mirth') -> {'mirth': 1}
# ('mirth', 'in') -> {'in': 1}
# ('in', 'funerall') -> {'funerall': 1}
# ('funerall', 'and') -> {'and': 1}
# ('and', 'with') -> {'with': 15}
# ('with', 'dirge') -> {'dirge': 1}
# ('dirge', 'in') -> {'in': 1}
# ('in', 'marriage') -> {'marriage': 2}
# ('marriage', 'in') -> {'in': 1}
# ('in', 'equall') -> {'equall': 1}
# ('equall', 'scale') -> {'scale': 1}
# ('scale', 'weighing') -> {'weighing': 1}
# ('weighing', 'delight') -> {'delight': 1}
# ('delight', 'and') -> {'and': 1}
# ('and', 'dole') -> {'dole': 1}
# ('dole', 'taken') -> {'taken': 1}
# ('taken', 'to') -> {'to': 1}
# ('to', 'wife') -> {'wife': 1}
# ('wife', 'nor') -> {'nor': 1}
# ('nor', 'haue') -> {'haue': 1}
# ('we', 'heerein') -> {'heerein': 1}
# ('heerein', 'barrd') -> {'barrd': 1}
# ('barrd', 'your') -> {'your': 1}
# ('your', 'better') -> {'better': 1}
# ('better', 'wisedomes') -> {'wisedomes': 1}
# ('wisedomes', 'which') -> {'which': 1}
# ('which', 'haue') -> {'haue': 2}
# ('haue', 'freely') -> {'freely': 1}
# ('freely', 'gone') -> {'gone': 1}
# ('gone', 'with') -> {'with': 1}
# ('with', 'this') -> {'this': 9}
# ('this', 'affaire') -> {'affaire': 1}
# ('affaire', 'along') -> {'along': 1}
# ('along', 'for') -> {'for': 1}
# ('for', 'all') -> {'all': 3}
# ('all', 'our') -> {'our': 4}
# ('our', 'thankes') -> {'thankes': 2}
# ('thankes', 'now') -> {'now': 1}
# ('now', 'followes') -> {'followes': 1}
# ('followes', 'that') -> {'that': 1}
# ('that', 'you') -> {'you': 13}
# ('know', 'young') -> {'young': 1}
# ('fortinbras', 'holding') -> {'holding': 1}
# ('holding', 'a') -> {'a': 1}
# ('a', 'weake') -> {'weake': 1}
# ('weake', 'supposall') -> {'supposall': 1}
# ('supposall', 'of') -> {'of': 1}
# ('our', 'worth') -> {'worth': 1}
# ('worth', 'or') -> {'or': 1}
# ('or', 'thinking') -> {'thinking': 1}
# ('thinking', 'by') -> {'by': 1}
# ('our', 'late') -> {'late': 1}
# ('late', 'deere') -> {'deere': 1}
# ('death', 'our') -> {'our': 1}
# ('state', 'to') -> {'to': 1}
# ('be', 'disioynt') -> {'disioynt': 1}
# ('disioynt', 'and') -> {'and': 1}
# ('and', 'out') -> {'out': 2}
# ('out', 'of') -> {'of': 16}
# ('of', 'frame') -> {'frame': 1}
# ('frame', 'colleagued') -> {'colleagued': 1}
# ('colleagued', 'with') -> {'with': 1}
# ('the', 'dreame') -> {'dreame': 1}
# ('dreame', 'of') -> {'of': 2}
# ('of', 'his') -> {'his': 34}
# ('his', 'aduantage') -> {'aduantage': 1}
# ('aduantage', 'he') -> {'he': 1}
# ('he', 'hath') -> {'hath': 12}
# ('hath', 'not') -> {'not': 1}
# ('not', 'fayld') -> {'fayld': 1}
# ('fayld', 'to') -> {'to': 1}
# ('to', 'pester') -> {'pester': 1}
# ('pester', 'vs') -> {'vs': 1}
# ('vs', 'with') -> {'with': 1}
# ('with', 'message') -> {'message': 1}
# ('message', 'importing') -> {'importing': 1}
# ('importing', 'the') -> {'the': 1}
# ('the', 'surrender') -> {'surrender': 1}
# ('surrender', 'of') -> {'of': 1}
# ('of', 'those') -> {'those': 2}
# ('those', 'lands') -> {'lands': 1}
# ('lands', 'lost') -> {'lost': 1}
# ('lost', 'by') -> {'by': 1}
# ('father', 'with') -> {'with': 1}
# ('with', 'all') -> {'all': 11}
# ('all', 'bonds') -> {'bonds': 1}
# ('bonds', 'of') -> {'of': 1}
# ('of', 'law') -> {'law': 1}
# ('law', 'to') -> {'to': 1}
# ('our', 'most') -> {'most': 1}
# ('most', 'valiant') -> {'valiant': 1}
# ('valiant', 'brother') -> {'brother': 1}
# ('brother', 'so') -> {'so': 1}
# ('so', 'much') -> {'much': 8}
# ('much', 'for') -> {'for': 2}
# ('for', 'him') -> {'him': 4}
# ('him', 'enter') -> {'enter': 4}
# ('enter', 'voltemand') -> {'voltemand': 1}
# ('voltemand', 'and') -> {'and': 2}
# ('and', 'cornelius') -> {'cornelius': 3}
# ('cornelius', 'now') -> {'now': 1}
# ('now', 'for') -> {'for': 1}
# ('for', 'our') -> {'our': 2}
# ('our', 'selfe') -> {'selfe': 4}
# ('selfe', 'and') -> {'and': 6}
# ('and', 'for') -> {'for': 14}
# ('of', 'meeting') -> {'meeting': 2}
# ('meeting', 'thus') -> {'thus': 1}
# ('thus', 'much') -> {'much': 1}
# ('much', 'the') -> {'the': 1}
# ('the', 'businesse') -> {'businesse': 2}
# ('businesse', 'is') -> {'is': 2}
# ('is', 'we') -> {'we': 1}
# ('haue', 'heere') -> {'heere': 1}
# ('heere', 'writ') -> {'writ': 1}
# ('writ', 'to') -> {'to': 1}
# ('to', 'norway') -> {'norway': 1}
# ('norway', 'vncle') -> {'vncle': 1}
# ('vncle', 'of') -> {'of': 1}
# ('of', 'young') -> {'young': 1}
# ('who', 'impotent') -> {'impotent': 1}
# ('impotent', 'and') -> {'and': 1}
# ('and', 'bedrid') -> {'bedrid': 1}
# ('bedrid', 'scarsely') -> {'scarsely': 1}
# ('scarsely', 'heares') -> {'heares': 1}
# ('heares', 'of') -> {'of': 1}
# ('this', 'his') -> {'his': 1}
# ('his', 'nephewes') -> {'nephewes': 2}
# ('nephewes', 'purpose') -> {'purpose': 1}
# ('purpose', 'to') -> {'to': 1}
# ('to', 'suppresse') -> {'suppresse': 2}
# ('suppresse', 'his') -> {'his': 2}
# ('his', 'further') -> {'further': 1}
# ('further', 'gate') -> {'gate': 1}
# ('gate', 'heerein') -> {'heerein': 1}
# ('heerein', 'in') -> {'in': 1}
# ('in', 'that') -> {'that': 7}
# ('that', 'the') -> {'the': 7}
# ('the', 'leuies') -> {'leuies': 1}
# ('leuies', 'the') -> {'the': 1}
# ('the', 'lists') -> {'lists': 1}
# ('lists', 'and') -> {'and': 1}
# ('full', 'proportions') -> {'proportions': 1}
# ('proportions', 'are') -> {'are': 1}
# ('are', 'all') -> {'all': 3}
# ('all', 'made') -> {'made': 1}
# ('made', 'out') -> {'out': 1}
# ('his', 'subiect') -> {'subiect': 1}
# ('subiect', 'and') -> {'and': 1}
# ('and', 'we') -> {'we': 10}
# ('we', 'heere') -> {'heere': 1}
# ('heere', 'dispatch') -> {'dispatch': 1}
# ('dispatch', 'you') -> {'you': 1}
# ('good', 'cornelius') -> {'cornelius': 1}
# ('cornelius', 'and') -> {'and': 2}
# ('and', 'you') -> {'you': 13}
# ('you', 'voltemand') -> {'voltemand': 1}
# ('voltemand', 'for') -> {'for': 1}
# ('for', 'bearing') -> {'bearing': 1}
# ('bearing', 'of') -> {'of': 1}
# ('this', 'greeting') -> {'greeting': 1}
# ('greeting', 'to') -> {'to': 1}
# ('to', 'old') -> {'old': 1}
# ('old', 'norway') -> {'norway': 1}
# ('norway', 'giuing') -> {'giuing': 1}
# ('giuing', 'to') -> {'to': 1}
# ('to', 'you') -> {'you': 21}
# ('you', 'no') -> {'no': 2}
# ('no', 'further') -> {'further': 3}
# ('further', 'personall') -> {'personall': 1}
# ('personall', 'power') -> {'power': 1}
# ('to', 'businesse') -> {'businesse': 1}
# ('businesse', 'with') -> {'with': 1}
# ('king', 'more') -> {'more': 1}
# ('then', 'the') -> {'the': 9}
# ('the', 'scope') -> {'scope': 1}
# ('of', 'these') -> {'these': 4}
# ('these', 'dilated') -> {'dilated': 1}
# ('dilated', 'articles') -> {'articles': 1}
# ('articles', 'allow') -> {'allow': 1}
# ...
# ('hurts', 'the') -> {'the': 1}
# ('king', 'all') -> {'all': 1}
# ('all', 'treason') -> {'treason': 1}
# ('treason', 'treason') -> {'treason': 1}
# ('treason', 'king') -> {'king': 1}
# ('o', 'yet') -> {'yet': 1}
# ('yet', 'defend') -> {'defend': 1}
# ('defend', 'me') -> {'me': 1}
# ('friends', 'i') -> {'i': 1}
# ('but', 'hurt') -> {'hurt': 1}
# ('hurt', 'ham') -> {'ham': 1}
# ('ham', 'heere') -> {'heere': 1}
# ('heere', 'thou') -> {'thou': 1}
# ('thou', 'incestuous') -> {'incestuous': 1}
# ('incestuous', 'murdrous') -> {'murdrous': 1}
# ('murdrous', 'damned') -> {'damned': 1}
# ('damned', 'dane') -> {'dane': 1}
# ('dane', 'drinke') -> {'drinke': 1}
# ('drinke', 'off') -> {'off': 1}
# ('this', 'potion') -> {'potion': 1}
# ('potion', 'is') -> {'is': 1}
# ('thy', 'vnion') -> {'vnion': 1}
# ('vnion', 'heere') -> {'heere': 1}
# ('heere', 'follow') -> {'follow': 1}
# ('follow', 'my') -> {'my': 1}
# ('king', 'dyes') -> {'dyes': 1}
# ('dyes', 'laer') -> {'laer': 1}
# ('laer', 'he') -> {'he': 1}
# ('is', 'iustly') -> {'iustly': 1}
# ('iustly', 'serud') -> {'serud': 1}
# ('serud', 'it') -> {'it': 1}
# ('a', 'poyson') -> {'poyson': 1}
# ('poyson', 'tempred') -> {'tempred': 1}
# ('tempred', 'by') -> {'by': 1}
# ('by', 'himselfe') -> {'himselfe': 1}
# ('himselfe', 'exchange') -> {'exchange': 1}
# ('exchange', 'forgiuenesse') -> {'forgiuenesse': 1}
# ('forgiuenesse', 'with') -> {'with': 1}
# ('me', 'noble') -> {'noble': 1}
# ('noble', 'hamlet') -> {'hamlet': 1}
# ('hamlet', 'mine') -> {'mine': 1}
# ('death', 'come') -> {'come': 1}
# ('not', 'vpon') -> {'vpon': 1}
# ('vpon', 'thee') -> {'thee': 1}
# ('thee', 'nor') -> {'nor': 1}
# ('nor', 'thine') -> {'thine': 1}
# ('thine', 'on') -> {'on': 1}
# ('me', 'dyes') -> {'dyes': 1}
# ('dyes', 'ham') -> {'ham': 1}
# ('ham', 'heauen') -> {'heauen': 1}
# ('heauen', 'make') -> {'make': 1}
# ('thee', 'free') -> {'free': 1}
# ('free', 'of') -> {'of': 1}
# ('am', 'dead') -> {'dead': 2}
# ('dead', 'horatio') -> {'horatio': 1}
# ('horatio', 'wretched') -> {'wretched': 1}
# ('wretched', 'queene') -> {'queene': 1}
# ('queene', 'adiew') -> {'adiew': 1}
# ('adiew', 'you') -> {'you': 1}
# ('that', 'looke') -> {'looke': 1}
# ('looke', 'pale') -> {'pale': 1}
# ('pale', 'and') -> {'and': 1}
# ('and', 'tremble') -> {'tremble': 1}
# ('tremble', 'at') -> {'at': 1}
# ('this', 'chance') -> {'chance': 1}
# ('chance', 'that') -> {'that': 1}
# ('but', 'mutes') -> {'mutes': 1}
# ('mutes', 'or') -> {'or': 1}
# ('or', 'audience') -> {'audience': 1}
# ('audience', 'to') -> {'to': 1}
# ('this', 'acte') -> {'acte': 1}
# ('acte', 'had') -> {'had': 1}
# ('had', 'i') -> {'i': 1}
# ('but', 'time') -> {'time': 1}
# ('time', 'as') -> {'as': 1}
# ('this', 'fell') -> {'fell': 1}
# ('fell', 'sergeant') -> {'sergeant': 1}
# ('sergeant', 'death') -> {'death': 1}
# ('death', 'is') -> {'is': 1}
# ('is', 'strickd') -> {'strickd': 1}
# ('strickd', 'in') -> {'in': 1}
# ('his', 'arrest') -> {'arrest': 1}
# ('arrest', 'oh') -> {'oh': 1}
# ('could', 'tell') -> {'tell': 1}
# ('horatio', 'i') -> {'i': 1}
# ('dead', 'thou') -> {'thou': 1}
# ('thou', 'liust') -> {'liust': 1}
# ('liust', 'report') -> {'report': 1}
# ('report', 'me') -> {'me': 1}
# ('my', 'causes') -> {'causes': 1}
# ('causes', 'right') -> {'right': 1}
# ('right', 'to') -> {'to': 1}
# ('the', 'vnsatisfied') -> {'vnsatisfied': 1}
# ('vnsatisfied', 'hor') -> {'hor': 1}
# ('hor', 'neuer') -> {'neuer': 1}
# ('neuer', 'beleeue') -> {'beleeue': 1}
# ('am', 'more') -> {'more': 1}
# ('more', 'an') -> {'an': 1}
# ('an', 'antike') -> {'antike': 1}
# ('antike', 'roman') -> {'roman': 1}
# ('roman', 'then') -> {'then': 1}
# ('a', 'dane') -> {'dane': 1}
# ('dane', 'heeres') -> {'heeres': 1}
# ('heeres', 'yet') -> {'yet': 1}
# ('yet', 'some') -> {'some': 1}
# ('some', 'liquor') -> {'liquor': 1}
# ('liquor', 'left') -> {'left': 1}
# ('left', 'ham') -> {'ham': 1}
# ('as', 'thart') -> {'thart': 1}
# ('thart', 'a') -> {'a': 1}
# ('man', 'giue') -> {'giue': 1}
# ('cup', 'let') -> {'let': 1}
# ('let', 'go') -> {'go': 1}
# ('heauen', 'ile') -> {'ile': 1}
# ('ile', 'hauet') -> {'hauet': 1}
# ('hauet', 'oh') -> {'oh': 1}
# ('horatio', 'what') -> {'what': 1}
# ('a', 'wounded') -> {'wounded': 1}
# ('wounded', 'name') -> {'name': 1}
# ('name', 'things') -> {'things': 1}
# ('things', 'standing') -> {'standing': 1}
# ('standing', 'thus') -> {'thus': 1}
# ('thus', 'vnknowne') -> {'vnknowne': 1}
# ('vnknowne', 'shall') -> {'shall': 1}
# ('liue', 'behind') -> {'behind': 1}
# ('behind', 'me') -> {'me': 1}
# ('euer', 'hold') -> {'hold': 1}
# ('hold', 'me') -> {'me': 1}
# ('thy', 'heart') -> {'heart': 1}
# ('heart', 'absent') -> {'absent': 1}
# ('absent', 'thee') -> {'thee': 1}
# ('thee', 'from') -> {'from': 1}
# ('from', 'felicitie') -> {'felicitie': 1}
# ('felicitie', 'awhile') -> {'awhile': 1}
# ('this', 'harsh') -> {'harsh': 1}
# ('harsh', 'world') -> {'world': 1}
# ('world', 'draw') -> {'draw': 1}
# ('draw', 'thy') -> {'thy': 1}
# ('thy', 'breath') -> {'breath': 1}
# ('breath', 'in') -> {'in': 1}
# ('in', 'paine') -> {'paine': 1}
# ('paine', 'to') -> {'to': 1}
# ('tell', 'my') -> {'my': 1}
# ('my', 'storie') -> {'storie': 1}
# ('storie', 'march') -> {'march': 1}
# ('march', 'afarre') -> {'afarre': 1}
# ('afarre', 'off') -> {'off': 1}
# ('and', 'shout') -> {'shout': 1}
# ('shout', 'within') -> {'within': 1}
# ('within', 'what') -> {'what': 1}
# ('what', 'warlike') -> {'warlike': 1}
# ('warlike', 'noyse') -> {'noyse': 1}
# ('this', 'enter') -> {'enter': 1}
# ('enter', 'osricke') -> {'osricke': 1}
# ('osr', 'yong') -> {'yong': 1}
# ('yong', 'fortinbras') -> {'fortinbras': 1}
# ('with', 'conquest') -> {'conquest': 1}
# ('conquest', 'come') -> {'come': 1}
# ('from', 'poland') -> {'poland': 1}
# ('poland', 'to') -> {'to': 1}
# ('ambassadors', 'of') -> {'of': 1}
# ('of', 'england') -> {'england': 1}
# ('england', 'giues') -> {'giues': 1}
# ('giues', 'this') -> {'this': 1}
# ('warlike', 'volly') -> {'volly': 1}
# ('volly', 'ham') -> {'ham': 1}
# ('o', 'i') -> {'i': 1}
# ('i', 'dye') -> {'dye': 1}
# ('dye', 'horatio') -> {'horatio': 1}
# ('the', 'potent') -> {'potent': 1}
# ('potent', 'poyson') -> {'poyson': 1}
# ('poyson', 'quite') -> {'quite': 1}
# ('quite', 'orecrowes') -> {'orecrowes': 1}
# ('orecrowes', 'my') -> {'my': 1}
# ('my', 'spirit') -> {'spirit': 1}
# ('spirit', 'i') -> {'i': 1}
# ('not', 'liue') -> {'liue': 1}
# ('liue', 'to') -> {'to': 1}
# ('newes', 'from') -> {'from': 1}
# ('england', 'but') -> {'but': 1}
# ('do', 'prophesie') -> {'prophesie': 1}
# ('prophesie', 'th') -> {'th': 1}
# ('election', 'lights') -> {'lights': 1}
# ('lights', 'on') -> {'on': 1}
# ('fortinbras', 'he') -> {'he': 1}
# ('my', 'dying') -> {'dying': 1}
# ('dying', 'voyce') -> {'voyce': 1}
# ('voyce', 'so') -> {'so': 1}
# ('so', 'tell') -> {'tell': 1}
# ('the', 'occurrents') -> {'occurrents': 1}
# ('occurrents', 'more') -> {'more': 1}
# ('lesse', 'which') -> {'which': 1}
# ('haue', 'solicited') -> {'solicited': 1}
# ('solicited', 'the') -> {'the': 1}
# ('rest', 'is') -> {'is': 1}
# ('is', 'silence') -> {'silence': 1}
# ('silence', 'o') -> {'o': 1}
# ('o', 'o') -> {'o': 3}
# ('o', 'dyes') -> {'dyes': 1}
# ('dyes', 'hora') -> {'hora': 1}
# ('hora', 'now') -> {'now': 1}
# ('now', 'cracke') -> {'cracke': 1}
# ('cracke', 'a') -> {'a': 1}
# ('noble', 'heart') -> {'heart': 1}
# ('heart', 'goodnight') -> {'goodnight': 1}
# ('sweet', 'prince') -> {'prince': 1}
# ('prince', 'and') -> {'and': 1}
# ('and', 'flights') -> {'flights': 1}
# ('flights', 'of') -> {'of': 1}
# ('of', 'angels') -> {'angels': 1}
# ('angels', 'sing') -> {'sing': 1}
# ('sing', 'thee') -> {'thee': 1}
# ('thy', 'rest') -> {'rest': 1}
# ('rest', 'why') -> {'why': 1}
# ('why', 'dos') -> {'dos': 1}
# ('dos', 'the') -> {'the': 1}
# ('the', 'drumme') -> {'drumme': 1}
# ('drumme', 'come') -> {'come': 1}
# ('hither', 'enter') -> {'enter': 1}
# ('fortinbras', 'and') -> {'and': 1}
# ('and', 'english') -> {'english': 1}
# ('english', 'ambassador') -> {'ambassador': 1}
# ('ambassador', 'with') -> {'with': 1}
# ('with', 'drumme') -> {'drumme': 1}
# ('drumme', 'colours') -> {'colours': 1}
# ('colours', 'and') -> {'and': 1}
# ('and', 'attendants') -> {'attendants': 1}
# ('attendants', 'fortin') -> {'fortin': 1}
# ('fortin', 'where') -> {'where': 1}
# ('sight', 'hor') -> {'hor': 1}
# ('it', 'ye') -> {'ye': 1}
# ('ye', 'would') -> {'would': 1}
# ('would', 'see') -> {'see': 1}
# ('if', 'ought') -> {'ought': 1}
# ('woe', 'or') -> {'or': 1}
# ('or', 'wonder') -> {'wonder': 1}
# ('wonder', 'cease') -> {'cease': 1}
# ('cease', 'your') -> {'your': 1}
# ('your', 'search') -> {'search': 1}
# ('search', 'for') -> {'for': 1}
# ('his', 'quarry') -> {'quarry': 1}
# ('quarry', 'cries') -> {'cries': 1}
# ('cries', 'on') -> {'on': 1}
# ('on', 'hauocke') -> {'hauocke': 1}
# ('hauocke', 'oh') -> {'oh': 1}
# ('oh', 'proud') -> {'proud': 1}
# ('proud', 'death') -> {'death': 1}
# ('what', 'feast') -> {'feast': 1}
# ('feast', 'is') -> {'is': 1}
# ('is', 'toward') -> {'toward': 1}
# ('toward', 'in') -> {'in': 1}
# ('in', 'thine') -> {'thine': 1}
# ('thine', 'eternall') -> {'eternall': 1}
# ('eternall', 'cell') -> {'cell': 1}
# ('cell', 'that') -> {'that': 1}
# ('many', 'princes') -> {'princes': 1}
# ('princes', 'at') -> {'at': 1}
# ('a', 'shoote') -> {'shoote': 1}
# ('shoote', 'so') -> {'so': 1}
# ('so', 'bloodily') -> {'bloodily': 1}
# ('bloodily', 'hast') -> {'hast': 1}
# ('hast', 'strooke') -> {'strooke': 1}
# ('strooke', 'amb') -> {'amb': 1}
# ('amb', 'the') -> {'the': 1}
# ('the', 'sight') -> {'sight': 1}
# ('sight', 'is') -> {'is': 1}
# ('is', 'dismall') -> {'dismall': 1}
# ('dismall', 'and') -> {'and': 1}
# ('our', 'affaires') -> {'affaires': 1}
# ('affaires', 'from') -> {'from': 1}
# ('england', 'come') -> {'come': 1}
# ('come', 'too') -> {'too': 1}
# ('eares', 'are') -> {'are': 1}
# ('are', 'senselesse') -> {'senselesse': 1}
# ('senselesse', 'that') -> {'that': 1}
# ('should', 'giue') -> {'giue': 1}
# ('vs', 'hearing') -> {'hearing': 1}
# ('his', 'commandment') -> {'commandment': 1}
# ('commandment', 'is') -> {'is': 1}
# ('is', 'fulfilld') -> {'fulfilld': 1}
# ('fulfilld', 'that') -> {'that': 1}
# ('that', 'rosincrance') -> {'rosincrance': 1}
# ('guildensterne', 'are') -> {'are': 1}
# ('are', 'dead') -> {'dead': 1}
# ('dead', 'where') -> {'where': 1}
# ('where', 'should') -> {'should': 1}
# ('haue', 'our') -> {'our': 1}
# ('thankes', 'hor') -> {'hor': 1}
# ('his', 'mouth') -> {'mouth': 2}
# ('mouth', 'had') -> {'had': 1}
# ('had', 'it') -> {'it': 1}
# ('it', 'th') -> {'th': 1}
# ('th', 'abilitie') -> {'abilitie': 1}
# ('abilitie', 'of') -> {'of': 1}
# ('to', 'thanke') -> {'thanke': 1}
# ('you', 'he') -> {'he': 1}
# ('gaue', 'commandment') -> {'commandment': 1}
# ('commandment', 'for') -> {'for': 1}
# ('for', 'their') -> {'their': 1}
# ('their', 'death') -> {'death': 1}
# ('death', 'but') -> {'but': 1}
# ('so', 'iumpe') -> {'iumpe': 1}
# ('iumpe', 'vpon') -> {'vpon': 1}
# ('this', 'bloodie') -> {'bloodie': 1}
# ('bloodie', 'question') -> {'question': 1}
# ('question', 'you') -> {'you': 1}
# ('the', 'polake') -> {'polake': 1}
# ('polake', 'warres') -> {'warres': 1}
# ('warres', 'and') -> {'and': 1}
# ('england', 'are') -> {'are': 1}
# ('are', 'heere') -> {'heere': 1}
# ('heere', 'arriued') -> {'arriued': 1}
# ('arriued', 'giue') -> {'giue': 1}
# ('giue', 'order') -> {'order': 1}
# ('order', 'that') -> {'that': 1}
# ('that', 'these') -> {'these': 1}
# ('these', 'bodies') -> {'bodies': 1}
# ('bodies', 'high') -> {'high': 1}
# ('high', 'on') -> {'on': 1}
# ('a', 'stage') -> {'stage': 1}
# ('stage', 'be') -> {'be': 1}
# ('be', 'placed') -> {'placed': 1}
# ('placed', 'to') -> {'to': 1}
# ('me', 'speake') -> {'speake': 1}
# ('th', 'yet') -> {'yet': 1}
# ('yet', 'vnknowing') -> {'vnknowing': 1}
# ('vnknowing', 'world') -> {'world': 1}
# ('world', 'how') -> {'how': 1}
# ('how', 'these') -> {'these': 1}
# ('these', 'things') -> {'things': 1}
# ('things', 'came') -> {'came': 1}
# ('came', 'about') -> {'about': 1}
# ('about', 'so') -> {'so': 1}
# ('you', 'heare') -> {'heare': 1}
# ('of', 'carnall') -> {'carnall': 1}
# ('carnall', 'bloudie') -> {'bloudie': 1}
# ('bloudie', 'and') -> {'and': 1}
# ('vnnaturall', 'acts') -> {'acts': 1}
# ('acts', 'of') -> {'of': 1}
# ('of', 'accidentall') -> {'accidentall': 1}
# ('accidentall', 'iudgements') -> {'iudgements': 1}
# ('iudgements', 'casuall') -> {'casuall': 1}
# ('casuall', 'slaughters') -> {'slaughters': 1}
# ('slaughters', 'of') -> {'of': 1}
# ('of', 'deaths') -> {'deaths': 1}
# ('deaths', 'put') -> {'put': 1}
# ('by', 'cunning') -> {'cunning': 1}
# ('cunning', 'and') -> {'and': 1}
# ('and', 'forcd') -> {'forcd': 1}
# ('forcd', 'cause') -> {'cause': 1}
# ('this', 'vpshot') -> {'vpshot': 1}
# ('vpshot', 'purposes') -> {'purposes': 1}
# ('purposes', 'mistooke') -> {'mistooke': 1}
# ('mistooke', 'falne') -> {'falne': 1}
# ('falne', 'on') -> {'on': 1}
# ('the', 'inuentors') -> {'inuentors': 1}
# ('inuentors', 'head') -> {'head': 1}
# ('head', 'all') -> {'all': 1}
# ('this', 'can') -> {'can': 1}
# ('i', 'truly') -> {'truly': 1}
# ('truly', 'deliuer') -> {'deliuer': 1}
# ('deliuer', 'for') -> {'for': 1}
# ('vs', 'hast') -> {'hast': 1}
# ('hast', 'to') -> {'to': 1}
# ('heare', 'it') -> {'it': 1}
# ('the', 'noblest') -> {'noblest': 1}
# ('noblest', 'to') -> {'to': 1}
# ('the', 'audience') -> {'audience': 1}
# ('audience', 'for') -> {'for': 1}
# ('with', 'sorrow') -> {'sorrow': 1}
# ('sorrow', 'i') -> {'i': 1}
# ('i', 'embrace') -> {'embrace': 1}
# ('embrace', 'my') -> {'my': 1}
# ('my', 'fortune') -> {'fortune': 1}
# ('fortune', 'i') -> {'i': 1}
# ('haue', 'some') -> {'some': 1}
# ('some', 'rites') -> {'rites': 1}
# ('rites', 'of') -> {'of': 2}
# ('of', 'memory') -> {'memory': 1}
# ('memory', 'in') -> {'in': 1}
# ('this', 'kingdome') -> {'kingdome': 1}
# ('kingdome', 'which') -> {'which': 1}
# ('to', 'claime') -> {'claime': 1}
# ('claime', 'my') -> {'my': 1}
# ('my', 'vantage') -> {'vantage': 1}
# ('vantage', 'doth') -> {'doth': 1}
# ('doth', 'inuite') -> {'inuite': 1}
# ('inuite', 'me') -> {'me': 1}
# ('hor', 'of') -> {'of': 1}
# ('haue', 'alwayes') -> {'alwayes': 1}
# ('alwayes', 'cause') -> {'cause': 1}
# ('cause', 'to') -> {'to': 1}
# ('speake', 'and') -> {'and': 1}
# ('mouth', 'whose') -> {'whose': 1}
# ('whose', 'voyce') -> {'voyce': 1}
# ('voyce', 'will') -> {'will': 1}
# ('draw', 'on') -> {'on': 1}
# ('on', 'more') -> {'more': 1}
# ('same', 'be') -> {'be': 1}
# ('be', 'presently') -> {'presently': 1}
# ('presently', 'performd') -> {'performd': 1}
# ('performd', 'euen') -> {'euen': 1}
# ('euen', 'whiles') -> {'whiles': 1}
# ('whiles', 'mens') -> {'mens': 1}
# ('mens', 'mindes') -> {'mindes': 1}
# ('mindes', 'are') -> {'are': 1}
# ('are', 'wilde') -> {'wilde': 1}
# ('wilde', 'lest') -> {'lest': 1}
# ('lest', 'more') -> {'more': 1}
# ('more', 'mischance') -> {'mischance': 1}
# ('mischance', 'on') -> {'on': 1}
# ('on', 'plots') -> {'plots': 1}
# ('plots', 'and') -> {'and': 1}
# ('and', 'errors') -> {'errors': 1}
# ('errors', 'happen') -> {'happen': 1}
# ('happen', 'for') -> {'for': 1}
# ('let', 'foure') -> {'foure': 1}
# ('foure', 'captaines') -> {'captaines': 1}
# ('captaines', 'beare') -> {'beare': 1}
# ('beare', 'hamlet') -> {'hamlet': 1}
# ('hamlet', 'like') -> {'like': 1}
# ('a', 'soldier') -> {'soldier': 1}
# ('soldier', 'to') -> {'to': 1}
# ('stage', 'for') -> {'for': 1}
# ('for', 'he') -> {'he': 1}
# ('was', 'likely') -> {'likely': 1}
# ('likely', 'had') -> {'had': 1}
# ('beene', 'put') -> {'put': 1}
# ('haue', 'proud') -> {'proud': 1}
# ('proud', 'most') -> {'most': 1}
# ('most', 'royally') -> {'royally': 1}
# ('royally', 'and') -> {'and': 1}
# ('passage', 'the') -> {'the': 1}
# ('the', 'souldiours') -> {'souldiours': 1}
# ('souldiours', 'musicke') -> {'musicke': 1}
# ('musicke', 'and') -> {'and': 1}
# ('the', 'rites') -> {'rites': 1}
# ('warre', 'speake') -> {'speake': 1}
# ('speake', 'lowdly') -> {'lowdly': 1}
# ('lowdly', 'for') -> {'for': 1}
# ('take', 'vp') -> {'vp': 1}
# ('body', 'such') -> {'such': 1}
# ('sight', 'as') -> {'as': 1}
# ('this', 'becomes') -> {'becomes': 1}
# ('becomes', 'the') -> {'the': 1}
# ('the', 'field') -> {'field': 1}
# ('field', 'but') -> {'but': 1}
# ('but', 'heere') -> {'heere': 1}
# ('heere', 'shewes') -> {'shewes': 1}
# ('shewes', 'much') -> {'much': 1}
# ('much', 'amis') -> {'amis': 1}
# ('amis', 'go') -> {'go': 1}
# ('go', 'bid') -> {'bid': 1}
# ('the', 'souldiers') -> {'souldiers': 1}
# ('souldiers', 'shoote') -> {'shoote': 1}
# ('shoote', 'exeunt') -> {'exeunt': 1}
# ('exeunt', 'marching') -> {'marching': 1}
# ('marching', 'after') -> {'after': 1}
# ('a', 'peale') -> {'peale': 1}
# ('peale', 'of') -> {'of': 1}
# ('of', 'ordenance') -> {'ordenance': 1}
# ('ordenance', 'are') -> {'are': 1}
# ('are', 'shot') -> {'shot': 1}
# ('shot', 'off') -> {'off': 1}
# ('off', 'finis') -> {'finis': 1}
# ('finis', 'the') -> {'the': 1}
# ('hamlet', 'prince') -> {'prince': 1}
# ('prince', 'of') -> {'of': 1}

# %% [markdown]
# # Task 2

# %%
#initialize the dictionary to store probabilities
from_bigram_to_next_token_probs = defaultdict(lambda: defaultdict(float))

# Loop through the bigram counts to calculate the probabilities
for bigram, next_tokens in from_bigram_to_next_token_counts.items():
    total_count = sum(next_tokens.values())  #total count this bigram happens
    for next_token, count in next_tokens.items():
        #calculate the probability for each next_token given the bigram
        from_bigram_to_next_token_probs[bigram][next_token] = count / total_count

#print the probabilities
for bigram, next_tokens in from_bigram_to_next_token_probs.items():
    print(f"{bigram} -> {dict(next_tokens)}")
# Out:
# ('the', 'tragedie') -> {'tragedie': 1.0}
# ('tragedie', 'of') -> {'of': 1.0}
# ('of', 'hamlet') -> {'hamlet': 1.0}
# ('hamlet', 'by') -> {'by': 1.0}
# ('by', 'william') -> {'william': 1.0}
# ('william', 'shakespeare') -> {'shakespeare': 1.0}
# ('shakespeare', '1599') -> {'1599': 1.0}
# ('1599', 'actus') -> {'actus': 1.0}
# ('actus', 'primus') -> {'primus': 1.0}
# ('primus', 'scoena') -> {'scoena': 1.0}
# ('scoena', 'prima') -> {'prima': 1.0}
# ('prima', 'enter') -> {'enter': 1.0}
# ('enter', 'barnardo') -> {'barnardo': 1.0}
# ('barnardo', 'and') -> {'and': 1.0}
# ('and', 'francisco') -> {'francisco': 1.0}
# ('francisco', 'two') -> {'two': 1.0}
# ('two', 'centinels') -> {'centinels': 1.0}
# ('centinels', 'barnardo') -> {'barnardo': 1.0}
# ('barnardo', 'who') -> {'who': 1.0}
# ('who', 's') -> {'s': 1.0}
# ('s', 'there') -> {'there': 1.0}
# ('there', 'fran') -> {'fran': 1.0}
# ('fran', 'nay') -> {'nay': 1.0}
# ('nay', 'answer') -> {'answer': 1.0}
# ('answer', 'me') -> {'me': 1.0}
# ('me', 'stand') -> {'stand': 1.0}
# ('stand', 'vnfold') -> {'vnfold': 1.0}
# ('vnfold', 'your') -> {'your': 1.0}
# ('your', 'selfe') -> {'selfe': 1.0}
# ('selfe', 'bar') -> {'bar': 1.0}
# ('bar', 'long') -> {'long': 1.0}
# ('long', 'liue') -> {'liue': 1.0}
# ('liue', 'the') -> {'the': 1.0}
# ('the', 'king') -> {'king': 1.0}
# ('king', 'fran') -> {'fran': 1.0}
# ('fran', 'barnardo') -> {'barnardo': 1.0}
# ('barnardo', 'bar') -> {'bar': 1.0}
# ('bar', 'he') -> {'he': 1.0}
# ('he', 'fran') -> {'fran': 1.0}
# ('fran', 'you') -> {'you': 1.0}
# ('you', 'come') -> {'come': 1.0}
# ('come', 'most') -> {'most': 1.0}
# ('most', 'carefully') -> {'carefully': 1.0}
# ('carefully', 'vpon') -> {'vpon': 1.0}
# ('vpon', 'your') -> {'your': 1.0}
# ('your', 'houre') -> {'houre': 1.0}
# ('houre', 'bar') -> {'bar': 1.0}
# ('bar', 'tis') -> {'tis': 1.0}
# ('tis', 'now') -> {'now': 1.0}
# ('now', 'strook') -> {'strook': 1.0}
# ('strook', 'twelue') -> {'twelue': 1.0}
# ('twelue', 'get') -> {'get': 1.0}
# ('get', 'thee') -> {'thee': 1.0}
# ('thee', 'to') -> {'to': 1.0}
# ('to', 'bed') -> {'bed': 1.0}
# ('bed', 'francisco') -> {'francisco': 1.0}
# ('francisco', 'fran') -> {'fran': 1.0}
# ('fran', 'for') -> {'for': 1.0}
# ('for', 'this') -> {'this': 1.0}
# ('this', 'releefe') -> {'releefe': 1.0}
# ('releefe', 'much') -> {'much': 1.0}
# ('much', 'thankes') -> {'thankes': 1.0}
# ('thankes', 'tis') -> {'tis': 1.0}
# ('tis', 'bitter') -> {'bitter': 1.0}
# ('bitter', 'cold') -> {'cold': 1.0}
# ('cold', 'and') -> {'and': 1.0}
# ('and', 'i') -> {'i': 1.0}
# ('i', 'am') -> {'am': 1.0}
# ('am', 'sicke') -> {'sicke': 1.0}
# ('sicke', 'at') -> {'at': 1.0}
# ('at', 'heart') -> {'heart': 1.0}
# ('heart', 'barn') -> {'barn': 1.0}
# ('barn', 'haue') -> {'haue': 1.0}
# ('haue', 'you') -> {'you': 1.0}
# ('you', 'had') -> {'had': 1.0}
# ('had', 'quiet') -> {'quiet': 1.0}
# ('quiet', 'guard') -> {'guard': 1.0}
# ('guard', 'fran') -> {'fran': 1.0}
# ('fran', 'not') -> {'not': 1.0}
# ('not', 'a') -> {'a': 1.0}
# ('a', 'mouse') -> {'mouse': 1.0}
# ('mouse', 'stirring') -> {'stirring': 1.0}
# ('stirring', 'barn') -> {'barn': 1.0}
# ('barn', 'well') -> {'well': 1.0}
# ('well', 'goodnight') -> {'goodnight': 1.0}
# ('goodnight', 'if') -> {'if': 1.0}
# ('if', 'you') -> {'you': 1.0}
# ('you', 'do') -> {'do': 1.0}
# ('do', 'meet') -> {'meet': 1.0}
# ('meet', 'horatio') -> {'horatio': 1.0}
# ('horatio', 'and') -> {'and': 1.0}
# ('and', 'marcellus') -> {'marcellus': 1.0}
# ('marcellus', 'the') -> {'the': 1.0}
# ('the', 'riuals') -> {'riuals': 1.0}
# ('riuals', 'of') -> {'of': 1.0}
# ('of', 'my') -> {'my': 1.0}
# ('my', 'watch') -> {'watch': 1.0}
# ('watch', 'bid') -> {'bid': 1.0}
# ('bid', 'them') -> {'them': 1.0}
# ('them', 'make') -> {'make': 1.0}
# ('make', 'hast') -> {'hast': 1.0}
# ('hast', 'enter') -> {'enter': 1.0}
# ('enter', 'horatio') -> {'horatio': 1.0}
# ('marcellus', 'fran') -> {'fran': 1.0}
# ('fran', 'i') -> {'i': 1.0}
# ('i', 'thinke') -> {'thinke': 1.0}
# ('thinke', 'i') -> {'i': 1.0}
# ('i', 'heare') -> {'heare': 1.0}
# ('heare', 'them') -> {'them': 1.0}
# ('them', 'stand') -> {'stand': 1.0}
# ('stand', 'who') -> {'who': 1.0}
# ('there', 'hor') -> {'hor': 1.0}
# ('hor', 'friends') -> {'friends': 1.0}
# ('friends', 'to') -> {'to': 1.0}
# ('to', 'this') -> {'this': 1.0}
# ('this', 'ground') -> {'ground': 1.0}
# ('ground', 'mar') -> {'mar': 1.0}
# ('mar', 'and') -> {'and': 1.0}
# ('and', 'leigemen') -> {'leigemen': 1.0}
# ('leigemen', 'to') -> {'to': 1.0}
# ('to', 'the') -> {'the': 1.0}
# ('the', 'dane') -> {'dane': 1.0}
# ('dane', 'fran') -> {'fran': 1.0}
# ('fran', 'giue') -> {'giue': 1.0}
# ('giue', 'you') -> {'you': 1.0}
# ('you', 'good') -> {'good': 1.0}
# ('good', 'night') -> {'night': 1.0}
# ('night', 'mar') -> {'mar': 1.0}
# ('mar', 'o') -> {'o': 1.0}
# ('o', 'farwel') -> {'farwel': 1.0}
# ('farwel', 'honest') -> {'honest': 1.0}
# ('honest', 'soldier') -> {'soldier': 1.0}
# ('soldier', 'who') -> {'who': 1.0}
# ('who', 'hath') -> {'hath': 1.0}
# ('hath', 'relieud') -> {'relieud': 1.0}
# ('relieud', 'you') -> {'you': 1.0}
# ('you', 'fra') -> {'fra': 1.0}
# ('fra', 'barnardo') -> {'barnardo': 1.0}
# ('barnardo', 'has') -> {'has': 1.0}
# ('has', 'my') -> {'my': 1.0}
# ('my', 'place') -> {'place': 1.0}
# ('place', 'giue') -> {'giue': 1.0}
# ('you', 'goodnight') -> {'goodnight': 1.0}
# ('goodnight', 'exit') -> {'exit': 1.0}
# ('exit', 'fran') -> {'fran': 1.0}
# ('fran', 'mar') -> {'mar': 1.0}
# ('mar', 'holla') -> {'holla': 1.0}
# ('holla', 'barnardo') -> {'barnardo': 1.0}
# ('bar', 'say') -> {'say': 1.0}
# ('say', 'what') -> {'what': 1.0}
# ('what', 'is') -> {'is': 1.0}
# ('is', 'horatio') -> {'horatio': 1.0}
# ('horatio', 'there') -> {'there': 1.0}
# ('hor', 'a') -> {'a': 1.0}
# ('a', 'peece') -> {'peece': 1.0}
# ('peece', 'of') -> {'of': 1.0}
# ('of', 'him') -> {'him': 1.0}
# ('him', 'bar') -> {'bar': 1.0}
# ('bar', 'welcome') -> {'welcome': 1.0}
# ('welcome', 'horatio') -> {'horatio': 1.0}
# ('horatio', 'welcome') -> {'welcome': 1.0}
# ('welcome', 'good') -> {'good': 1.0}
# ('good', 'marcellus') -> {'marcellus': 1.0}
# ('marcellus', 'mar') -> {'mar': 1.0}
# ('mar', 'what') -> {'what': 1.0}
# ('what', 'has') -> {'has': 1.0}
# ('has', 'this') -> {'this': 1.0}
# ('this', 'thing') -> {'thing': 1.0}
# ('thing', 'appeard') -> {'appeard': 1.0}
# ('appeard', 'againe') -> {'againe': 1.0}
# ('againe', 'to') -> {'to': 1.0}
# ('to', 'night') -> {'night': 1.0}
# ('night', 'bar') -> {'bar': 1.0}
# ('bar', 'i') -> {'i': 1.0}
# ('i', 'haue') -> {'haue': 1.0}
# ('haue', 'seene') -> {'seene': 1.0}
# ('seene', 'nothing') -> {'nothing': 1.0}
# ('nothing', 'mar') -> {'mar': 1.0}
# ('mar', 'horatio') -> {'horatio': 1.0}
# ('horatio', 'saies') -> {'saies': 1.0}
# ('saies', 'tis') -> {'tis': 1.0}
# ('tis', 'but') -> {'but': 1.0}
# ('but', 'our') -> {'our': 1.0}
# ('our', 'fantasie') -> {'fantasie': 1.0}
# ('fantasie', 'and') -> {'and': 1.0}
# ('and', 'will') -> {'will': 1.0}
# ('will', 'not') -> {'not': 1.0}
# ('not', 'let') -> {'let': 1.0}
# ('let', 'beleefe') -> {'beleefe': 1.0}
# ('beleefe', 'take') -> {'take': 1.0}
# ('take', 'hold') -> {'hold': 1.0}
# ('hold', 'of') -> {'of': 1.0}
# ('him', 'touching') -> {'touching': 1.0}
# ('touching', 'this') -> {'this': 1.0}
# ('this', 'dreaded') -> {'dreaded': 1.0}
# ('dreaded', 'sight') -> {'sight': 1.0}
# ('sight', 'twice') -> {'twice': 1.0}
# ('twice', 'seene') -> {'seene': 1.0}
# ('seene', 'of') -> {'of': 1.0}
# ('of', 'vs') -> {'vs': 1.0}
# ('vs', 'therefore') -> {'therefore': 1.0}
# ('therefore', 'i') -> {'i': 1.0}
# ('haue', 'intreated') -> {'intreated': 1.0}
# ('intreated', 'him') -> {'him': 1.0}
# ('him', 'along') -> {'along': 1.0}
# ('along', 'with') -> {'with': 1.0}
# ('with', 'vs') -> {'vs': 1.0}
# ('vs', 'to') -> {'to': 1.0}
# ('to', 'watch') -> {'watch': 1.0}
# ('watch', 'the') -> {'the': 1.0}
# ('the', 'minutes') -> {'minutes': 1.0}
# ('minutes', 'of') -> {'of': 1.0}
# ('of', 'this') -> {'this': 1.0}
# ('this', 'night') -> {'night': 1.0}
# ('night', 'that') -> {'that': 1.0}
# ('that', 'if') -> {'if': 1.0}
# ('if', 'againe') -> {'againe': 1.0}
# ('againe', 'this') -> {'this': 1.0}
# ('this', 'apparition') -> {'apparition': 1.0}
# ('apparition', 'come') -> {'come': 1.0}
# ('come', 'he') -> {'he': 1.0}
# ('he', 'may') -> {'may': 1.0}
# ('may', 'approue') -> {'approue': 1.0}
# ('approue', 'our') -> {'our': 1.0}
# ('our', 'eyes') -> {'eyes': 1.0}
# ('eyes', 'and') -> {'and': 1.0}
# ('and', 'speake') -> {'speake': 1.0}
# ('speake', 'to') -> {'to': 1.0}
# ('to', 'it') -> {'it': 1.0}
# ('it', 'hor') -> {'hor': 1.0}
# ('hor', 'tush') -> {'tush': 1.0}
# ('tush', 'tush') -> {'tush': 1.0}
# ('tush', 'twill') -> {'twill': 1.0}
# ('twill', 'not') -> {'not': 1.0}
# ('not', 'appeare') -> {'appeare': 1.0}
# ('appeare', 'bar') -> {'bar': 1.0}
# ('bar', 'sit') -> {'sit': 1.0}
# ('sit', 'downe') -> {'downe': 1.0}
# ('downe', 'awhile') -> {'awhile': 1.0}
# ('awhile', 'and') -> {'and': 1.0}
# ('and', 'let') -> {'let': 1.0}
# ('let', 'vs') -> {'vs': 1.0}
# ('vs', 'once') -> {'once': 1.0}
# ('once', 'againe') -> {'againe': 1.0}
# ('againe', 'assaile') -> {'assaile': 1.0}
# ('assaile', 'your') -> {'your': 1.0}
# ('your', 'eares') -> {'eares': 1.0}
# ('eares', 'that') -> {'that': 1.0}
# ('that', 'are') -> {'are': 1.0}
# ('are', 'so') -> {'so': 1.0}
# ('so', 'fortified') -> {'fortified': 1.0}
# ('fortified', 'against') -> {'against': 1.0}
# ('against', 'our') -> {'our': 1.0}
# ('our', 'story') -> {'story': 1.0}
# ('story', 'what') -> {'what': 1.0}
# ('what', 'we') -> {'we': 1.0}
# ('we', 'two') -> {'two': 1.0}
# ('two', 'nights') -> {'nights': 1.0}
# ('nights', 'haue') -> {'haue': 1.0}
# ('seene', 'hor') -> {'hor': 1.0}
# ('hor', 'well') -> {'well': 1.0}
# ('well', 'sit') -> {'sit': 1.0}
# ('sit', 'we') -> {'we': 1.0}
# ('we', 'downe') -> {'downe': 1.0}
# ('downe', 'and') -> {'and': 1.0}
# ('vs', 'heare') -> {'heare': 1.0}
# ('heare', 'barnardo') -> {'barnardo': 1.0}
# ('barnardo', 'speake') -> {'speake': 1.0}
# ('speake', 'of') -> {'of': 1.0}
# ('this', 'barn') -> {'barn': 1.0}
# ('barn', 'last') -> {'last': 1.0}
# ('last', 'night') -> {'night': 1.0}
# ('night', 'of') -> {'of': 1.0}
# ('of', 'all') -> {'all': 1.0}
# ('all', 'when') -> {'when': 1.0}
# ('when', 'yond') -> {'yond': 1.0}
# ('yond', 'same') -> {'same': 1.0}
# ('same', 'starre') -> {'starre': 1.0}
# ('starre', 'that') -> {'that': 1.0}
# ('that', 's') -> {'s': 1.0}
# ('s', 'westward') -> {'westward': 1.0}
# ('westward', 'from') -> {'from': 1.0}
# ('from', 'the') -> {'the': 1.0}
# ('the', 'pole') -> {'pole': 1.0}
# ('pole', 'had') -> {'had': 1.0}
# ('had', 'made') -> {'made': 1.0}
# ('made', 'his') -> {'his': 1.0}
# ('his', 'course') -> {'course': 1.0}
# ('course', 't') -> {'t': 1.0}
# ('t', 'illume') -> {'illume': 1.0}
# ('illume', 'that') -> {'that': 1.0}
# ('that', 'part') -> {'part': 1.0}
# ('part', 'of') -> {'of': 1.0}
# ('of', 'heauen') -> {'heauen': 1.0}
# ('heauen', 'where') -> {'where': 1.0}
# ('where', 'now') -> {'now': 1.0}
# ('now', 'it') -> {'it': 1.0}
# ('it', 'burnes') -> {'burnes': 1.0}
# ('burnes', 'marcellus') -> {'marcellus': 1.0}
# ('marcellus', 'and') -> {'and': 1.0}
# ('and', 'my') -> {'my': 1.0}
# ('my', 'selfe') -> {'selfe': 1.0}
# ('selfe', 'the') -> {'the': 1.0}
# ('the', 'bell') -> {'bell': 1.0}
# ('bell', 'then') -> {'then': 1.0}
# ('then', 'beating') -> {'beating': 1.0}
# ('beating', 'one') -> {'one': 1.0}
# ('one', 'mar') -> {'mar': 1.0}
# ('mar', 'peace') -> {'peace': 1.0}
# ('peace', 'breake') -> {'breake': 1.0}
# ('breake', 'thee') -> {'thee': 1.0}
# ('thee', 'of') -> {'of': 1.0}
# ('of', 'enter') -> {'enter': 1.0}
# ('enter', 'the') -> {'the': 1.0}
# ('the', 'ghost') -> {'ghost': 1.0}
# ('ghost', 'looke') -> {'looke': 1.0}
# ('looke', 'where') -> {'where': 1.0}
# ('where', 'it') -> {'it': 1.0}
# ('it', 'comes') -> {'comes': 1.0}
# ('comes', 'againe') -> {'againe': 1.0}
# ('againe', 'barn') -> {'barn': 1.0}
# ('barn', 'in') -> {'in': 1.0}
# ('in', 'the') -> {'the': 1.0}
# ('the', 'same') -> {'same': 1.0}
# ('same', 'figure') -> {'figure': 1.0}
# ('figure', 'like') -> {'like': 1.0}
# ('like', 'the') -> {'the': 1.0}
# ('king', 'that') -> {'that': 1.0}
# ('s', 'dead') -> {'dead': 1.0}
# ('dead', 'mar') -> {'mar': 1.0}
# ('mar', 'thou') -> {'thou': 1.0}
# ('thou', 'art') -> {'art': 1.0}
# ('art', 'a') -> {'a': 1.0}
# ('a', 'scholler') -> {'scholler': 1.0}
# ('scholler', 'speake') -> {'speake': 1.0}
# ('it', 'horatio') -> {'horatio': 1.0}
# ('horatio', 'barn') -> {'barn': 1.0}
# ('barn', 'lookes') -> {'lookes': 1.0}
# ('lookes', 'it') -> {'it': 1.0}
# ('it', 'not') -> {'not': 1.0}
# ('not', 'like') -> {'like': 1.0}
# ('king', 'marke') -> {'marke': 1.0}
# ('marke', 'it') -> {'it': 1.0}
# ('horatio', 'hora') -> {'hora': 1.0}
# ('hora', 'most') -> {'most': 1.0}
# ('most', 'like') -> {'like': 1.0}
# ('like', 'it') -> {'it': 1.0}
# ('it', 'harrowes') -> {'harrowes': 1.0}
# ('harrowes', 'me') -> {'me': 1.0}
# ('me', 'with') -> {'with': 1.0}
# ('with', 'fear') -> {'fear': 1.0}
# ('fear', 'wonder') -> {'wonder': 1.0}
# ('wonder', 'barn') -> {'barn': 1.0}
# ('barn', 'it') -> {'it': 1.0}
# ('it', 'would') -> {'would': 1.0}
# ('would', 'be') -> {'be': 1.0}
# ('be', 'spoke') -> {'spoke': 1.0}
# ('spoke', 'too') -> {'too': 1.0}
# ('too', 'mar') -> {'mar': 1.0}
# ('mar', 'question') -> {'question': 1.0}
# ('question', 'it') -> {'it': 1.0}
# ('horatio', 'hor') -> {'hor': 1.0}
# ('hor', 'what') -> {'what': 1.0}
# ('what', 'art') -> {'art': 1.0}
# ('art', 'thou') -> {'thou': 1.0}
# ('thou', 'that') -> {'that': 1.0}
# ('that', 'vsurpst') -> {'vsurpst': 1.0}
# ('vsurpst', 'this') -> {'this': 1.0}
# ('this', 'time') -> {'time': 1.0}
# ('time', 'of') -> {'of': 1.0}
# ('of', 'night') -> {'night': 1.0}
# ('night', 'together') -> {'together': 1.0}
# ('together', 'with') -> {'with': 1.0}
# ('with', 'that') -> {'that': 1.0}
# ('that', 'faire') -> {'faire': 1.0}
# ('faire', 'and') -> {'and': 1.0}
# ('and', 'warlike') -> {'warlike': 1.0}
# ('warlike', 'forme') -> {'forme': 1.0}
# ('forme', 'in') -> {'in': 1.0}
# ('in', 'which') -> {'which': 1.0}
# ('which', 'the') -> {'the': 1.0}
# ('the', 'maiesty') -> {'maiesty': 1.0}
# ('maiesty', 'of') -> {'of': 1.0}
# ('of', 'buried') -> {'buried': 1.0}
# ('buried', 'denmarke') -> {'denmarke': 1.0}
# ('denmarke', 'did') -> {'did': 1.0}
# ('did', 'sometimes') -> {'sometimes': 1.0}
# ('sometimes', 'march') -> {'march': 1.0}
# ('march', 'by') -> {'by': 1.0}
# ('by', 'heauen') -> {'heauen': 1.0}
# ('heauen', 'i') -> {'i': 1.0}
# ('i', 'charge') -> {'charge': 1.0}
# ('charge', 'thee') -> {'thee': 1.0}
# ('thee', 'speake') -> {'speake': 1.0}
# ('speake', 'mar') -> {'mar': 1.0}
# ('mar', 'it') -> {'it': 1.0}
# ('it', 'is') -> {'is': 1.0}
# ('is', 'offended') -> {'offended': 1.0}
# ('offended', 'barn') -> {'barn': 1.0}
# ('barn', 'see') -> {'see': 1.0}
# ('see', 'it') -> {'it': 1.0}
# ('it', 'stalkes') -> {'stalkes': 1.0}
# ('stalkes', 'away') -> {'away': 1.0}
# ('away', 'hor') -> {'hor': 1.0}
# ('hor', 'stay') -> {'stay': 1.0}
# ('stay', 'speake') -> {'speake': 1.0}
# ('speake', 'speake') -> {'speake': 1.0}
# ('speake', 'i') -> {'i': 1.0}
# ('speake', 'exit') -> {'exit': 1.0}
# ('exit', 'the') -> {'the': 1.0}
# ('ghost', 'mar') -> {'mar': 1.0}
# ('mar', 'tis') -> {'tis': 1.0}
# ('tis', 'gone') -> {'gone': 1.0}
# ('gone', 'and') -> {'and': 1.0}
# ('not', 'answer') -> {'answer': 1.0}
# ('answer', 'barn') -> {'barn': 1.0}
# ('barn', 'how') -> {'how': 1.0}
# ('how', 'now') -> {'now': 1.0}
# ('now', 'horatio') -> {'horatio': 1.0}
# ('horatio', 'you') -> {'you': 1.0}
# ('you', 'tremble') -> {'tremble': 1.0}
# ('tremble', 'look') -> {'look': 1.0}
# ('look', 'pale') -> {'pale': 1.0}
# ('pale', 'is') -> {'is': 1.0}
# ('is', 'not') -> {'not': 1.0}
# ('not', 'this') -> {'this': 1.0}
# ('this', 'something') -> {'something': 1.0}
# ('something', 'more') -> {'more': 1.0}
# ('more', 'then') -> {'then': 1.0}
# ('then', 'fantasie') -> {'fantasie': 1.0}
# ('fantasie', 'what') -> {'what': 1.0}
# ('what', 'thinke') -> {'thinke': 1.0}
# ('thinke', 'you') -> {'you': 1.0}
# ('you', 'ont') -> {'ont': 1.0}
# ('ont', 'hor') -> {'hor': 1.0}
# ('hor', 'before') -> {'before': 1.0}
# ('before', 'my') -> {'my': 1.0}
# ('my', 'god') -> {'god': 1.0}
# ('god', 'i') -> {'i': 1.0}
# ('i', 'might') -> {'might': 1.0}
# ('might', 'not') -> {'not': 1.0}
# ('this', 'beleeue') -> {'beleeue': 1.0}
# ('beleeue', 'without') -> {'without': 1.0}
# ('without', 'the') -> {'the': 1.0}
# ('the', 'sensible') -> {'sensible': 1.0}
# ('sensible', 'and') -> {'and': 1.0}
# ('and', 'true') -> {'true': 1.0}
# ('true', 'auouch') -> {'auouch': 1.0}
# ('auouch', 'of') -> {'of': 1.0}
# ('of', 'mine') -> {'mine': 1.0}
# ('mine', 'owne') -> {'owne': 1.0}
# ('owne', 'eyes') -> {'eyes': 1.0}
# ('eyes', 'mar') -> {'mar': 1.0}
# ('mar', 'is') -> {'is': 1.0}
# ('is', 'it') -> {'it': 1.0}
# ('king', 'hor') -> {'hor': 1.0}
# ('hor', 'as') -> {'as': 1.0}
# ('as', 'thou') -> {'thou': 1.0}
# ('art', 'to') -> {'to': 1.0}
# ('to', 'thy') -> {'thy': 1.0}
# ('thy', 'selfe') -> {'selfe': 1.0}
# ('selfe', 'such') -> {'such': 1.0}
# ('such', 'was') -> {'was': 1.0}
# ('was', 'the') -> {'the': 1.0}
# ('the', 'very') -> {'very': 1.0}
# ('very', 'armour') -> {'armour': 1.0}
# ('armour', 'he') -> {'he': 1.0}
# ('he', 'had') -> {'had': 1.0}
# ('had', 'on') -> {'on': 1.0}
# ('on', 'when') -> {'when': 1.0}
# ('when', 'th') -> {'th': 1.0}
# ('th', 'ambitious') -> {'ambitious': 1.0}
# ('ambitious', 'norwey') -> {'norwey': 1.0}
# ('norwey', 'combatted') -> {'combatted': 1.0}
# ('combatted', 'so') -> {'so': 1.0}
# ('so', 'frownd') -> {'frownd': 1.0}
# ('frownd', 'he') -> {'he': 1.0}
# ('he', 'once') -> {'once': 1.0}
# ('once', 'when') -> {'when': 1.0}
# ('when', 'in') -> {'in': 1.0}
# ('in', 'an') -> {'an': 1.0}
# ('an', 'angry') -> {'angry': 1.0}
# ('angry', 'parle') -> {'parle': 1.0}
# ('parle', 'he') -> {'he': 1.0}
# ('he', 'smot') -> {'smot': 1.0}
# ('smot', 'the') -> {'the': 1.0}
# ('the', 'sledded') -> {'sledded': 1.0}
# ('sledded', 'pollax') -> {'pollax': 1.0}
# ('pollax', 'on') -> {'on': 1.0}
# ('on', 'the') -> {'the': 1.0}
# ('the', 'ice') -> {'ice': 1.0}
# ('ice', 'tis') -> {'tis': 1.0}
# ('tis', 'strange') -> {'strange': 1.0}
# ('strange', 'mar') -> {'mar': 1.0}
# ('mar', 'thus') -> {'thus': 1.0}
# ('thus', 'twice') -> {'twice': 1.0}
# ('twice', 'before') -> {'before': 1.0}
# ('before', 'and') -> {'and': 1.0}
# ('and', 'iust') -> {'iust': 1.0}
# ('iust', 'at') -> {'at': 1.0}
# ('at', 'this') -> {'this': 1.0}
# ('this', 'dead') -> {'dead': 1.0}
# ('dead', 'houre') -> {'houre': 1.0}
# ('houre', 'with') -> {'with': 1.0}
# ('with', 'martiall') -> {'martiall': 1.0}
# ('martiall', 'stalke') -> {'stalke': 1.0}
# ('stalke', 'hath') -> {'hath': 1.0}
# ('hath', 'he') -> {'he': 1.0}
# ('he', 'gone') -> {'gone': 1.0}
# ('gone', 'by') -> {'by': 1.0}
# ('by', 'our') -> {'our': 1.0}
# ('our', 'watch') -> {'watch': 1.0}
# ('watch', 'hor') -> {'hor': 1.0}
# ('hor', 'in') -> {'in': 1.0}
# ('in', 'what') -> {'what': 1.0}
# ('what', 'particular') -> {'particular': 1.0}
# ('particular', 'thought') -> {'thought': 1.0}
# ('thought', 'to') -> {'to': 1.0}
# ('to', 'work') -> {'work': 1.0}
# ('work', 'i') -> {'i': 1.0}
# ('i', 'know') -> {'know': 1.0}
# ('know', 'not') -> {'not': 1.0}
# ('not', 'but') -> {'but': 1.0}
# ('but', 'in') -> {'in': 1.0}
# ('the', 'grosse') -> {'grosse': 1.0}
# ('grosse', 'and') -> {'and': 1.0}
# ('and', 'scope') -> {'scope': 1.0}
# ('scope', 'of') -> {'of': 1.0}
# ('my', 'opinion') -> {'opinion': 1.0}
# ('opinion', 'this') -> {'this': 1.0}
# ('this', 'boades') -> {'boades': 1.0}
# ('boades', 'some') -> {'some': 1.0}
# ('some', 'strange') -> {'strange': 1.0}
# ('strange', 'erruption') -> {'erruption': 1.0}
# ('erruption', 'to') -> {'to': 1.0}
# ('to', 'our') -> {'our': 1.0}
# ('our', 'state') -> {'state': 1.0}
# ('state', 'mar') -> {'mar': 1.0}
# ('mar', 'good') -> {'good': 1.0}
# ('good', 'now') -> {'now': 1.0}
# ('now', 'sit') -> {'sit': 1.0}
# ('downe', 'tell') -> {'tell': 1.0}
# ('tell', 'me') -> {'me': 1.0}
# ('me', 'he') -> {'he': 1.0}
# ('he', 'that') -> {'that': 1.0}
# ('that', 'knowes') -> {'knowes': 1.0}
# ('knowes', 'why') -> {'why': 1.0}
# ('why', 'this') -> {'this': 1.0}
# ('this', 'same') -> {'same': 1.0}
# ('same', 'strict') -> {'strict': 1.0}
# ('strict', 'and') -> {'and': 1.0}
# ('and', 'most') -> {'most': 1.0}
# ('most', 'obseruant') -> {'obseruant': 1.0}
# ('obseruant', 'watch') -> {'watch': 1.0}
# ('watch', 'so') -> {'so': 1.0}
# ('so', 'nightly') -> {'nightly': 1.0}
# ('nightly', 'toyles') -> {'toyles': 1.0}
# ('toyles', 'the') -> {'the': 1.0}
# ('the', 'subiect') -> {'subiect': 1.0}
# ('subiect', 'of') -> {'of': 1.0}
# ('of', 'the') -> {'the': 1.0}
# ('the', 'land') -> {'land': 1.0}
# ('land', 'and') -> {'and': 1.0}
# ('and', 'why') -> {'why': 1.0}
# ('why', 'such') -> {'such': 1.0}
# ('such', 'dayly') -> {'dayly': 1.0}
# ('dayly', 'cast') -> {'cast': 1.0}
# ('cast', 'of') -> {'of': 1.0}
# ('of', 'brazon') -> {'brazon': 1.0}
# ('brazon', 'cannon') -> {'cannon': 1.0}
# ('cannon', 'and') -> {'and': 1.0}
# ('and', 'forraigne') -> {'forraigne': 1.0}
# ('forraigne', 'mart') -> {'mart': 1.0}
# ('mart', 'for') -> {'for': 1.0}
# ('for', 'implements') -> {'implements': 1.0}
# ('implements', 'of') -> {'of': 1.0}
# ('of', 'warre') -> {'warre': 1.0}
# ('warre', 'why') -> {'why': 1.0}
# ('such', 'impresse') -> {'impresse': 1.0}
# ('impresse', 'of') -> {'of': 1.0}
# ('of', 'shipwrights') -> {'shipwrights': 1.0}
# ('shipwrights', 'whose') -> {'whose': 1.0}
# ('whose', 'sore') -> {'sore': 1.0}
# ('sore', 'taske') -> {'taske': 1.0}
# ('taske', 'dos') -> {'dos': 1.0}
# ('dos', 'not') -> {'not': 1.0}
# ('not', 'diuide') -> {'diuide': 1.0}
# ('diuide', 'the') -> {'the': 1.0}
# ('the', 'sunday') -> {'sunday': 1.0}
# ('sunday', 'from') -> {'from': 1.0}
# ('the', 'weeke') -> {'weeke': 1.0}
# ('weeke', 'what') -> {'what': 1.0}
# ('what', 'might') -> {'might': 1.0}
# ('might', 'be') -> {'be': 1.0}
# ('be', 'toward') -> {'toward': 1.0}
# ('toward', 'that') -> {'that': 1.0}
# ('that', 'this') -> {'this': 1.0}
# ('this', 'sweaty') -> {'sweaty': 1.0}
# ('sweaty', 'hast') -> {'hast': 1.0}
# ('hast', 'doth') -> {'doth': 1.0}
# ('doth', 'make') -> {'make': 1.0}
# ('make', 'the') -> {'the': 1.0}
# ('the', 'night') -> {'night': 1.0}
# ('night', 'ioyntlabourer') -> {'ioyntlabourer': 1.0}
# ('ioyntlabourer', 'with') -> {'with': 1.0}
# ('with', 'the') -> {'the': 1.0}
# ('the', 'day') -> {'day': 1.0}
# ('day', 'who') -> {'who': 1.0}
# ('who', 'ist') -> {'ist': 1.0}
# ('ist', 'that') -> {'that': 1.0}
# ('that', 'can') -> {'can': 1.0}
# ('can', 'informe') -> {'informe': 1.0}
# ('informe', 'me') -> {'me': 1.0}
# ('me', 'hor') -> {'hor': 1.0}
# ('hor', 'that') -> {'that': 1.0}
# ('can', 'i') -> {'i': 1.0}
# ('i', 'at') -> {'at': 1.0}
# ('at', 'least') -> {'least': 1.0}
# ('least', 'the') -> {'the': 1.0}
# ('the', 'whisper') -> {'whisper': 1.0}
# ('whisper', 'goes') -> {'goes': 1.0}
# ('goes', 'so') -> {'so': 1.0}
# ('so', 'our') -> {'our': 1.0}
# ('our', 'last') -> {'last': 1.0}
# ('last', 'king') -> {'king': 1.0}
# ('king', 'whose') -> {'whose': 1.0}
# ('whose', 'image') -> {'image': 1.0}
# ('image', 'euen') -> {'euen': 1.0}
# ('euen', 'but') -> {'but': 1.0}
# ('but', 'now') -> {'now': 1.0}
# ('now', 'appeard') -> {'appeard': 1.0}
# ('appeard', 'to') -> {'to': 1.0}
# ('to', 'vs') -> {'vs': 1.0}
# ('vs', 'was') -> {'was': 1.0}
# ('was', 'as') -> {'as': 1.0}
# ('as', 'you') -> {'you': 1.0}
# ('you', 'know') -> {'know': 1.0}
# ('know', 'by') -> {'by': 1.0}
# ('by', 'fortinbras') -> {'fortinbras': 1.0}
# ('fortinbras', 'of') -> {'of': 1.0}
# ('of', 'norway') -> {'norway': 1.0}
# ('norway', 'thereto') -> {'thereto': 1.0}
# ('thereto', 'prickd') -> {'prickd': 1.0}
# ('prickd', 'on') -> {'on': 1.0}
# ('on', 'by') -> {'by': 1.0}
# ('by', 'a') -> {'a': 1.0}
# ('a', 'most') -> {'most': 1.0}
# ('most', 'emulate') -> {'emulate': 1.0}
# ('emulate', 'pride') -> {'pride': 1.0}
# ('pride', 'dard') -> {'dard': 1.0}
# ('dard', 'to') -> {'to': 1.0}
# ('the', 'combate') -> {'combate': 1.0}
# ('combate', 'in') -> {'in': 1.0}
# ('which', 'our') -> {'our': 1.0}
# ('our', 'valiant') -> {'valiant': 1.0}
# ('valiant', 'hamlet') -> {'hamlet': 1.0}
# ('hamlet', 'for') -> {'for': 1.0}
# ('for', 'so') -> {'so': 1.0}
# ('so', 'this') -> {'this': 1.0}
# ('this', 'side') -> {'side': 1.0}
# ('side', 'of') -> {'of': 1.0}
# ('of', 'our') -> {'our': 1.0}
# ('our', 'knowne') -> {'knowne': 1.0}
# ('knowne', 'world') -> {'world': 1.0}
# ('world', 'esteemd') -> {'esteemd': 1.0}
# ('esteemd', 'him') -> {'him': 1.0}
# ('him', 'did') -> {'did': 1.0}
# ('did', 'slay') -> {'slay': 1.0}
# ('slay', 'this') -> {'this': 1.0}
# ('this', 'fortinbras') -> {'fortinbras': 1.0}
# ('fortinbras', 'who') -> {'who': 1.0}
# ('who', 'by') -> {'by': 1.0}
# ('a', 'seald') -> {'seald': 1.0}
# ('seald', 'compact') -> {'compact': 1.0}
# ('compact', 'well') -> {'well': 1.0}
# ('well', 'ratified') -> {'ratified': 1.0}
# ('ratified', 'by') -> {'by': 1.0}
# ('by', 'law') -> {'law': 1.0}
# ('law', 'and') -> {'and': 1.0}
# ('and', 'heraldrie') -> {'heraldrie': 1.0}
# ('heraldrie', 'did') -> {'did': 1.0}
# ('did', 'forfeite') -> {'forfeite': 1.0}
# ('forfeite', 'with') -> {'with': 1.0}
# ('with', 'his') -> {'his': 1.0}
# ('his', 'life') -> {'life': 1.0}
# ('life', 'all') -> {'all': 1.0}
# ('all', 'those') -> {'those': 1.0}
# ('those', 'his') -> {'his': 1.0}
# ('his', 'lands') -> {'lands': 1.0}
# ('lands', 'which') -> {'which': 1.0}
# ('which', 'he') -> {'he': 1.0}
# ('he', 'stood') -> {'stood': 1.0}
# ('stood', 'seizd') -> {'seizd': 1.0}
# ('seizd', 'on') -> {'on': 1.0}
# ('on', 'to') -> {'to': 1.0}
# ('the', 'conqueror') -> {'conqueror': 1.0}
# ('conqueror', 'against') -> {'against': 1.0}
# ('against', 'the') -> {'the': 1.0}
# ('the', 'which') -> {'which': 1.0}
# ('which', 'a') -> {'a': 1.0}
# ('a', 'moity') -> {'moity': 1.0}
# ('moity', 'competent') -> {'competent': 1.0}
# ('competent', 'was') -> {'was': 1.0}
# ('was', 'gaged') -> {'gaged': 1.0}
# ('gaged', 'by') -> {'by': 1.0}
# ('our', 'king') -> {'king': 1.0}
# ('king', 'which') -> {'which': 1.0}
# ('which', 'had') -> {'had': 1.0}
# ('had', 'returnd') -> {'returnd': 1.0}
# ('returnd', 'to') -> {'to': 1.0}
# ('the', 'inheritance') -> {'inheritance': 1.0}
# ('inheritance', 'of') -> {'of': 1.0}
# ('of', 'fortinbras') -> {'fortinbras': 1.0}
# ('fortinbras', 'had') -> {'had': 1.0}
# ('had', 'he') -> {'he': 1.0}
# ('he', 'bin') -> {'bin': 1.0}
# ('bin', 'vanquisher') -> {'vanquisher': 1.0}
# ('vanquisher', 'as') -> {'as': 1.0}
# ('as', 'by') -> {'by': 1.0}
# ('by', 'the') -> {'the': 1.0}
# ('same', 'counant') -> {'counant': 1.0}
# ('counant', 'and') -> {'and': 1.0}
# ('and', 'carriage') -> {'carriage': 1.0}
# ('carriage', 'of') -> {'of': 1.0}
# ('the', 'article') -> {'article': 1.0}
# ('article', 'designe') -> {'designe': 1.0}
# ('designe', 'his') -> {'his': 1.0}
# ('his', 'fell') -> {'fell': 1.0}
# ('fell', 'to') -> {'to': 1.0}
# ('to', 'hamlet') -> {'hamlet': 1.0}
# ('hamlet', 'now') -> {'now': 1.0}
# ('now', 'sir') -> {'sir': 1.0}
# ('sir', 'young') -> {'young': 1.0}
# ('young', 'fortinbras') -> {'fortinbras': 1.0}
# ('of', 'vnimproued') -> {'vnimproued': 1.0}
# ('vnimproued', 'mettle') -> {'mettle': 1.0}
# ('mettle', 'hot') -> {'hot': 1.0}
# ('hot', 'and') -> {'and': 1.0}
# ('and', 'full') -> {'full': 1.0}
# ('full', 'hath') -> {'hath': 1.0}
# ('hath', 'in') -> {'in': 1.0}
# ('the', 'skirts') -> {'skirts': 1.0}
# ('skirts', 'of') -> {'of': 1.0}
# ('norway', 'heere') -> {'heere': 1.0}
# ('heere', 'and') -> {'and': 1.0}
# ('and', 'there') -> {'there': 1.0}
# ('there', 'sharkd') -> {'sharkd': 1.0}
# ('sharkd', 'vp') -> {'vp': 1.0}
# ('vp', 'a') -> {'a': 1.0}
# ('a', 'list') -> {'list': 1.0}
# ('list', 'of') -> {'of': 1.0}
# ('of', 'landlesse') -> {'landlesse': 1.0}
# ('landlesse', 'resolutes') -> {'resolutes': 1.0}
# ('resolutes', 'for') -> {'for': 1.0}
# ('for', 'foode') -> {'foode': 1.0}
# ('foode', 'and') -> {'and': 1.0}
# ('and', 'diet') -> {'diet': 1.0}
# ('diet', 'to') -> {'to': 1.0}
# ('to', 'some') -> {'some': 1.0}
# ('some', 'enterprize') -> {'enterprize': 1.0}
# ('enterprize', 'that') -> {'that': 1.0}
# ('that', 'hath') -> {'hath': 1.0}
# ('hath', 'a') -> {'a': 1.0}
# ('a', 'stomacke') -> {'stomacke': 1.0}
# ('stomacke', 'int') -> {'int': 1.0}
# ('int', 'which') -> {'which': 1.0}
# ('which', 'is') -> {'is': 1.0}
# ('is', 'no') -> {'no': 1.0}
# ('no', 'other') -> {'other': 1.0}
# ('other', 'and') -> {'and': 1.0}
# ('and', 'it') -> {'it': 1.0}
# ('it', 'doth') -> {'doth': 1.0}
# ('doth', 'well') -> {'well': 1.0}
# ('well', 'appeare') -> {'appeare': 1.0}
# ('appeare', 'vnto') -> {'vnto': 1.0}
# ('vnto', 'our') -> {'our': 1.0}
# ('state', 'but') -> {'but': 1.0}
# ('but', 'to') -> {'to': 1.0}
# ('to', 'recouer') -> {'recouer': 1.0}
# ('recouer', 'of') -> {'of': 1.0}
# ('vs', 'by') -> {'by': 1.0}
# ('by', 'strong') -> {'strong': 1.0}
# ('strong', 'hand') -> {'hand': 1.0}
# ('hand', 'and') -> {'and': 1.0}
# ('and', 'termes') -> {'termes': 1.0}
# ('termes', 'compulsatiue') -> {'compulsatiue': 1.0}
# ('compulsatiue', 'those') -> {'those': 1.0}
# ('those', 'foresaid') -> {'foresaid': 1.0}
# ('foresaid', 'lands') -> {'lands': 1.0}
# ('lands', 'so') -> {'so': 1.0}
# ('so', 'by') -> {'by': 1.0}
# ('by', 'his') -> {'his': 1.0}
# ('his', 'father') -> {'father': 1.0}
# ('father', 'lost') -> {'lost': 1.0}
# ('lost', 'and') -> {'and': 1.0}
# ('and', 'this') -> {'this': 1.0}
# ('this', 'i') -> {'i': 1.0}
# ('i', 'take') -> {'take': 1.0}
# ('take', 'it') -> {'it': 1.0}
# ('is', 'the') -> {'the': 1.0}
# ('the', 'maine') -> {'maine': 1.0}
# ('maine', 'motiue') -> {'motiue': 1.0}
# ('motiue', 'of') -> {'of': 1.0}
# ('our', 'preparations') -> {'preparations': 1.0}
# ('preparations', 'the') -> {'the': 1.0}
# ('the', 'sourse') -> {'sourse': 1.0}
# ('sourse', 'of') -> {'of': 1.0}
# ('this', 'our') -> {'our': 1.0}
# ('watch', 'and') -> {'and': 1.0}
# ('and', 'the') -> {'the': 1.0}
# ('the', 'cheefe') -> {'cheefe': 1.0}
# ('cheefe', 'head') -> {'head': 1.0}
# ('head', 'of') -> {'of': 1.0}
# ('this', 'posthast') -> {'posthast': 1.0}
# ('posthast', 'and') -> {'and': 1.0}
# ('and', 'romage') -> {'romage': 1.0}
# ('romage', 'in') -> {'in': 1.0}
# ('land', 'enter') -> {'enter': 1.0}
# ('enter', 'ghost') -> {'ghost': 1.0}
# ('ghost', 'againe') -> {'againe': 1.0}
# ('againe', 'but') -> {'but': 1.0}
# ('but', 'soft') -> {'soft': 1.0}
# ('soft', 'behold') -> {'behold': 1.0}
# ('behold', 'loe') -> {'loe': 1.0}
# ('loe', 'where') -> {'where': 1.0}
# ('againe', 'ile') -> {'ile': 1.0}
# ('ile', 'crosse') -> {'crosse': 1.0}
# ('crosse', 'it') -> {'it': 1.0}
# ('it', 'though') -> {'though': 1.0}
# ('though', 'it') -> {'it': 1.0}
# ('it', 'blast') -> {'blast': 1.0}
# ('blast', 'me') -> {'me': 1.0}
# ('me', 'stay') -> {'stay': 1.0}
# ('stay', 'illusion') -> {'illusion': 1.0}
# ('illusion', 'if') -> {'if': 1.0}
# ('if', 'thou') -> {'thou': 1.0}
# ('thou', 'hast') -> {'hast': 1.0}
# ('hast', 'any') -> {'any': 1.0}
# ('any', 'sound') -> {'sound': 1.0}
# ('sound', 'or') -> {'or': 1.0}
# ('or', 'vse') -> {'vse': 1.0}
# ('vse', 'of') -> {'of': 1.0}
# ('of', 'voyce') -> {'voyce': 1.0}
# ('voyce', 'speake') -> {'speake': 1.0}
# ('to', 'me') -> {'me': 1.0}
# ('me', 'if') -> {'if': 1.0}
# ('if', 'there') -> {'there': 1.0}
# ('there', 'be') -> {'be': 1.0}
# ('be', 'any') -> {'any': 1.0}
# ('any', 'good') -> {'good': 1.0}
# ('good', 'thing') -> {'thing': 1.0}
# ('thing', 'to') -> {'to': 1.0}
# ('to', 'be') -> {'be': 1.0}
# ('be', 'done') -> {'done': 1.0}
# ('done', 'that') -> {'that': 1.0}
# ('that', 'may') -> {'may': 1.0}
# ('may', 'to') -> {'to': 1.0}
# ('to', 'thee') -> {'thee': 1.0}
# ('thee', 'do') -> {'do': 1.0}
# ('do', 'ease') -> {'ease': 1.0}
# ('ease', 'and') -> {'and': 1.0}
# ('and', 'grace') -> {'grace': 1.0}
# ('grace', 'to') -> {'to': 1.0}
# ('me', 'speak') -> {'speak': 1.0}
# ('speak', 'to') -> {'to': 1.0}
# ('art', 'priuy') -> {'priuy': 1.0}
# ('priuy', 'to') -> {'to': 1.0}
# ('thy', 'countries') -> {'countries': 1.0}
# ('countries', 'fate') -> {'fate': 1.0}
# ('fate', 'which') -> {'which': 1.0}
# ('which', 'happily') -> {'happily': 1.0}
# ('happily', 'foreknowing') -> {'foreknowing': 1.0}
# ('foreknowing', 'may') -> {'may': 1.0}
# ('may', 'auoyd') -> {'auoyd': 1.0}
# ('auoyd', 'oh') -> {'oh': 1.0}
# ('oh', 'speake') -> {'speake': 1.0}
# ('speake', 'or') -> {'or': 1.0}
# ('or', 'if') -> {'if': 1.0}
# ('hast', 'vphoorded') -> {'vphoorded': 1.0}
# ('vphoorded', 'in') -> {'in': 1.0}
# ('in', 'thy') -> {'thy': 1.0}
# ('thy', 'life') -> {'life': 1.0}
# ('life', 'extorted') -> {'extorted': 1.0}
# ('extorted', 'treasure') -> {'treasure': 1.0}
# ('treasure', 'in') -> {'in': 1.0}
# ('the', 'wombe') -> {'wombe': 1.0}
# ('wombe', 'of') -> {'of': 1.0}
# ('of', 'earth') -> {'earth': 1.0}
# ('earth', 'for') -> {'for': 1.0}
# ('for', 'which') -> {'which': 1.0}
# ('which', 'they') -> {'they': 1.0}
# ('they', 'say') -> {'say': 1.0}
# ('say', 'you') -> {'you': 1.0}
# ('you', 'spirits') -> {'spirits': 1.0}
# ('spirits', 'oft') -> {'oft': 1.0}
# ('oft', 'walke') -> {'walke': 1.0}
# ('walke', 'in') -> {'in': 1.0}
# ('in', 'death') -> {'death': 1.0}
# ('death', 'speake') -> {'speake': 1.0}
# ('of', 'it') -> {'it': 1.0}
# ('it', 'stay') -> {'stay': 1.0}
# ('stay', 'and') -> {'and': 1.0}
# ('speake', 'stop') -> {'stop': 1.0}
# ('stop', 'it') -> {'it': 1.0}
# ('it', 'marcellus') -> {'marcellus': 1.0}
# ('mar', 'shall') -> {'shall': 1.0}
# ('shall', 'i') -> {'i': 1.0}
# ('i', 'strike') -> {'strike': 1.0}
# ('strike', 'at') -> {'at': 1.0}
# ('at', 'it') -> {'it': 1.0}
# ('it', 'with') -> {'with': 1.0}
# ('with', 'my') -> {'my': 1.0}
# ('my', 'partizan') -> {'partizan': 1.0}
# ('partizan', 'hor') -> {'hor': 1.0}
# ('hor', 'do') -> {'do': 1.0}
# ('do', 'if') -> {'if': 1.0}
# ('if', 'it') -> {'it': 1.0}
# ('it', 'will') -> {'will': 1.0}
# ('not', 'stand') -> {'stand': 1.0}
# ('stand', 'barn') -> {'barn': 1.0}
# ('barn', 'tis') -> {'tis': 1.0}
# ('tis', 'heere') -> {'heere': 1.0}
# ('heere', 'hor') -> {'hor': 1.0}
# ('hor', 'tis') -> {'tis': 1.0}
# ('heere', 'mar') -> {'mar': 1.0}
# ('gone', 'exit') -> {'exit': 1.0}
# ('exit', 'ghost') -> {'ghost': 1.0}
# ('ghost', 'we') -> {'we': 1.0}
# ('we', 'do') -> {'do': 1.0}
# ('do', 'it') -> {'it': 1.0}
# ('it', 'wrong') -> {'wrong': 1.0}
# ('wrong', 'being') -> {'being': 1.0}
# ('being', 'so') -> {'so': 1.0}
# ('so', 'maiesticall') -> {'maiesticall': 1.0}
# ('maiesticall', 'to') -> {'to': 1.0}
# ('to', 'offer') -> {'offer': 1.0}
# ('offer', 'it') -> {'it': 1.0}
# ('it', 'the') -> {'the': 1.0}
# ('the', 'shew') -> {'shew': 1.0}
# ('shew', 'of') -> {'of': 1.0}
# ('of', 'violence') -> {'violence': 1.0}
# ('violence', 'for') -> {'for': 1.0}
# ('for', 'it') -> {'it': 1.0}
# ('is', 'as') -> {'as': 1.0}
# ('as', 'the') -> {'the': 1.0}
# ('the', 'ayre') -> {'ayre': 1.0}
# ('ayre', 'invulnerable') -> {'invulnerable': 1.0}
# ('invulnerable', 'and') -> {'and': 1.0}
# ('and', 'our') -> {'our': 1.0}
# ('our', 'vaine') -> {'vaine': 1.0}
# ('vaine', 'blowes') -> {'blowes': 1.0}
# ('blowes', 'malicious') -> {'malicious': 1.0}
# ('malicious', 'mockery') -> {'mockery': 1.0}
# ('mockery', 'barn') -> {'barn': 1.0}
# ('it', 'was') -> {'was': 1.0}
# ('was', 'about') -> {'about': 1.0}
# ('about', 'to') -> {'to': 1.0}
# ('to', 'speake') -> {'speake': 1.0}
# ('speake', 'when') -> {'when': 1.0}
# ('when', 'the') -> {'the': 1.0}
# ('the', 'cocke') -> {'cocke': 1.0}
# ('cocke', 'crew') -> {'crew': 1.0}
# ('crew', 'hor') -> {'hor': 1.0}
# ('hor', 'and') -> {'and': 1.0}
# ('and', 'then') -> {'then': 1.0}
# ('then', 'it') -> {'it': 1.0}
# ('it', 'started') -> {'started': 1.0}
# ('started', 'like') -> {'like': 1.0}
# ('like', 'a') -> {'a': 1.0}
# ('a', 'guilty') -> {'guilty': 1.0}
# ('guilty', 'thing') -> {'thing': 1.0}
# ('thing', 'vpon') -> {'vpon': 1.0}
# ('vpon', 'a') -> {'a': 1.0}
# ('a', 'fearfull') -> {'fearfull': 1.0}
# ('fearfull', 'summons') -> {'summons': 1.0}
# ('summons', 'i') -> {'i': 1.0}
# ('haue', 'heard') -> {'heard': 1.0}
# ('heard', 'the') -> {'the': 1.0}
# ('cocke', 'that') -> {'that': 1.0}
# ('that', 'is') -> {'is': 1.0}
# ('the', 'trumpet') -> {'trumpet': 1.0}
# ('trumpet', 'to') -> {'to': 1.0}
# ('day', 'doth') -> {'doth': 1.0}
# ('doth', 'with') -> {'with': 1.0}
# ('his', 'lofty') -> {'lofty': 1.0}
# ('lofty', 'and') -> {'and': 1.0}
# ('and', 'shrillsounding') -> {'shrillsounding': 1.0}
# ('shrillsounding', 'throate') -> {'throate': 1.0}
# ('throate', 'awake') -> {'awake': 1.0}
# ('awake', 'the') -> {'the': 1.0}
# ('the', 'god') -> {'god': 1.0}
# ('god', 'of') -> {'of': 1.0}
# ('of', 'day') -> {'day': 1.0}
# ('day', 'and') -> {'and': 1.0}
# ('and', 'at') -> {'at': 1.0}
# ('at', 'his') -> {'his': 1.0}
# ('his', 'warning') -> {'warning': 1.0}
# ('warning', 'whether') -> {'whether': 1.0}
# ('whether', 'in') -> {'in': 1.0}
# ('in', 'sea') -> {'sea': 1.0}
# ('sea', 'or') -> {'or': 1.0}
# ('or', 'fire') -> {'fire': 1.0}
# ('fire', 'in') -> {'in': 1.0}
# ('in', 'earth') -> {'earth': 1.0}
# ('earth', 'or') -> {'or': 1.0}
# ('or', 'ayre') -> {'ayre': 1.0}
# ('ayre', 'th') -> {'th': 1.0}
# ('th', 'extrauagant') -> {'extrauagant': 1.0}
# ('extrauagant', 'and') -> {'and': 1.0}
# ('and', 'erring') -> {'erring': 1.0}
# ('erring', 'spirit') -> {'spirit': 1.0}
# ('spirit', 'hyes') -> {'hyes': 1.0}
# ('hyes', 'to') -> {'to': 1.0}
# ('to', 'his') -> {'his': 1.0}
# ('his', 'confine') -> {'confine': 1.0}
# ('confine', 'and') -> {'and': 1.0}
# ('and', 'of') -> {'of': 1.0}
# ('the', 'truth') -> {'truth': 1.0}
# ('truth', 'heerein') -> {'heerein': 1.0}
# ('heerein', 'this') -> {'this': 1.0}
# ('this', 'present') -> {'present': 1.0}
# ('present', 'obiect') -> {'obiect': 1.0}
# ('obiect', 'made') -> {'made': 1.0}
# ('made', 'probation') -> {'probation': 1.0}
# ('probation', 'mar') -> {'mar': 1.0}
# ('it', 'faded') -> {'faded': 1.0}
# ('faded', 'on') -> {'on': 1.0}
# ('the', 'crowing') -> {'crowing': 1.0}
# ('crowing', 'of') -> {'of': 1.0}
# ('cocke', 'some') -> {'some': 1.0}
# ('some', 'sayes') -> {'sayes': 1.0}
# ('sayes', 'that') -> {'that': 1.0}
# ('that', 'euer') -> {'euer': 1.0}
# ('euer', 'gainst') -> {'gainst': 1.0}
# ('gainst', 'that') -> {'that': 1.0}
# ('that', 'season') -> {'season': 1.0}
# ('season', 'comes') -> {'comes': 1.0}
# ('comes', 'wherein') -> {'wherein': 1.0}
# ('wherein', 'our') -> {'our': 1.0}
# ('our', 'sauiours') -> {'sauiours': 1.0}
# ('sauiours', 'birch') -> {'birch': 1.0}
# ('birch', 'is') -> {'is': 1.0}
# ('is', 'celebrated') -> {'celebrated': 1.0}
# ('celebrated', 'the') -> {'the': 1.0}
# ('the', 'bird') -> {'bird': 1.0}
# ('bird', 'of') -> {'of': 1.0}
# ('of', 'dawning') -> {'dawning': 1.0}
# ('dawning', 'singeth') -> {'singeth': 1.0}
# ('singeth', 'all') -> {'all': 1.0}
# ('all', 'night') -> {'night': 1.0}
# ('night', 'long') -> {'long': 1.0}
# ('long', 'and') -> {'and': 1.0}
# ('then', 'they') -> {'they': 1.0}
# ('say', 'no') -> {'no': 1.0}
# ('no', 'spirit') -> {'spirit': 1.0}
# ('spirit', 'can') -> {'can': 1.0}
# ('can', 'walke') -> {'walke': 1.0}
# ('walke', 'abroad') -> {'abroad': 1.0}
# ('abroad', 'the') -> {'the': 1.0}
# ('the', 'nights') -> {'nights': 1.0}
# ('nights', 'are') -> {'are': 1.0}
# ('are', 'wholsome') -> {'wholsome': 1.0}
# ('wholsome', 'then') -> {'then': 1.0}
# ('then', 'no') -> {'no': 1.0}
# ('no', 'planets') -> {'planets': 1.0}
# ('planets', 'strike') -> {'strike': 1.0}
# ('strike', 'no') -> {'no': 1.0}
# ('no', 'faiery') -> {'faiery': 1.0}
# ('faiery', 'talkes') -> {'talkes': 1.0}
# ('talkes', 'nor') -> {'nor': 1.0}
# ('nor', 'witch') -> {'witch': 1.0}
# ('witch', 'hath') -> {'hath': 1.0}
# ('hath', 'power') -> {'power': 1.0}
# ('power', 'to') -> {'to': 1.0}
# ('to', 'charme') -> {'charme': 1.0}
# ('charme', 'so') -> {'so': 1.0}
# ('so', 'hallowd') -> {'hallowd': 1.0}
# ('hallowd', 'and') -> {'and': 1.0}
# ('and', 'so') -> {'so': 1.0}
# ('so', 'gracious') -> {'gracious': 1.0}
# ('gracious', 'is') -> {'is': 1.0}
# ('the', 'time') -> {'time': 1.0}
# ('time', 'hor') -> {'hor': 1.0}
# ('hor', 'so') -> {'so': 1.0}
# ('so', 'haue') -> {'haue': 1.0}
# ('haue', 'i') -> {'i': 1.0}
# ('i', 'heard') -> {'heard': 1.0}
# ('heard', 'and') -> {'and': 1.0}
# ('and', 'do') -> {'do': 1.0}
# ('do', 'in') -> {'in': 1.0}
# ('in', 'part') -> {'part': 1.0}
# ('part', 'beleeue') -> {'beleeue': 1.0}
# ('beleeue', 'it') -> {'it': 1.0}
# ('it', 'but') -> {'but': 1.0}
# ('but', 'looke') -> {'looke': 1.0}
# ('looke', 'the') -> {'the': 1.0}
# ('the', 'morne') -> {'morne': 1.0}
# ('morne', 'in') -> {'in': 1.0}
# ('in', 'russet') -> {'russet': 1.0}
# ('russet', 'mantle') -> {'mantle': 1.0}
# ('mantle', 'clad') -> {'clad': 1.0}
# ('clad', 'walkes') -> {'walkes': 1.0}
# ('walkes', 'ore') -> {'ore': 1.0}
# ('ore', 'the') -> {'the': 1.0}
# ('the', 'dew') -> {'dew': 1.0}
# ('dew', 'of') -> {'of': 1.0}
# ('of', 'yon') -> {'yon': 1.0}
# ('yon', 'high') -> {'high': 1.0}
# ('high', 'easterne') -> {'easterne': 1.0}
# ('easterne', 'hill') -> {'hill': 1.0}
# ('hill', 'breake') -> {'breake': 1.0}
# ('breake', 'we') -> {'we': 1.0}
# ('we', 'our') -> {'our': 1.0}
# ('watch', 'vp') -> {'vp': 1.0}
# ('vp', 'and') -> {'and': 1.0}
# ('and', 'by') -> {'by': 1.0}
# ('by', 'my') -> {'my': 1.0}
# ('my', 'aduice') -> {'aduice': 1.0}
# ('aduice', 'let') -> {'let': 1.0}
# ('vs', 'impart') -> {'impart': 1.0}
# ('impart', 'what') -> {'what': 1.0}
# ('we', 'haue') -> {'haue': 1.0}
# ('seene', 'to') -> {'to': 1.0}
# ('night', 'vnto') -> {'vnto': 1.0}
# ('vnto', 'yong') -> {'yong': 1.0}
# ('yong', 'hamlet') -> {'hamlet': 1.0}
# ('for', 'vpon') -> {'vpon': 1.0}
# ('vpon', 'my') -> {'my': 1.0}
# ('my', 'life') -> {'life': 1.0}
# ('life', 'this') -> {'this': 1.0}
# ('this', 'spirit') -> {'spirit': 1.0}
# ('spirit', 'dumbe') -> {'dumbe': 1.0}
# ('dumbe', 'to') -> {'to': 1.0}
# ('vs', 'will') -> {'will': 1.0}
# ('will', 'speake') -> {'speake': 1.0}
# ('to', 'him') -> {'him': 1.0}
# ('him', 'do') -> {'do': 1.0}
# ('do', 'you') -> {'you': 1.0}
# ('you', 'consent') -> {'consent': 1.0}
# ('consent', 'we') -> {'we': 1.0}
# ('we', 'shall') -> {'shall': 1.0}
# ('shall', 'acquaint') -> {'acquaint': 1.0}
# ('acquaint', 'him') -> {'him': 1.0}
# ('him', 'with') -> {'with': 1.0}
# ('with', 'it') -> {'it': 1.0}
# ('it', 'as') -> {'as': 1.0}
# ('as', 'needfull') -> {'needfull': 1.0}
# ('needfull', 'in') -> {'in': 1.0}
# ('in', 'our') -> {'our': 1.0}
# ('our', 'loues') -> {'loues': 1.0}
# ('loues', 'fitting') -> {'fitting': 1.0}
# ('fitting', 'our') -> {'our': 1.0}
# ('our', 'duty') -> {'duty': 1.0}
# ('duty', 'mar') -> {'mar': 1.0}
# ('mar', 'let') -> {'let': 1.0}
# ('let', 'dot') -> {'dot': 1.0}
# ('dot', 'i') -> {'i': 1.0}
# ('i', 'pray') -> {'pray': 1.0}
# ('pray', 'and') -> {'and': 1.0}
# ('i', 'this') -> {'this': 1.0}
# ('this', 'morning') -> {'morning': 1.0}
# ('morning', 'know') -> {'know': 1.0}
# ('know', 'where') -> {'where': 1.0}
# ('where', 'we') -> {'we': 1.0}
# ('shall', 'finde') -> {'finde': 1.0}
# ('finde', 'him') -> {'him': 1.0}
# ('him', 'most') -> {'most': 1.0}
# ('most', 'conueniently') -> {'conueniently': 1.0}
# ('conueniently', 'exeunt') -> {'exeunt': 1.0}
# ('exeunt', 'scena') -> {'scena': 1.0}
# ('scena', 'secunda') -> {'secunda': 1.0}
# ('secunda', 'enter') -> {'enter': 1.0}
# ('enter', 'claudius') -> {'claudius': 1.0}
# ('claudius', 'king') -> {'king': 1.0}
# ('king', 'of') -> {'of': 1.0}
# ('of', 'denmarke') -> {'denmarke': 1.0}
# ('denmarke', 'gertrude') -> {'gertrude': 1.0}
# ('gertrude', 'the') -> {'the': 1.0}
# ('the', 'queene') -> {'queene': 1.0}
# ('queene', 'hamlet') -> {'hamlet': 1.0}
# ('hamlet', 'polonius') -> {'polonius': 1.0}
# ('polonius', 'laertes') -> {'laertes': 1.0}
# ('laertes', 'and') -> {'and': 1.0}
# ('and', 'his') -> {'his': 1.0}
# ('his', 'sister') -> {'sister': 1.0}
# ('sister', 'ophelia') -> {'ophelia': 1.0}
# ('ophelia', 'lords') -> {'lords': 1.0}
# ('lords', 'attendant') -> {'attendant': 1.0}
# ('attendant', 'king') -> {'king': 1.0}
# ('king', 'though') -> {'though': 1.0}
# ('though', 'yet') -> {'yet': 1.0}
# ('yet', 'of') -> {'of': 1.0}
# ('hamlet', 'our') -> {'our': 1.0}
# ('our', 'deere') -> {'deere': 1.0}
# ('deere', 'brothers') -> {'brothers': 1.0}
# ('brothers', 'death') -> {'death': 1.0}
# ('death', 'the') -> {'the': 1.0}
# ('the', 'memory') -> {'memory': 1.0}
# ('memory', 'be') -> {'be': 1.0}
# ('be', 'greene') -> {'greene': 1.0}
# ('greene', 'and') -> {'and': 1.0}
# ('and', 'that') -> {'that': 1.0}
# ('that', 'it') -> {'it': 1.0}
# ('it', 'vs') -> {'vs': 1.0}
# ('vs', 'befitted') -> {'befitted': 1.0}
# ('befitted', 'to') -> {'to': 1.0}
# ('to', 'beare') -> {'beare': 1.0}
# ('beare', 'our') -> {'our': 1.0}
# ('our', 'hearts') -> {'hearts': 1.0}
# ('hearts', 'in') -> {'in': 1.0}
# ('in', 'greefe') -> {'greefe': 1.0}
# ('greefe', 'and') -> {'and': 1.0}
# ('our', 'whole') -> {'whole': 1.0}
# ('whole', 'kingdome') -> {'kingdome': 1.0}
# ('kingdome', 'to') -> {'to': 1.0}
# ('be', 'contracted') -> {'contracted': 1.0}
# ('contracted', 'in') -> {'in': 1.0}
# ('in', 'one') -> {'one': 1.0}
# ('one', 'brow') -> {'brow': 1.0}
# ('brow', 'of') -> {'of': 1.0}
# ('of', 'woe') -> {'woe': 1.0}
# ('woe', 'yet') -> {'yet': 1.0}
# ('yet', 'so') -> {'so': 1.0}
# ('so', 'farre') -> {'farre': 1.0}
# ('farre', 'hath') -> {'hath': 1.0}
# ('hath', 'discretion') -> {'discretion': 1.0}
# ('discretion', 'fought') -> {'fought': 1.0}
# ('fought', 'with') -> {'with': 1.0}
# ('with', 'nature') -> {'nature': 1.0}
# ('nature', 'that') -> {'that': 1.0}
# ('that', 'we') -> {'we': 1.0}
# ('we', 'with') -> {'with': 1.0}
# ('with', 'wisest') -> {'wisest': 1.0}
# ('wisest', 'sorrow') -> {'sorrow': 1.0}
# ('sorrow', 'thinke') -> {'thinke': 1.0}
# ('thinke', 'on') -> {'on': 1.0}
# ('on', 'him') -> {'him': 1.0}
# ('him', 'together') -> {'together': 1.0}
# ('with', 'remembrance') -> {'remembrance': 1.0}
# ('remembrance', 'of') -> {'of': 1.0}
# ('our', 'selues') -> {'selues': 1.0}
# ('selues', 'therefore') -> {'therefore': 1.0}
# ('therefore', 'our') -> {'our': 1.0}
# ('our', 'sometimes') -> {'sometimes': 1.0}
# ('sometimes', 'sister') -> {'sister': 1.0}
# ('sister', 'now') -> {'now': 1.0}
# ('now', 'our') -> {'our': 1.0}
# ('our', 'queene') -> {'queene': 1.0}
# ('queene', 'th') -> {'th': 1.0}
# ('th', 'imperiall') -> {'imperiall': 1.0}
# ('imperiall', 'ioyntresse') -> {'ioyntresse': 1.0}
# ('ioyntresse', 'of') -> {'of': 1.0}
# ('this', 'warlike') -> {'warlike': 1.0}
# ('warlike', 'state') -> {'state': 1.0}
# ('state', 'haue') -> {'haue': 1.0}
# ('haue', 'we') -> {'we': 1.0}
# ('we', 'as') -> {'as': 1.0}
# ('as', 'twere') -> {'twere': 1.0}
# ('twere', 'with') -> {'with': 1.0}
# ('with', 'a') -> {'a': 1.0}
# ('a', 'defeated') -> {'defeated': 1.0}
# ('defeated', 'ioy') -> {'ioy': 1.0}
# ('ioy', 'with') -> {'with': 1.0}
# ('with', 'one') -> {'one': 1.0}
# ('one', 'auspicious') -> {'auspicious': 1.0}
# ('auspicious', 'and') -> {'and': 1.0}
# ('and', 'one') -> {'one': 1.0}
# ('one', 'dropping') -> {'dropping': 1.0}
# ('dropping', 'eye') -> {'eye': 1.0}
# ('eye', 'with') -> {'with': 1.0}
# ('with', 'mirth') -> {'mirth': 1.0}
# ('mirth', 'in') -> {'in': 1.0}
# ('in', 'funerall') -> {'funerall': 1.0}
# ('funerall', 'and') -> {'and': 1.0}
# ('and', 'with') -> {'with': 1.0}
# ('with', 'dirge') -> {'dirge': 1.0}
# ('dirge', 'in') -> {'in': 1.0}
# ('in', 'marriage') -> {'marriage': 1.0}
# ('marriage', 'in') -> {'in': 1.0}
# ('in', 'equall') -> {'equall': 1.0}
# ('equall', 'scale') -> {'scale': 1.0}
# ('scale', 'weighing') -> {'weighing': 1.0}
# ('weighing', 'delight') -> {'delight': 1.0}
# ('delight', 'and') -> {'and': 1.0}
# ('and', 'dole') -> {'dole': 1.0}
# ('dole', 'taken') -> {'taken': 1.0}
# ('taken', 'to') -> {'to': 1.0}
# ('to', 'wife') -> {'wife': 1.0}
# ('wife', 'nor') -> {'nor': 1.0}
# ('nor', 'haue') -> {'haue': 1.0}
# ('we', 'heerein') -> {'heerein': 1.0}
# ('heerein', 'barrd') -> {'barrd': 1.0}
# ('barrd', 'your') -> {'your': 1.0}
# ('your', 'better') -> {'better': 1.0}
# ('better', 'wisedomes') -> {'wisedomes': 1.0}
# ('wisedomes', 'which') -> {'which': 1.0}
# ('which', 'haue') -> {'haue': 1.0}
# ('haue', 'freely') -> {'freely': 1.0}
# ('freely', 'gone') -> {'gone': 1.0}
# ('gone', 'with') -> {'with': 1.0}
# ('with', 'this') -> {'this': 1.0}
# ('this', 'affaire') -> {'affaire': 1.0}
# ('affaire', 'along') -> {'along': 1.0}
# ('along', 'for') -> {'for': 1.0}
# ('for', 'all') -> {'all': 1.0}
# ('all', 'our') -> {'our': 1.0}
# ('our', 'thankes') -> {'thankes': 1.0}
# ('thankes', 'now') -> {'now': 1.0}
# ('now', 'followes') -> {'followes': 1.0}
# ('followes', 'that') -> {'that': 1.0}
# ('that', 'you') -> {'you': 1.0}
# ('know', 'young') -> {'young': 1.0}
# ('fortinbras', 'holding') -> {'holding': 1.0}
# ('holding', 'a') -> {'a': 1.0}
# ('a', 'weake') -> {'weake': 1.0}
# ('weake', 'supposall') -> {'supposall': 1.0}
# ('supposall', 'of') -> {'of': 1.0}
# ('our', 'worth') -> {'worth': 1.0}
# ('worth', 'or') -> {'or': 1.0}
# ('or', 'thinking') -> {'thinking': 1.0}
# ('thinking', 'by') -> {'by': 1.0}
# ('our', 'late') -> {'late': 1.0}
# ('late', 'deere') -> {'deere': 1.0}
# ('death', 'our') -> {'our': 1.0}
# ('state', 'to') -> {'to': 1.0}
# ('be', 'disioynt') -> {'disioynt': 1.0}
# ('disioynt', 'and') -> {'and': 1.0}
# ('and', 'out') -> {'out': 1.0}
# ('out', 'of') -> {'of': 1.0}
# ('of', 'frame') -> {'frame': 1.0}
# ('frame', 'colleagued') -> {'colleagued': 1.0}
# ('colleagued', 'with') -> {'with': 1.0}
# ('the', 'dreame') -> {'dreame': 1.0}
# ('dreame', 'of') -> {'of': 1.0}
# ('of', 'his') -> {'his': 1.0}
# ('his', 'aduantage') -> {'aduantage': 1.0}
# ('aduantage', 'he') -> {'he': 1.0}
# ('he', 'hath') -> {'hath': 1.0}
# ('hath', 'not') -> {'not': 1.0}
# ('not', 'fayld') -> {'fayld': 1.0}
# ('fayld', 'to') -> {'to': 1.0}
# ('to', 'pester') -> {'pester': 1.0}
# ('pester', 'vs') -> {'vs': 1.0}
# ('vs', 'with') -> {'with': 1.0}
# ('with', 'message') -> {'message': 1.0}
# ('message', 'importing') -> {'importing': 1.0}
# ('importing', 'the') -> {'the': 1.0}
# ('the', 'surrender') -> {'surrender': 1.0}
# ('surrender', 'of') -> {'of': 1.0}
# ('of', 'those') -> {'those': 1.0}
# ('those', 'lands') -> {'lands': 1.0}
# ('lands', 'lost') -> {'lost': 1.0}
# ('lost', 'by') -> {'by': 1.0}
# ('father', 'with') -> {'with': 1.0}
# ('with', 'all') -> {'all': 1.0}
# ('all', 'bonds') -> {'bonds': 1.0}
# ('bonds', 'of') -> {'of': 1.0}
# ('of', 'law') -> {'law': 1.0}
# ('law', 'to') -> {'to': 1.0}
# ('our', 'most') -> {'most': 1.0}
# ('most', 'valiant') -> {'valiant': 1.0}
# ('valiant', 'brother') -> {'brother': 1.0}
# ('brother', 'so') -> {'so': 1.0}
# ('so', 'much') -> {'much': 1.0}
# ('much', 'for') -> {'for': 1.0}
# ('for', 'him') -> {'him': 1.0}
# ('him', 'enter') -> {'enter': 1.0}
# ('enter', 'voltemand') -> {'voltemand': 1.0}
# ('voltemand', 'and') -> {'and': 1.0}
# ('and', 'cornelius') -> {'cornelius': 1.0}
# ('cornelius', 'now') -> {'now': 1.0}
# ('now', 'for') -> {'for': 1.0}
# ('for', 'our') -> {'our': 1.0}
# ...
# ('dyes', 'laer') -> {'laer': 1.0}
# ('laer', 'he') -> {'he': 1.0}
# ('is', 'iustly') -> {'iustly': 1.0}
# ('iustly', 'serud') -> {'serud': 1.0}
# ('serud', 'it') -> {'it': 1.0}
# ('a', 'poyson') -> {'poyson': 1.0}
# ('poyson', 'tempred') -> {'tempred': 1.0}
# ('tempred', 'by') -> {'by': 1.0}
# ('by', 'himselfe') -> {'himselfe': 1.0}
# ('himselfe', 'exchange') -> {'exchange': 1.0}
# ('exchange', 'forgiuenesse') -> {'forgiuenesse': 1.0}
# ('forgiuenesse', 'with') -> {'with': 1.0}
# ('me', 'noble') -> {'noble': 1.0}
# ('noble', 'hamlet') -> {'hamlet': 1.0}
# ('hamlet', 'mine') -> {'mine': 1.0}
# ('death', 'come') -> {'come': 1.0}
# ('not', 'vpon') -> {'vpon': 1.0}
# ('vpon', 'thee') -> {'thee': 1.0}
# ('thee', 'nor') -> {'nor': 1.0}
# ('nor', 'thine') -> {'thine': 1.0}
# ('thine', 'on') -> {'on': 1.0}
# ('me', 'dyes') -> {'dyes': 1.0}
# ('dyes', 'ham') -> {'ham': 1.0}
# ('ham', 'heauen') -> {'heauen': 1.0}
# ('heauen', 'make') -> {'make': 1.0}
# ('thee', 'free') -> {'free': 1.0}
# ('free', 'of') -> {'of': 1.0}
# ('am', 'dead') -> {'dead': 1.0}
# ('dead', 'horatio') -> {'horatio': 1.0}
# ('horatio', 'wretched') -> {'wretched': 1.0}
# ('wretched', 'queene') -> {'queene': 1.0}
# ('queene', 'adiew') -> {'adiew': 1.0}
# ('adiew', 'you') -> {'you': 1.0}
# ('that', 'looke') -> {'looke': 1.0}
# ('looke', 'pale') -> {'pale': 1.0}
# ('pale', 'and') -> {'and': 1.0}
# ('and', 'tremble') -> {'tremble': 1.0}
# ('tremble', 'at') -> {'at': 1.0}
# ('this', 'chance') -> {'chance': 1.0}
# ('chance', 'that') -> {'that': 1.0}
# ('but', 'mutes') -> {'mutes': 1.0}
# ('mutes', 'or') -> {'or': 1.0}
# ('or', 'audience') -> {'audience': 1.0}
# ('audience', 'to') -> {'to': 1.0}
# ('this', 'acte') -> {'acte': 1.0}
# ('acte', 'had') -> {'had': 1.0}
# ('had', 'i') -> {'i': 1.0}
# ('but', 'time') -> {'time': 1.0}
# ('time', 'as') -> {'as': 1.0}
# ('this', 'fell') -> {'fell': 1.0}
# ('fell', 'sergeant') -> {'sergeant': 1.0}
# ('sergeant', 'death') -> {'death': 1.0}
# ('death', 'is') -> {'is': 1.0}
# ('is', 'strickd') -> {'strickd': 1.0}
# ('strickd', 'in') -> {'in': 1.0}
# ('his', 'arrest') -> {'arrest': 1.0}
# ('arrest', 'oh') -> {'oh': 1.0}
# ('could', 'tell') -> {'tell': 1.0}
# ('horatio', 'i') -> {'i': 1.0}
# ('dead', 'thou') -> {'thou': 1.0}
# ('thou', 'liust') -> {'liust': 1.0}
# ('liust', 'report') -> {'report': 1.0}
# ('report', 'me') -> {'me': 1.0}
# ('my', 'causes') -> {'causes': 1.0}
# ('causes', 'right') -> {'right': 1.0}
# ('right', 'to') -> {'to': 1.0}
# ('the', 'vnsatisfied') -> {'vnsatisfied': 1.0}
# ('vnsatisfied', 'hor') -> {'hor': 1.0}
# ('hor', 'neuer') -> {'neuer': 1.0}
# ('neuer', 'beleeue') -> {'beleeue': 1.0}
# ('am', 'more') -> {'more': 1.0}
# ('more', 'an') -> {'an': 1.0}
# ('an', 'antike') -> {'antike': 1.0}
# ('antike', 'roman') -> {'roman': 1.0}
# ('roman', 'then') -> {'then': 1.0}
# ('a', 'dane') -> {'dane': 1.0}
# ('dane', 'heeres') -> {'heeres': 1.0}
# ('heeres', 'yet') -> {'yet': 1.0}
# ('yet', 'some') -> {'some': 1.0}
# ('some', 'liquor') -> {'liquor': 1.0}
# ('liquor', 'left') -> {'left': 1.0}
# ('left', 'ham') -> {'ham': 1.0}
# ('as', 'thart') -> {'thart': 1.0}
# ('thart', 'a') -> {'a': 1.0}
# ('man', 'giue') -> {'giue': 1.0}
# ('cup', 'let') -> {'let': 1.0}
# ('let', 'go') -> {'go': 1.0}
# ('heauen', 'ile') -> {'ile': 1.0}
# ('ile', 'hauet') -> {'hauet': 1.0}
# ('hauet', 'oh') -> {'oh': 1.0}
# ('horatio', 'what') -> {'what': 1.0}
# ('a', 'wounded') -> {'wounded': 1.0}
# ('wounded', 'name') -> {'name': 1.0}
# ('name', 'things') -> {'things': 1.0}
# ('things', 'standing') -> {'standing': 1.0}
# ('standing', 'thus') -> {'thus': 1.0}
# ('thus', 'vnknowne') -> {'vnknowne': 1.0}
# ('vnknowne', 'shall') -> {'shall': 1.0}
# ('liue', 'behind') -> {'behind': 1.0}
# ('behind', 'me') -> {'me': 1.0}
# ('euer', 'hold') -> {'hold': 1.0}
# ('hold', 'me') -> {'me': 1.0}
# ('thy', 'heart') -> {'heart': 1.0}
# ('heart', 'absent') -> {'absent': 1.0}
# ('absent', 'thee') -> {'thee': 1.0}
# ('thee', 'from') -> {'from': 1.0}
# ('from', 'felicitie') -> {'felicitie': 1.0}
# ('felicitie', 'awhile') -> {'awhile': 1.0}
# ('this', 'harsh') -> {'harsh': 1.0}
# ('harsh', 'world') -> {'world': 1.0}
# ('world', 'draw') -> {'draw': 1.0}
# ('draw', 'thy') -> {'thy': 1.0}
# ('thy', 'breath') -> {'breath': 1.0}
# ('breath', 'in') -> {'in': 1.0}
# ('in', 'paine') -> {'paine': 1.0}
# ('paine', 'to') -> {'to': 1.0}
# ('tell', 'my') -> {'my': 1.0}
# ('my', 'storie') -> {'storie': 1.0}
# ('storie', 'march') -> {'march': 1.0}
# ('march', 'afarre') -> {'afarre': 1.0}
# ('afarre', 'off') -> {'off': 1.0}
# ('and', 'shout') -> {'shout': 1.0}
# ('shout', 'within') -> {'within': 1.0}
# ('within', 'what') -> {'what': 1.0}
# ('what', 'warlike') -> {'warlike': 1.0}
# ('warlike', 'noyse') -> {'noyse': 1.0}
# ('this', 'enter') -> {'enter': 1.0}
# ('enter', 'osricke') -> {'osricke': 1.0}
# ('osr', 'yong') -> {'yong': 1.0}
# ('yong', 'fortinbras') -> {'fortinbras': 1.0}
# ('with', 'conquest') -> {'conquest': 1.0}
# ('conquest', 'come') -> {'come': 1.0}
# ('from', 'poland') -> {'poland': 1.0}
# ('poland', 'to') -> {'to': 1.0}
# ('ambassadors', 'of') -> {'of': 1.0}
# ('of', 'england') -> {'england': 1.0}
# ('england', 'giues') -> {'giues': 1.0}
# ('giues', 'this') -> {'this': 1.0}
# ('warlike', 'volly') -> {'volly': 1.0}
# ('volly', 'ham') -> {'ham': 1.0}
# ('o', 'i') -> {'i': 1.0}
# ('i', 'dye') -> {'dye': 1.0}
# ('dye', 'horatio') -> {'horatio': 1.0}
# ('the', 'potent') -> {'potent': 1.0}
# ('potent', 'poyson') -> {'poyson': 1.0}
# ('poyson', 'quite') -> {'quite': 1.0}
# ('quite', 'orecrowes') -> {'orecrowes': 1.0}
# ('orecrowes', 'my') -> {'my': 1.0}
# ('my', 'spirit') -> {'spirit': 1.0}
# ('spirit', 'i') -> {'i': 1.0}
# ('not', 'liue') -> {'liue': 1.0}
# ('liue', 'to') -> {'to': 1.0}
# ('newes', 'from') -> {'from': 1.0}
# ('england', 'but') -> {'but': 1.0}
# ('do', 'prophesie') -> {'prophesie': 1.0}
# ('prophesie', 'th') -> {'th': 1.0}
# ('election', 'lights') -> {'lights': 1.0}
# ('lights', 'on') -> {'on': 1.0}
# ('fortinbras', 'he') -> {'he': 1.0}
# ('my', 'dying') -> {'dying': 1.0}
# ('dying', 'voyce') -> {'voyce': 1.0}
# ('voyce', 'so') -> {'so': 1.0}
# ('so', 'tell') -> {'tell': 1.0}
# ('the', 'occurrents') -> {'occurrents': 1.0}
# ('occurrents', 'more') -> {'more': 1.0}
# ('lesse', 'which') -> {'which': 1.0}
# ('haue', 'solicited') -> {'solicited': 1.0}
# ('solicited', 'the') -> {'the': 1.0}
# ('rest', 'is') -> {'is': 1.0}
# ('is', 'silence') -> {'silence': 1.0}
# ('silence', 'o') -> {'o': 1.0}
# ('o', 'o') -> {'o': 1.0}
# ('o', 'dyes') -> {'dyes': 1.0}
# ('dyes', 'hora') -> {'hora': 1.0}
# ('hora', 'now') -> {'now': 1.0}
# ('now', 'cracke') -> {'cracke': 1.0}
# ('cracke', 'a') -> {'a': 1.0}
# ('noble', 'heart') -> {'heart': 1.0}
# ('heart', 'goodnight') -> {'goodnight': 1.0}
# ('sweet', 'prince') -> {'prince': 1.0}
# ('prince', 'and') -> {'and': 1.0}
# ('and', 'flights') -> {'flights': 1.0}
# ('flights', 'of') -> {'of': 1.0}
# ('of', 'angels') -> {'angels': 1.0}
# ('angels', 'sing') -> {'sing': 1.0}
# ('sing', 'thee') -> {'thee': 1.0}
# ('thy', 'rest') -> {'rest': 1.0}
# ('rest', 'why') -> {'why': 1.0}
# ('why', 'dos') -> {'dos': 1.0}
# ('dos', 'the') -> {'the': 1.0}
# ('the', 'drumme') -> {'drumme': 1.0}
# ('drumme', 'come') -> {'come': 1.0}
# ('hither', 'enter') -> {'enter': 1.0}
# ('fortinbras', 'and') -> {'and': 1.0}
# ('and', 'english') -> {'english': 1.0}
# ('english', 'ambassador') -> {'ambassador': 1.0}
# ('ambassador', 'with') -> {'with': 1.0}
# ('with', 'drumme') -> {'drumme': 1.0}
# ('drumme', 'colours') -> {'colours': 1.0}
# ('colours', 'and') -> {'and': 1.0}
# ('and', 'attendants') -> {'attendants': 1.0}
# ('attendants', 'fortin') -> {'fortin': 1.0}
# ('fortin', 'where') -> {'where': 1.0}
# ('sight', 'hor') -> {'hor': 1.0}
# ('it', 'ye') -> {'ye': 1.0}
# ('ye', 'would') -> {'would': 1.0}
# ('would', 'see') -> {'see': 1.0}
# ('if', 'ought') -> {'ought': 1.0}
# ('woe', 'or') -> {'or': 1.0}
# ('or', 'wonder') -> {'wonder': 1.0}
# ('wonder', 'cease') -> {'cease': 1.0}
# ('cease', 'your') -> {'your': 1.0}
# ('your', 'search') -> {'search': 1.0}
# ('search', 'for') -> {'for': 1.0}
# ('his', 'quarry') -> {'quarry': 1.0}
# ('quarry', 'cries') -> {'cries': 1.0}
# ('cries', 'on') -> {'on': 1.0}
# ('on', 'hauocke') -> {'hauocke': 1.0}
# ('hauocke', 'oh') -> {'oh': 1.0}
# ('oh', 'proud') -> {'proud': 1.0}
# ('proud', 'death') -> {'death': 1.0}
# ('what', 'feast') -> {'feast': 1.0}
# ('feast', 'is') -> {'is': 1.0}
# ('is', 'toward') -> {'toward': 1.0}
# ('toward', 'in') -> {'in': 1.0}
# ('in', 'thine') -> {'thine': 1.0}
# ('thine', 'eternall') -> {'eternall': 1.0}
# ('eternall', 'cell') -> {'cell': 1.0}
# ('cell', 'that') -> {'that': 1.0}
# ('many', 'princes') -> {'princes': 1.0}
# ('princes', 'at') -> {'at': 1.0}
# ('a', 'shoote') -> {'shoote': 1.0}
# ('shoote', 'so') -> {'so': 1.0}
# ('so', 'bloodily') -> {'bloodily': 1.0}
# ('bloodily', 'hast') -> {'hast': 1.0}
# ('hast', 'strooke') -> {'strooke': 1.0}
# ('strooke', 'amb') -> {'amb': 1.0}
# ('amb', 'the') -> {'the': 1.0}
# ('the', 'sight') -> {'sight': 1.0}
# ('sight', 'is') -> {'is': 1.0}
# ('is', 'dismall') -> {'dismall': 1.0}
# ('dismall', 'and') -> {'and': 1.0}
# ('our', 'affaires') -> {'affaires': 1.0}
# ('affaires', 'from') -> {'from': 1.0}
# ('england', 'come') -> {'come': 1.0}
# ('come', 'too') -> {'too': 1.0}
# ('eares', 'are') -> {'are': 1.0}
# ('are', 'senselesse') -> {'senselesse': 1.0}
# ('senselesse', 'that') -> {'that': 1.0}
# ('should', 'giue') -> {'giue': 1.0}
# ('vs', 'hearing') -> {'hearing': 1.0}
# ('his', 'commandment') -> {'commandment': 1.0}
# ('commandment', 'is') -> {'is': 1.0}
# ('is', 'fulfilld') -> {'fulfilld': 1.0}
# ('fulfilld', 'that') -> {'that': 1.0}
# ('that', 'rosincrance') -> {'rosincrance': 1.0}
# ('guildensterne', 'are') -> {'are': 1.0}
# ('are', 'dead') -> {'dead': 1.0}
# ('dead', 'where') -> {'where': 1.0}
# ('where', 'should') -> {'should': 1.0}
# ('haue', 'our') -> {'our': 1.0}
# ('thankes', 'hor') -> {'hor': 1.0}
# ('his', 'mouth') -> {'mouth': 1.0}
# ('mouth', 'had') -> {'had': 1.0}
# ('had', 'it') -> {'it': 1.0}
# ('it', 'th') -> {'th': 1.0}
# ('th', 'abilitie') -> {'abilitie': 1.0}
# ('abilitie', 'of') -> {'of': 1.0}
# ('to', 'thanke') -> {'thanke': 1.0}
# ('you', 'he') -> {'he': 1.0}
# ('gaue', 'commandment') -> {'commandment': 1.0}
# ('commandment', 'for') -> {'for': 1.0}
# ('for', 'their') -> {'their': 1.0}
# ('their', 'death') -> {'death': 1.0}
# ('death', 'but') -> {'but': 1.0}
# ('so', 'iumpe') -> {'iumpe': 1.0}
# ('iumpe', 'vpon') -> {'vpon': 1.0}
# ('this', 'bloodie') -> {'bloodie': 1.0}
# ('bloodie', 'question') -> {'question': 1.0}
# ('question', 'you') -> {'you': 1.0}
# ('the', 'polake') -> {'polake': 1.0}
# ('polake', 'warres') -> {'warres': 1.0}
# ('warres', 'and') -> {'and': 1.0}
# ('england', 'are') -> {'are': 1.0}
# ('are', 'heere') -> {'heere': 1.0}
# ('heere', 'arriued') -> {'arriued': 1.0}
# ('arriued', 'giue') -> {'giue': 1.0}
# ('giue', 'order') -> {'order': 1.0}
# ('order', 'that') -> {'that': 1.0}
# ('that', 'these') -> {'these': 1.0}
# ('these', 'bodies') -> {'bodies': 1.0}
# ('bodies', 'high') -> {'high': 1.0}
# ('high', 'on') -> {'on': 1.0}
# ('a', 'stage') -> {'stage': 1.0}
# ('stage', 'be') -> {'be': 1.0}
# ('be', 'placed') -> {'placed': 1.0}
# ('placed', 'to') -> {'to': 1.0}
# ('me', 'speake') -> {'speake': 1.0}
# ('th', 'yet') -> {'yet': 1.0}
# ('yet', 'vnknowing') -> {'vnknowing': 1.0}
# ('vnknowing', 'world') -> {'world': 1.0}
# ('world', 'how') -> {'how': 1.0}
# ('how', 'these') -> {'these': 1.0}
# ('these', 'things') -> {'things': 1.0}
# ('things', 'came') -> {'came': 1.0}
# ('came', 'about') -> {'about': 1.0}
# ('about', 'so') -> {'so': 1.0}
# ('you', 'heare') -> {'heare': 1.0}
# ('of', 'carnall') -> {'carnall': 1.0}
# ('carnall', 'bloudie') -> {'bloudie': 1.0}
# ('bloudie', 'and') -> {'and': 1.0}
# ('vnnaturall', 'acts') -> {'acts': 1.0}
# ('acts', 'of') -> {'of': 1.0}
# ('of', 'accidentall') -> {'accidentall': 1.0}
# ('accidentall', 'iudgements') -> {'iudgements': 1.0}
# ('iudgements', 'casuall') -> {'casuall': 1.0}
# ('casuall', 'slaughters') -> {'slaughters': 1.0}
# ('slaughters', 'of') -> {'of': 1.0}
# ('of', 'deaths') -> {'deaths': 1.0}
# ('deaths', 'put') -> {'put': 1.0}
# ('by', 'cunning') -> {'cunning': 1.0}
# ('cunning', 'and') -> {'and': 1.0}
# ('and', 'forcd') -> {'forcd': 1.0}
# ('forcd', 'cause') -> {'cause': 1.0}
# ('this', 'vpshot') -> {'vpshot': 1.0}
# ('vpshot', 'purposes') -> {'purposes': 1.0}
# ('purposes', 'mistooke') -> {'mistooke': 1.0}
# ('mistooke', 'falne') -> {'falne': 1.0}
# ('falne', 'on') -> {'on': 1.0}
# ('the', 'inuentors') -> {'inuentors': 1.0}
# ('inuentors', 'head') -> {'head': 1.0}
# ('head', 'all') -> {'all': 1.0}
# ('this', 'can') -> {'can': 1.0}
# ('i', 'truly') -> {'truly': 1.0}
# ('truly', 'deliuer') -> {'deliuer': 1.0}
# ('deliuer', 'for') -> {'for': 1.0}
# ('vs', 'hast') -> {'hast': 1.0}
# ('hast', 'to') -> {'to': 1.0}
# ('heare', 'it') -> {'it': 1.0}
# ('the', 'noblest') -> {'noblest': 1.0}
# ('noblest', 'to') -> {'to': 1.0}
# ('the', 'audience') -> {'audience': 1.0}
# ('audience', 'for') -> {'for': 1.0}
# ('with', 'sorrow') -> {'sorrow': 1.0}
# ('sorrow', 'i') -> {'i': 1.0}
# ('i', 'embrace') -> {'embrace': 1.0}
# ('embrace', 'my') -> {'my': 1.0}
# ('my', 'fortune') -> {'fortune': 1.0}
# ('fortune', 'i') -> {'i': 1.0}
# ('haue', 'some') -> {'some': 1.0}
# ('some', 'rites') -> {'rites': 1.0}
# ('rites', 'of') -> {'of': 1.0}
# ('of', 'memory') -> {'memory': 1.0}
# ('memory', 'in') -> {'in': 1.0}
# ('this', 'kingdome') -> {'kingdome': 1.0}
# ('kingdome', 'which') -> {'which': 1.0}
# ('to', 'claime') -> {'claime': 1.0}
# ('claime', 'my') -> {'my': 1.0}
# ('my', 'vantage') -> {'vantage': 1.0}
# ('vantage', 'doth') -> {'doth': 1.0}
# ('doth', 'inuite') -> {'inuite': 1.0}
# ('inuite', 'me') -> {'me': 1.0}
# ('hor', 'of') -> {'of': 1.0}
# ('haue', 'alwayes') -> {'alwayes': 1.0}
# ('alwayes', 'cause') -> {'cause': 1.0}
# ('cause', 'to') -> {'to': 1.0}
# ('speake', 'and') -> {'and': 1.0}
# ('mouth', 'whose') -> {'whose': 1.0}
# ('whose', 'voyce') -> {'voyce': 1.0}
# ('voyce', 'will') -> {'will': 1.0}
# ('draw', 'on') -> {'on': 1.0}
# ('on', 'more') -> {'more': 1.0}
# ('same', 'be') -> {'be': 1.0}
# ('be', 'presently') -> {'presently': 1.0}
# ('presently', 'performd') -> {'performd': 1.0}
# ('performd', 'euen') -> {'euen': 1.0}
# ('euen', 'whiles') -> {'whiles': 1.0}
# ('whiles', 'mens') -> {'mens': 1.0}
# ('mens', 'mindes') -> {'mindes': 1.0}
# ('mindes', 'are') -> {'are': 1.0}
# ('are', 'wilde') -> {'wilde': 1.0}
# ('wilde', 'lest') -> {'lest': 1.0}
# ('lest', 'more') -> {'more': 1.0}
# ('more', 'mischance') -> {'mischance': 1.0}
# ('mischance', 'on') -> {'on': 1.0}
# ('on', 'plots') -> {'plots': 1.0}
# ('plots', 'and') -> {'and': 1.0}
# ('and', 'errors') -> {'errors': 1.0}
# ('errors', 'happen') -> {'happen': 1.0}
# ('happen', 'for') -> {'for': 1.0}
# ('let', 'foure') -> {'foure': 1.0}
# ('foure', 'captaines') -> {'captaines': 1.0}
# ('captaines', 'beare') -> {'beare': 1.0}
# ('beare', 'hamlet') -> {'hamlet': 1.0}
# ('hamlet', 'like') -> {'like': 1.0}
# ('a', 'soldier') -> {'soldier': 1.0}
# ('soldier', 'to') -> {'to': 1.0}
# ('stage', 'for') -> {'for': 1.0}
# ('for', 'he') -> {'he': 1.0}
# ('was', 'likely') -> {'likely': 1.0}
# ('likely', 'had') -> {'had': 1.0}
# ('beene', 'put') -> {'put': 1.0}
# ('haue', 'proud') -> {'proud': 1.0}
# ('proud', 'most') -> {'most': 1.0}
# ('most', 'royally') -> {'royally': 1.0}
# ('royally', 'and') -> {'and': 1.0}
# ('passage', 'the') -> {'the': 1.0}
# ('the', 'souldiours') -> {'souldiours': 1.0}
# ('souldiours', 'musicke') -> {'musicke': 1.0}
# ('musicke', 'and') -> {'and': 1.0}
# ('the', 'rites') -> {'rites': 1.0}
# ('warre', 'speake') -> {'speake': 1.0}
# ('speake', 'lowdly') -> {'lowdly': 1.0}
# ('lowdly', 'for') -> {'for': 1.0}
# ('take', 'vp') -> {'vp': 1.0}
# ('body', 'such') -> {'such': 1.0}
# ('sight', 'as') -> {'as': 1.0}
# ('this', 'becomes') -> {'becomes': 1.0}
# ('becomes', 'the') -> {'the': 1.0}
# ('the', 'field') -> {'field': 1.0}
# ('field', 'but') -> {'but': 1.0}
# ('but', 'heere') -> {'heere': 1.0}
# ('heere', 'shewes') -> {'shewes': 1.0}
# ('shewes', 'much') -> {'much': 1.0}
# ('much', 'amis') -> {'amis': 1.0}
# ('amis', 'go') -> {'go': 1.0}
# ('go', 'bid') -> {'bid': 1.0}
# ('the', 'souldiers') -> {'souldiers': 1.0}
# ('souldiers', 'shoote') -> {'shoote': 1.0}
# ('shoote', 'exeunt') -> {'exeunt': 1.0}
# ('exeunt', 'marching') -> {'marching': 1.0}
# ('marching', 'after') -> {'after': 1.0}
# ('a', 'peale') -> {'peale': 1.0}
# ('peale', 'of') -> {'of': 1.0}
# ('of', 'ordenance') -> {'ordenance': 1.0}
# ('ordenance', 'are') -> {'are': 1.0}
# ('are', 'shot') -> {'shot': 1.0}
# ('shot', 'off') -> {'off': 1.0}
# ('off', 'finis') -> {'finis': 1.0}
# ('finis', 'the') -> {'the': 1.0}
# ('hamlet', 'prince') -> {'prince': 1.0}
# ('prince', 'of') -> {'of': 1.0}
